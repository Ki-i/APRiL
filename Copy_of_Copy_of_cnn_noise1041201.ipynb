# %% [markdown]
# <a href="https://colab.research.google.com/github/Ki-i/APRiL/blob/master/Copy_of_Copy_of_cnn_noise1041201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
workspace_dir = '.'
#!unzip -q "/content/drive/My Drive/crypko_data.zip" -d "{workspace_dir}/"

# %%
from torch.nn import Module
from torch import nn
import numpy as np
import math
import torch
from torch.nn import CrossEntropyLoss
from torch.nn import MSELoss
from torch.optim import SGD
from torch.utils.data import DataLoader, TensorDataset
import os
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import matplotlib.pyplot as plt
import sys
import scipy.io as scio
import pylab

# %%
class DnCNN(nn.Module):
    def __init__(self):
        super(DnCNN, self).__init__()
        channels=3
        num_of_layers=10
        kernel_size = 3
        padding = 1
        features = 64
        layers = []
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))
        for _ in range(num_of_layers-2):
            layers.append(nn.Conv2d(in_channels=features, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
            layers.append(nn.BatchNorm2d(features))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False))
 
        self.dncnn = nn.Sequential(*layers)
        self.fc1=nn.Linear( 3*50*100,6)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(6,2)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练
    def forward(self, x):
        y = self.dncnn(x)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu(y)
        y = self.fc2(y)
        #print(y)
        return y

# %%
class Model(Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(2, 32, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)
        self.conv3 = nn.Conv2d(64, 64, 5)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(64*2*9, 64)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(64, 6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练

    def forward(self, x):
        y = self.conv1(x)
        y = self.relu1(y)
        y = self.pool1(y)
        y = self.conv2(y)
        y = self.relu2(y)
        y = self.pool2(y)
        y = self.conv3(y)
        y = self.relu3(y)
        y = self.pool3(y)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu3(y)
        y = self.fc2(y)
        # y = self.relu4(y)
        # y = self.fc3(y)
        # y = self.relu5(y)
        return y

# %%
def get_data(dataset_path, fm, dev_ratio):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    #datalen = int(len(x_data) / 3)
    datalen=1000
    x = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y = np.zeros((datalen, 2), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str(i)
        #print(xkey)
        x[i] = data[xkey]
        
        ykey = 'y' + str(i)
        y[i] = data[ykey]#噪声
        #if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])
        

    data_size = len(y)
    train_size = int(data_size * (1 - dev_ratio))
    state = np.random.get_state()
    np.random.shuffle(x)
    np.random.set_state(state)
    np.random.shuffle(y)
    # print("train size:", train_size)
    # print("dev size:", data_size - train_size)
    x_train = x[:train_size]
    y_train = y[:train_size]
    x_dev = x[train_size:]
    y_dev = y[train_size:]
    return x_train, y_train, x_dev, y_dev

# %%
class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x, self.y = x, y
        self.data_size = len(self.y)
        #norm_mean = [0.485, 0.456, 0.406]
        #norm_std = [0.229, 0.224, 0.225]
        self.img_transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.ToTensor(),
            # transforms.Normalize(norm_mean, norm_std),
        ])

    def __len__(self):
        return self.data_size

    def __getitem__(self, item):
        '''
        这个函数是关键，通过item(索引)来取数据集中的数据，
        一般来说在这里才将图像数据加载入内存，之前存的是图像的保存路径
        '''
        ycut=self.y[item]
        #ycut=ycut[101:-6:400,1:-5:500]

        label = torch.from_numpy(ycut)
        #label = torch.reshape(label, (1, -1))
        xcut = self.x[item]
        #xcut = xcut[101:-6:400,1:-5:500]
        x = torch.from_numpy(xcut)
        #x=x.unsqueeze(0)
        #label=label.squeeze(0)
        x=x.float()
        label=label.float()
        x = torch.div(x, 255.)
        label = torch.div(label, 10000.)
        #print(x.size())
        #print(label.size())
        #label=torch.div(label, 255.)
        return x, label

# %%
x=np.array([1,2,3,4])
x=x/4
print(x)
# Out:
# [0.25 0.5  0.75 1.  ]

# %%
def psnr(target_data, ref_data):
    # target:目标图像  ref:参考图像  scale:尺寸大小
    # assume RGB image
    #target_data = np.array(target)
    #target_data = target_data[scale:-scale, scale:-scale]

    #ref_data = np.array(ref)
    #ref_data = ref_data[scale:-scale, scale:-scale]
    im = ref_data.max()
    print('参考图像峰值', ref_data.max(), ref_data.min())
    print('实际图像峰值', target_data.max(), target_data.min())
    target_data = target_data * (ref_data.max() / target_data.max())
    #print('实际图像峰值', target_data.max(), target_data.min())
    diff = ref_data - target_data
    diff = diff.flatten('C')

    #rmse = math.sqrt(np.mean(diff ** 2.))
    #return 20 * math.log10(math.pow(im,2) / rmse)
    mse = np.mean(diff ** 2.)
    return 20 * math.log10(math.pow(im,2) / mse)

def ab_err(target_data, ref_data):
  diff = abs(ref_data - target_data)/ref_data
  diff=diff.cpu().data.numpy()
  tdiff=diff[0:,0]
  vdiff=diff[0:,1]
  
  #print(tdiff,tdiff)
  terr = np.mean(tdiff)
  verr = np.mean(vdiff)
  

  return terr,verr

# %%
if __name__ == '__main__':

    batch_size = 32
    lr=1e-5
    #lr=1e-4#loss:11.72 10.74
    #lr=1e-3#9.6519
    #lr=0.01#8.3690
    #lr=0.1#8.2 7.72 7.71 ..7156.7147
    log_dir='/content/drive/My Drive/model.pth'
    #数据集加载
    dataset_path = '/content/drive/My Drive/'
    x_train, y_train, x_dev, y_dev = get_data(dataset_path, 'TrainData04.mat', 0.2)
    #print(x_train[0])
    train_dataset = MyDataset(x_train, y_train)
    train_loader = DataLoader(train_dataset, batch_size=batch_size)
    dev_dataset = MyDataset(x_dev, y_dev)
    dev_loader = DataLoader(train_dataset, batch_size=batch_size)

    model = DnCNN()
    #model = Model()
    #模型加载
    start_epoch=0
    '''
    if os.path.exists(log_dir):
        checkpoint = torch.load(log_dir)
        model.load_state_dict(checkpoint['net'])
        start_epoch = checkpoint['epoch']
        print('加载 epoch {} 成功！'.format(start_epoch))
    else:
        start_epoch = 0
        print('无保存模型，将从头开始训练！')
    '''
    sgd = SGD(model.parameters(), lr)

    cost = CrossEntropyLoss()
    criterion = MSELoss(reduction='sum')
    epoch = 150
    use_GPU = True
    if use_GPU:
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")
    model.to(device)
    epoch_train_loss_list = []
    epoch_dev_loss_list = []
    epoch_train_acc_list = []
    epoch_dev_acc_list = []
    epoch_train_derror_list = []
    epoch_dev_derror_list = []
    epoch_train_verror_list = []
    epoch_dev_verror_list = []
    for _epoch in range(start_epoch+1,start_epoch+epoch):
        model.train()
        epoch_train_loss = 0
        epoch_dev_loss = 0
        epoch_train_acc = 0
        epoch_dev_acc = 0
        train_num=0
        dev_num = 0
        epoch_dev_derror=0
        epoch_dev_verror=0
        epoch_train_derror=0
        epoch_train_verror=0
        for idx, (train_x, train_label) in enumerate(train_loader):
            s = train_label.shape[0]
            sgd.zero_grad()
            #print(train_x.size())
            predict_y = model(train_x.to(device))

            loss = criterion(predict_y, train_label.to(device))/ (2 * len(train_x))
            terror,verror=ab_err(predict_y,train_label.to(device))
            epoch_train_loss += loss.item()
            epoch_train_derror+=terror
            epoch_train_verror+=verror
            label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
            #acc = np.sum(label_pred == train_label.numpy())
            # print("batch Train acc:",acc / s)
            #epoch_train_acc += acc / s
            train_num+=1
            loss.backward()
            sgd.step()

        correct = 0
        _sum = 0
        model.eval()

        with torch.no_grad():
            for idx, (dev_x, dev_label) in enumerate(dev_loader):
                s = dev_label.shape[0]
                predict_y = model(dev_x.to(device))
                # print(predict_y[0], dev_label[0])
                loss = criterion(predict_y, train_label.to(device)) / (2 * len(train_x))
                terror,verror=ab_err(predict_y,train_label.to(device))
                
                epoch_dev_derror+=terror
                epoch_dev_verror+=verror
                epoch_dev_loss += loss.item()
                label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
                # print("------")
                # print(label_pred)
                # print(dev_label.numpy())
                # print("------")
                #acc = np.sum(label_pred == dev_label.numpy())
                #batch_acc=acc / s
                dev_num+=1
                # print("batch_acc::",batch_acc)
                #epoch_dev_acc += acc / s
                # print("devacc", acc);
        epoch_train_loss_list.append(epoch_train_loss / train_num)
        epoch_dev_loss_list.append(epoch_dev_loss / dev_num)
        epoch_train_derror_list.append(epoch_train_derror / train_num)
        epoch_dev_derror_list.append(epoch_dev_derror / dev_num)
        epoch_train_verror_list.append(epoch_train_verror / train_num)
        epoch_dev_verror_list.append(epoch_dev_verror / dev_num)

        #epoch_train_acc_list.append(epoch_train_acc / dev_num)
        #epoch_dev_acc_list.append(epoch_dev_acc / dev_num)
        print('-------------------------------------------------------------------------------------------------------------------------------------')
        print("epoch {:.4f} ,train loss: {:.4f}, dev loss: {:.4f}".format(_epoch, epoch_train_loss / train_num, epoch_dev_loss / dev_num))
        print("epoch {:.4f} ,train derror: {:.4f}, dev derror: {:.4f}，train verror: {:.4f}, dev verror: {:.4f}".format(_epoch, epoch_train_derror / train_num, epoch_dev_derror / dev_num, epoch_train_verror / train_num, epoch_dev_verror / dev_num))
        print('-------------------------------------------------------------------------------------------------------------------------------------')
        '''
        #绘图
        y_show = predict_y.reshape([batch_size, 50, 100])
        y_show = y_show.cpu().data.numpy()
        
        #print(train_x.size())
        x_show_x=train_x.squeeze(1)
        label_show=train_label.reshape([batch_size,50, 100])
        label_show=label_show.cpu().data.numpy()
        #print(x_show_x.size())
        x_show= x_show_x.numpy()
        y_show=x_show-y_show
        label_show=x_show-label_show
        #print(len(y_show[batch_size-1]))
        im1=1
        im2=int(batch_size/2)
        im3=batch_size-1
        pylab.figure(figsize=(10,10))
        plot = 'plot' + str(_epoch)
        plot = pylab.subplot(3, 3, 1)
        pylab.title('input_epcho'+str(_epoch)+'_image'+str(im1))
        pylab.imshow(np.asarray(x_show[im1]))
        plot = pylab.subplot(3, 3, 2)
        pylab.title('output_epcho'+str(_epoch)+'_image'+str(im1))
        pylab.imshow(np.asarray(y_show[im1]))
        plot = pylab.subplot(3, 3, 3)
        pylab.title('label__epcho'+str(_epoch)+'_image'+str(im1))
        pylab.imshow(np.asarray(label_show[im1]))
        plot = pylab.subplot(3, 3, 4)
        pylab.title('input__epcho'+str(_epoch)+'_image'+str(im2))
        pylab.imshow(np.asarray(x_show[im2]))
        plot = pylab.subplot(3, 3, 5)
        pylab.title('output__epcho'+str(_epoch)+'_image'+str(im2))
        pylab.imshow(np.asarray(y_show[im2]))
        plot = pylab.subplot(3, 3, 6)
        pylab.title('label__epcho'+str(_epoch)+'_image'+str(im2))
        pylab.imshow(np.asarray(label_show[im2]))
        plot = pylab.subplot(3, 3, 7)
        pylab.title('input__epcho'+str(_epoch)+'_image'+str(im3))
        pylab.imshow(np.asarray(x_show[im3]))
        plot = pylab.subplot(3, 3, 8)
        pylab.title('output__epcho'+str(_epoch)+'_image'+str(im3))
        pylab.imshow(np.asarray(y_show[im3]))
        plot = pylab.subplot(3, 3, 9)
        pylab.title('label__epcho'+str(_epoch)+'_image'+str(im3))
        pylab.imshow(np.asarray(label_show[im3]))
        pylab.show()
        '''
        '''
        y_show=predict_y.reshape([batch_size,50,100])
        print(y_show.size())
        #y_show=y_show.cpu().data.numpy()
        #imgs_sample = [y_show[i] for i in range(16,32)]
        y_show = y_show.unsqueeze(1)
        print(y_show.size())
        grid_img = torchvision.utils.make_grid(y_show.cpu(), nrow=4)
        plt.figure(figsize=(10, 10))  # 画图
        plt.imshow(grid_img)
        plt.show()  # 展示图片
        '''

    t = np.arange(1, len(epoch_train_loss_list) + 1)
    #模型保存
    
    state = {'net':model.state_dict(),  'epoch':epoch}
    torch.save(state, log_dir)

    plt.figure(figsize=(5,15))
    
    loss_plot = plt.subplot(3, 1, 1)
    plt.title('loss ')
    plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
    plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
    der_plot = plt.subplot(3, 1, 2)
    plt.title('distance error')
    plt.plot(t, epoch_train_derror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
    der_plot = plt.subplot(3, 1, 3)
    plt.title('Velocity error')
    plt.plot(t, epoch_train_verror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
    plt.show()
# Out:
# load data from path1: /content/drive/My Drive/
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 1.0000 ,train loss: 1.3301, dev loss: 1.3333
# epoch 1.0000 ,train derror: inf, dev derror: 18.6841，train verror: inf, dev verror: 0.9236
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 2.0000 ,train loss: 1.1834, dev loss: 1.2864
# epoch 2.0000 ,train derror: inf, dev derror: 17.7787，train verror: inf, dev verror: 0.9081
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 3.0000 ,train loss: 0.9011, dev loss: 1.0809
# epoch 3.0000 ,train derror: inf, dev derror: 15.3056，train verror: inf, dev verror: 0.8322
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 4.0000 ,train loss: 0.6706, dev loss: 0.5982
# epoch 4.0000 ,train derror: inf, dev derror: 8.3532，train verror: inf, dev verror: 0.6148
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 5.0000 ,train loss: 0.5210, dev loss: 0.3686
# epoch 5.0000 ,train derror: inf, dev derror: 4.5686，train verror: inf, dev verror: 0.4753
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 6.0000 ,train loss: 0.4337, dev loss: 0.2703
# epoch 6.0000 ,train derror: inf, dev derror: 3.2407，train verror: inf, dev verror: 0.4006
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 7.0000 ,train loss: 0.3852, dev loss: 0.2101
# epoch 7.0000 ,train derror: inf, dev derror: 2.7998，train verror: inf, dev verror: 0.3467
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 8.0000 ,train loss: 0.3492, dev loss: 0.1692
# epoch 8.0000 ,train derror: inf, dev derror: 2.7599，train verror: inf, dev verror: 0.3049
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 9.0000 ,train loss: 0.3237, dev loss: 0.1422
# epoch 9.0000 ,train derror: inf, dev derror: 2.7942，train verror: inf, dev verror: 0.2740
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 10.0000 ,train loss: 0.2975, dev loss: 0.1251
# epoch 10.0000 ,train derror: inf, dev derror: 2.7876，train verror: inf, dev verror: 0.2530
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 11.0000 ,train loss: 0.3067, dev loss: 0.1108
# epoch 11.0000 ,train derror: inf, dev derror: 2.7908，train verror: inf, dev verror: 0.2341
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 12.0000 ,train loss: 0.2853, dev loss: 0.1011
# epoch 12.0000 ,train derror: inf, dev derror: 2.8050，train verror: inf, dev verror: 0.2206
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 13.0000 ,train loss: 0.3044, dev loss: 0.0942
# epoch 13.0000 ,train derror: inf, dev derror: 2.8535，train verror: inf, dev verror: 0.2108
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 14.0000 ,train loss: 0.2832, dev loss: 0.0888
# epoch 14.0000 ,train derror: inf, dev derror: 2.9539，train verror: inf, dev verror: 0.2028
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 15.0000 ,train loss: 0.2726, dev loss: 0.0851
# epoch 15.0000 ,train derror: inf, dev derror: 3.1032，train verror: inf, dev verror: 0.1973
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 16.0000 ,train loss: 0.2938, dev loss: 0.0811
# epoch 16.0000 ,train derror: inf, dev derror: 3.1929，train verror: inf, dev verror: 0.1912
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 17.0000 ,train loss: 0.2710, dev loss: 0.0777
# epoch 17.0000 ,train derror: inf, dev derror: 3.2868，train verror: inf, dev verror: 0.1860
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 18.0000 ,train loss: 0.2929, dev loss: 0.0743
# epoch 18.0000 ,train derror: inf, dev derror: 3.3614，train verror: inf, dev verror: 0.1804
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 19.0000 ,train loss: 0.2820, dev loss: 0.0713
# epoch 19.0000 ,train derror: inf, dev derror: 3.4756，train verror: inf, dev verror: 0.1757
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 20.0000 ,train loss: 0.2757, dev loss: 0.0697
# epoch 20.0000 ,train derror: inf, dev derror: 3.5781，train verror: inf, dev verror: 0.1732
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 21.0000 ,train loss: 0.2807, dev loss: 0.0681
# epoch 21.0000 ,train derror: inf, dev derror: 3.6446，train verror: inf, dev verror: 0.1708
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 22.0000 ,train loss: 0.2572, dev loss: 0.0697
# epoch 22.0000 ,train derror: inf, dev derror: 3.8491，train verror: inf, dev verror: 0.1736
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 23.0000 ,train loss: 0.2744, dev loss: 0.0675
# epoch 23.0000 ,train derror: inf, dev derror: 3.8045，train verror: inf, dev verror: 0.1701
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 24.0000 ,train loss: 0.2690, dev loss: 0.0671
# epoch 24.0000 ,train derror: inf, dev derror: 3.9113，train verror: inf, dev verror: 0.1695
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 25.0000 ,train loss: 0.2812, dev loss: 0.0659
# epoch 25.0000 ,train derror: inf, dev derror: 3.9634，train verror: inf, dev verror: 0.1675
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 26.0000 ,train loss: 0.2672, dev loss: 0.0664
# epoch 26.0000 ,train derror: inf, dev derror: 4.0429，train verror: inf, dev verror: 0.1686
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 27.0000 ,train loss: 0.2619, dev loss: 0.0645
# epoch 27.0000 ,train derror: inf, dev derror: 4.0299，train verror: inf, dev verror: 0.1655
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 28.0000 ,train loss: 0.2729, dev loss: 0.0637
# epoch 28.0000 ,train derror: inf, dev derror: 4.0465，train verror: inf, dev verror: 0.1641
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 29.0000 ,train loss: 0.2871, dev loss: 0.0615
# epoch 29.0000 ,train derror: inf, dev derror: 3.9702，train verror: inf, dev verror: 0.1603
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 30.0000 ,train loss: 0.2904, dev loss: 0.0594
# epoch 30.0000 ,train derror: inf, dev derror: 3.9337，train verror: inf, dev verror: 0.1568
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 31.0000 ,train loss: 0.2613, dev loss: 0.0599
# epoch 31.0000 ,train derror: inf, dev derror: 3.9748，train verror: inf, dev verror: 0.1577
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 32.0000 ,train loss: 0.2735, dev loss: 0.0595
# epoch 32.0000 ,train derror: inf, dev derror: 3.9854，train verror: inf, dev verror: 0.1570
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 33.0000 ,train loss: 0.2500, dev loss: 0.0594
# epoch 33.0000 ,train derror: inf, dev derror: 3.9712，train verror: inf, dev verror: 0.1571
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 34.0000 ,train loss: 0.2512, dev loss: 0.0593
# epoch 34.0000 ,train derror: inf, dev derror: 3.9758，train verror: inf, dev verror: 0.1571
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 35.0000 ,train loss: 0.2565, dev loss: 0.0581
# epoch 35.0000 ,train derror: inf, dev derror: 3.9374，train verror: inf, dev verror: 0.1551
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 36.0000 ,train loss: 0.2832, dev loss: 0.0571
# epoch 36.0000 ,train derror: inf, dev derror: 3.9282，train verror: inf, dev verror: 0.1533
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 37.0000 ,train loss: 0.2516, dev loss: 0.0565
# epoch 37.0000 ,train derror: inf, dev derror: 3.9032，train verror: inf, dev verror: 0.1524
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 38.0000 ,train loss: 0.2682, dev loss: 0.0562
# epoch 38.0000 ,train derror: inf, dev derror: 3.9133，train verror: inf, dev verror: 0.1520
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 39.0000 ,train loss: 0.2758, dev loss: 0.0555
# epoch 39.0000 ,train derror: inf, dev derror: 3.8701，train verror: inf, dev verror: 0.1509
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 40.0000 ,train loss: 0.2616, dev loss: 0.0550
# epoch 40.0000 ,train derror: inf, dev derror: 3.8354，train verror: inf, dev verror: 0.1500
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 41.0000 ,train loss: 0.2500, dev loss: 0.0566
# epoch 41.0000 ,train derror: inf, dev derror: 3.8979，train verror: inf, dev verror: 0.1533
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 42.0000 ,train loss: 0.2764, dev loss: 0.0536
# epoch 42.0000 ,train derror: inf, dev derror: 3.6883，train verror: inf, dev verror: 0.1480
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 43.0000 ,train loss: 0.2424, dev loss: 0.0546
# epoch 43.0000 ,train derror: inf, dev derror: 3.7562，train verror: inf, dev verror: 0.1500
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 44.0000 ,train loss: 0.2283, dev loss: 0.0557
# epoch 44.0000 ,train derror: inf, dev derror: 3.8097，train verror: inf, dev verror: 0.1524
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 45.0000 ,train loss: 0.2435, dev loss: 0.0552
# epoch 45.0000 ,train derror: inf, dev derror: 3.7908，train verror: inf, dev verror: 0.1514
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 46.0000 ,train loss: 0.2480, dev loss: 0.0542
# epoch 46.0000 ,train derror: inf, dev derror: 3.8065，train verror: inf, dev verror: 0.1497
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 47.0000 ,train loss: 0.2466, dev loss: 0.0542
# epoch 47.0000 ,train derror: inf, dev derror: 3.7269，train verror: inf, dev verror: 0.1498
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 48.0000 ,train loss: 0.2320, dev loss: 0.0551
# epoch 48.0000 ,train derror: inf, dev derror: 3.8082，train verror: inf, dev verror: 0.1515
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 49.0000 ,train loss: 0.2449, dev loss: 0.0556
# epoch 49.0000 ,train derror: inf, dev derror: 3.8878，train verror: inf, dev verror: 0.1527
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 50.0000 ,train loss: 0.2532, dev loss: 0.0542
# epoch 50.0000 ,train derror: inf, dev derror: 3.7698，train verror: inf, dev verror: 0.1503
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 51.0000 ,train loss: 0.2493, dev loss: 0.0523
# epoch 51.0000 ,train derror: inf, dev derror: 3.6131，train verror: inf, dev verror: 0.1468
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 52.0000 ,train loss: 0.2578, dev loss: 0.0524
# epoch 52.0000 ,train derror: inf, dev derror: 3.6514，train verror: inf, dev verror: 0.1472
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 53.0000 ,train loss: 0.2591, dev loss: 0.0530
# epoch 53.0000 ,train derror: inf, dev derror: 3.7114，train verror: inf, dev verror: 0.1483
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 54.0000 ,train loss: 0.2411, dev loss: 0.0535
# epoch 54.0000 ,train derror: inf, dev derror: 3.7549，train verror: inf, dev verror: 0.1493
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 55.0000 ,train loss: 0.2554, dev loss: 0.0529
# epoch 55.0000 ,train derror: inf, dev derror: 3.7062，train verror: inf, dev verror: 0.1484
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 56.0000 ,train loss: 0.2685, dev loss: 0.0515
# epoch 56.0000 ,train derror: inf, dev derror: 3.5973，train verror: inf, dev verror: 0.1458
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 57.0000 ,train loss: 0.2741, dev loss: 0.0504
# epoch 57.0000 ,train derror: inf, dev derror: 3.5133，train verror: inf, dev verror: 0.1439
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 58.0000 ,train loss: 0.2494, dev loss: 0.0541
# epoch 58.0000 ,train derror: inf, dev derror: 3.7015，train verror: inf, dev verror: 0.1512
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 59.0000 ,train loss: 0.2542, dev loss: 0.0528
# epoch 59.0000 ,train derror: inf, dev derror: 3.6064，train verror: inf, dev verror: 0.1489
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 60.0000 ,train loss: 0.2425, dev loss: 0.0511
# epoch 60.0000 ,train derror: inf, dev derror: 3.4570，train verror: inf, dev verror: 0.1457
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 61.0000 ,train loss: 0.2526, dev loss: 0.0517
# epoch 61.0000 ,train derror: inf, dev derror: 3.5010，train verror: inf, dev verror: 0.1468
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 62.0000 ,train loss: 0.2494, dev loss: 0.0512
# epoch 62.0000 ,train derror: inf, dev derror: 3.4856，train verror: inf, dev verror: 0.1461
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 63.0000 ,train loss: 0.2590, dev loss: 0.0503
# epoch 63.0000 ,train derror: inf, dev derror: 3.3891，train verror: inf, dev verror: 0.1444
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 64.0000 ,train loss: 0.2494, dev loss: 0.0504
# epoch 64.0000 ,train derror: inf, dev derror: 3.4123，train verror: inf, dev verror: 0.1446
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 65.0000 ,train loss: 0.2409, dev loss: 0.0509
# epoch 65.0000 ,train derror: inf, dev derror: 3.4326，train verror: inf, dev verror: 0.1458
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 66.0000 ,train loss: 0.2547, dev loss: 0.0496
# epoch 66.0000 ,train derror: inf, dev derror: 3.3889，train verror: inf, dev verror: 0.1433
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 67.0000 ,train loss: 0.2582, dev loss: 0.0508
# epoch 67.0000 ,train derror: inf, dev derror: 3.4902，train verror: inf, dev verror: 0.1456
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 68.0000 ,train loss: 0.2512, dev loss: 0.0491
# epoch 68.0000 ,train derror: inf, dev derror: 3.3691，train verror: inf, dev verror: 0.1423
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 69.0000 ,train loss: 0.2517, dev loss: 0.0484
# epoch 69.0000 ,train derror: inf, dev derror: 3.3346，train verror: inf, dev verror: 0.1409
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 70.0000 ,train loss: 0.2422, dev loss: 0.0481
# epoch 70.0000 ,train derror: inf, dev derror: 3.3387，train verror: inf, dev verror: 0.1405
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 71.0000 ,train loss: 0.2358, dev loss: 0.0492
# epoch 71.0000 ,train derror: inf, dev derror: 3.3996，train verror: inf, dev verror: 0.1426
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 72.0000 ,train loss: 0.2384, dev loss: 0.0490
# epoch 72.0000 ,train derror: inf, dev derror: 3.3721，train verror: inf, dev verror: 0.1424
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 73.0000 ,train loss: 0.2661, dev loss: 0.0476
# epoch 73.0000 ,train derror: inf, dev derror: 3.2802，train verror: inf, dev verror: 0.1395
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 74.0000 ,train loss: 0.2461, dev loss: 0.0475
# epoch 74.0000 ,train derror: inf, dev derror: 3.2221，train verror: inf, dev verror: 0.1395
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 75.0000 ,train loss: 0.2355, dev loss: 0.0487
# epoch 75.0000 ,train derror: inf, dev derror: 3.2862，train verror: inf, dev verror: 0.1420
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 76.0000 ,train loss: 0.2582, dev loss: 0.0494
# epoch 76.0000 ,train derror: inf, dev derror: 3.3900，train verror: inf, dev verror: 0.1434
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 77.0000 ,train loss: 0.2533, dev loss: 0.0494
# epoch 77.0000 ,train derror: inf, dev derror: 3.3597，train verror: inf, dev verror: 0.1436
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 78.0000 ,train loss: 0.2506, dev loss: 0.0507
# epoch 78.0000 ,train derror: inf, dev derror: 3.4183，train verror: inf, dev verror: 0.1460
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 79.0000 ,train loss: 0.2572, dev loss: 0.0500
# epoch 79.0000 ,train derror: inf, dev derror: 3.4334，train verror: inf, dev verror: 0.1449
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 80.0000 ,train loss: 0.2443, dev loss: 0.0503
# epoch 80.0000 ,train derror: inf, dev derror: 3.4273，train verror: inf, dev verror: 0.1455
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 81.0000 ,train loss: 0.2643, dev loss: 0.0491
# epoch 81.0000 ,train derror: inf, dev derror: 3.3770，train verror: inf, dev verror: 0.1430
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 82.0000 ,train loss: 0.2511, dev loss: 0.0486
# epoch 82.0000 ,train derror: inf, dev derror: 3.3474，train verror: inf, dev verror: 0.1420
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 83.0000 ,train loss: 0.2436, dev loss: 0.0490
# epoch 83.0000 ,train derror: inf, dev derror: 3.3309，train verror: inf, dev verror: 0.1430
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 84.0000 ,train loss: 0.2313, dev loss: 0.0493
# epoch 84.0000 ,train derror: inf, dev derror: 3.3239，train verror: inf, dev verror: 0.1437
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 85.0000 ,train loss: 0.2462, dev loss: 0.0477
# epoch 85.0000 ,train derror: inf, dev derror: 3.1729，train verror: inf, dev verror: 0.1406
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 86.0000 ,train loss: 0.2618, dev loss: 0.0480
# epoch 86.0000 ,train derror: inf, dev derror: 3.2100，train verror: inf, dev verror: 0.1410
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 87.0000 ,train loss: 0.2456, dev loss: 0.0480
# epoch 87.0000 ,train derror: inf, dev derror: 3.2094，train verror: inf, dev verror: 0.1410
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 88.0000 ,train loss: 0.2299, dev loss: 0.0491
# epoch 88.0000 ,train derror: inf, dev derror: 3.2825，train verror: inf, dev verror: 0.1432
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 89.0000 ,train loss: 0.2260, dev loss: 0.0508
# epoch 89.0000 ,train derror: inf, dev derror: 3.3399，train verror: inf, dev verror: 0.1466
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 90.0000 ,train loss: 0.2389, dev loss: 0.0512
# epoch 90.0000 ,train derror: inf, dev derror: 3.3407，train verror: inf, dev verror: 0.1473
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 91.0000 ,train loss: 0.2472, dev loss: 0.0517
# epoch 91.0000 ,train derror: inf, dev derror: 3.4082，train verror: inf, dev verror: 0.1483
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 92.0000 ,train loss: 0.2325, dev loss: 0.0509
# epoch 92.0000 ,train derror: inf, dev derror: 3.3521，train verror: inf, dev verror: 0.1469
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 93.0000 ,train loss: 0.2544, dev loss: 0.0488
# epoch 93.0000 ,train derror: inf, dev derror: 3.2103，train verror: inf, dev verror: 0.1429
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 94.0000 ,train loss: 0.2432, dev loss: 0.0462
# epoch 94.0000 ,train derror: inf, dev derror: 3.0184，train verror: inf, dev verror: 0.1377
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 95.0000 ,train loss: 0.2319, dev loss: 0.0479
# epoch 95.0000 ,train derror: inf, dev derror: 3.0915，train verror: inf, dev verror: 0.1412
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 96.0000 ,train loss: 0.2353, dev loss: 0.0510
# epoch 96.0000 ,train derror: inf, dev derror: 3.2574，train verror: inf, dev verror: 0.1473
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 97.0000 ,train loss: 0.2463, dev loss: 0.0495
# epoch 97.0000 ,train derror: inf, dev derror: 3.1989，train verror: inf, dev verror: 0.1444
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 98.0000 ,train loss: 0.2462, dev loss: 0.0482
# epoch 98.0000 ,train derror: inf, dev derror: 3.1428，train verror: inf, dev verror: 0.1418
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 99.0000 ,train loss: 0.2372, dev loss: 0.0469
# epoch 99.0000 ,train derror: inf, dev derror: 3.0300，train verror: inf, dev verror: 0.1393
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 100.0000 ,train loss: 0.2384, dev loss: 0.0473
# epoch 100.0000 ,train derror: inf, dev derror: 3.0231，train verror: inf, dev verror: 0.1404
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 101.0000 ,train loss: 0.2499, dev loss: 0.0474
# epoch 101.0000 ,train derror: inf, dev derror: 3.0306，train verror: inf, dev verror: 0.1404
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 102.0000 ,train loss: 0.2326, dev loss: 0.0484
# epoch 102.0000 ,train derror: inf, dev derror: 3.0817，train verror: inf, dev verror: 0.1423
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 103.0000 ,train loss: 0.2470, dev loss: 0.0486
# epoch 103.0000 ,train derror: inf, dev derror: 3.1092，train verror: inf, dev verror: 0.1427
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 104.0000 ,train loss: 0.2379, dev loss: 0.0494
# epoch 104.0000 ,train derror: inf, dev derror: 3.1361，train verror: inf, dev verror: 0.1445
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 105.0000 ,train loss: 0.2273, dev loss: 0.0490
# epoch 105.0000 ,train derror: inf, dev derror: 3.0986，train verror: inf, dev verror: 0.1437
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 106.0000 ,train loss: 0.2486, dev loss: 0.0497
# epoch 106.0000 ,train derror: inf, dev derror: 3.1330，train verror: inf, dev verror: 0.1451
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 107.0000 ,train loss: 0.2369, dev loss: 0.0490
# epoch 107.0000 ,train derror: inf, dev derror: 3.1687，train verror: inf, dev verror: 0.1436
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 108.0000 ,train loss: 0.2359, dev loss: 0.0470
# epoch 108.0000 ,train derror: inf, dev derror: 3.0865，train verror: inf, dev verror: 0.1395
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 109.0000 ,train loss: 0.2503, dev loss: 0.0480
# epoch 109.0000 ,train derror: inf, dev derror: 3.1136，train verror: inf, dev verror: 0.1415
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 110.0000 ,train loss: 0.2445, dev loss: 0.0481
# epoch 110.0000 ,train derror: inf, dev derror: 3.0751，train verror: inf, dev verror: 0.1421
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 111.0000 ,train loss: 0.2513, dev loss: 0.0457
# epoch 111.0000 ,train derror: inf, dev derror: 2.9040，train verror: inf, dev verror: 0.1371
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 112.0000 ,train loss: 0.2421, dev loss: 0.0450
# epoch 112.0000 ,train derror: inf, dev derror: 2.9116，train verror: inf, dev verror: 0.1355
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 113.0000 ,train loss: 0.2599, dev loss: 0.0446
# epoch 113.0000 ,train derror: inf, dev derror: 2.9265，train verror: inf, dev verror: 0.1348
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 114.0000 ,train loss: 0.2270, dev loss: 0.0454
# epoch 114.0000 ,train derror: inf, dev derror: 2.9662，train verror: inf, dev verror: 0.1365
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 115.0000 ,train loss: 0.2302, dev loss: 0.0465
# epoch 115.0000 ,train derror: inf, dev derror: 3.0045，train verror: inf, dev verror: 0.1388
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 116.0000 ,train loss: 0.2533, dev loss: 0.0461
# epoch 116.0000 ,train derror: inf, dev derror: 2.9613，train verror: inf, dev verror: 0.1380
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 117.0000 ,train loss: 0.2573, dev loss: 0.0461
# epoch 117.0000 ,train derror: inf, dev derror: 2.9909，train verror: inf, dev verror: 0.1380
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 118.0000 ,train loss: 0.2414, dev loss: 0.0471
# epoch 118.0000 ,train derror: inf, dev derror: 3.0383，train verror: inf, dev verror: 0.1401
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 119.0000 ,train loss: 0.2312, dev loss: 0.0477
# epoch 119.0000 ,train derror: inf, dev derror: 3.0735，train verror: inf, dev verror: 0.1414
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 120.0000 ,train loss: 0.2518, dev loss: 0.0466
# epoch 120.0000 ,train derror: inf, dev derror: 2.9526，train verror: inf, dev verror: 0.1392
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 121.0000 ,train loss: 0.2394, dev loss: 0.0456
# epoch 121.0000 ,train derror: inf, dev derror: 2.8960，train verror: inf, dev verror: 0.1372
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 122.0000 ,train loss: 0.2327, dev loss: 0.0454
# epoch 122.0000 ,train derror: inf, dev derror: 2.8952，train verror: inf, dev verror: 0.1368
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 123.0000 ,train loss: 0.2449, dev loss: 0.0445
# epoch 123.0000 ,train derror: inf, dev derror: 2.8543，train verror: inf, dev verror: 0.1350
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 124.0000 ,train loss: 0.2538, dev loss: 0.0451
# epoch 124.0000 ,train derror: inf, dev derror: 2.9520，train verror: inf, dev verror: 0.1360
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 125.0000 ,train loss: 0.2467, dev loss: 0.0465
# epoch 125.0000 ,train derror: inf, dev derror: 3.0452，train verror: inf, dev verror: 0.1389
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 126.0000 ,train loss: 0.2417, dev loss: 0.0480
# epoch 126.0000 ,train derror: inf, dev derror: 3.1686，train verror: inf, dev verror: 0.1421
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 127.0000 ,train loss: 0.2310, dev loss: 0.0468
# epoch 127.0000 ,train derror: inf, dev derror: 3.0636，train verror: inf, dev verror: 0.1397
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 128.0000 ,train loss: 0.2406, dev loss: 0.0458
# epoch 128.0000 ,train derror: inf, dev derror: 3.0039，train verror: inf, dev verror: 0.1377
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 129.0000 ,train loss: 0.2625, dev loss: 0.0462
# epoch 129.0000 ,train derror: inf, dev derror: 3.0625，train verror: inf, dev verror: 0.1385
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 130.0000 ,train loss: 0.2244, dev loss: 0.0471
# epoch 130.0000 ,train derror: inf, dev derror: 3.1557，train verror: inf, dev verror: 0.1403
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 131.0000 ,train loss: 0.2254, dev loss: 0.0471
# epoch 131.0000 ,train derror: inf, dev derror: 3.1258，train verror: inf, dev verror: 0.1403
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 132.0000 ,train loss: 0.2428, dev loss: 0.0455
# epoch 132.0000 ,train derror: inf, dev derror: 2.9795，train verror: inf, dev verror: 0.1373
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 133.0000 ,train loss: 0.2318, dev loss: 0.0473
# epoch 133.0000 ,train derror: inf, dev derror: 3.0686，train verror: inf, dev verror: 0.1412
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 134.0000 ,train loss: 0.2286, dev loss: 0.0478
# epoch 134.0000 ,train derror: inf, dev derror: 3.1328，train verror: inf, dev verror: 0.1420
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 135.0000 ,train loss: 0.2330, dev loss: 0.0466
# epoch 135.0000 ,train derror: inf, dev derror: 3.0333，train verror: inf, dev verror: 0.1396
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 136.0000 ,train loss: 0.2279, dev loss: 0.0477
# epoch 136.0000 ,train derror: inf, dev derror: 3.1035，train verror: inf, dev verror: 0.1419
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 137.0000 ,train loss: 0.2573, dev loss: 0.0457
# epoch 137.0000 ,train derror: inf, dev derror: 2.9983，train verror: inf, dev verror: 0.1377
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 138.0000 ,train loss: 0.2470, dev loss: 0.0453
# epoch 138.0000 ,train derror: inf, dev derror: 2.9851，train verror: inf, dev verror: 0.1369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 139.0000 ,train loss: 0.2436, dev loss: 0.0453
# epoch 139.0000 ,train derror: inf, dev derror: 2.9832，train verror: inf, dev verror: 0.1368
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 140.0000 ,train loss: 0.2375, dev loss: 0.0444
# epoch 140.0000 ,train derror: inf, dev derror: 2.9476，train verror: inf, dev verror: 0.1348
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 141.0000 ,train loss: 0.2364, dev loss: 0.0456
# epoch 141.0000 ,train derror: inf, dev derror: 3.0440，train verror: inf, dev verror: 0.1373
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 142.0000 ,train loss: 0.2353, dev loss: 0.0460
# epoch 142.0000 ,train derror: inf, dev derror: 3.0820，train verror: inf, dev verror: 0.1383
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 143.0000 ,train loss: 0.2411, dev loss: 0.0438
# epoch 143.0000 ,train derror: inf, dev derror: 2.9331，train verror: inf, dev verror: 0.1336
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 144.0000 ,train loss: 0.2347, dev loss: 0.0436
# epoch 144.0000 ,train derror: inf, dev derror: 2.9064，train verror: inf, dev verror: 0.1333
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 145.0000 ,train loss: 0.2505, dev loss: 0.0437
# epoch 145.0000 ,train derror: inf, dev derror: 2.9550，train verror: inf, dev verror: 0.1335
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 146.0000 ,train loss: 0.2635, dev loss: 0.0414
# epoch 146.0000 ,train derror: inf, dev derror: 2.8296，train verror: inf, dev verror: 0.1287
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 147.0000 ,train loss: 0.2315, dev loss: 0.0429
# epoch 147.0000 ,train derror: inf, dev derror: 2.9668，train verror: inf, dev verror: 0.1319
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 148.0000 ,train loss: 0.2321, dev loss: 0.0419
# epoch 148.0000 ,train derror: inf, dev derror: 2.9136，train verror: inf, dev verror: 0.1296
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 149.0000 ,train loss: 0.2444, dev loss: 0.0435
# epoch 149.0000 ,train derror: inf, dev derror: 3.0415，train verror: inf, dev verror: 0.1330
# -------------------------------------------------------------------------------------------------------------------------------------
