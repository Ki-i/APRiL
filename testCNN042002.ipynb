# %% [markdown]
# <a href="https://colab.research.google.com/github/Ki-i/APRiL/blob/master/testCNN042002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
workspace_dir = '.'
#!unzip -q "/content/drive/My Drive/crypko_data.zip" -d "{workspace_dir}/"

# %%
from torch.nn import Module
from torch import nn
import numpy as np
import math
import torch
from torch.nn import CrossEntropyLoss
from torch.nn import MSELoss
from torch.optim import SGD
from torch.utils.data import DataLoader, TensorDataset
import os
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import matplotlib.pyplot as plt
import sys
import scipy.io as scio
import pylab

# %%
class DnCNN(nn.Module):
    def __init__(self):
        super(DnCNN, self).__init__()
        channels=3
        num_of_layers=10
        kernel_size = 3
        padding = 1
        features = 64
        layers = []
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))
        for _ in range(num_of_layers-2):
            layers.append(nn.Conv2d(in_channels=features, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
            layers.append(nn.BatchNorm2d(features))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False))
 
        self.dncnn = nn.Sequential(*layers)
        self.fc1=nn.Linear( 3*50*100,6)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(6,6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练
    def forward(self, x):
        y = self.dncnn(x)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu(y)
        y = self.fc2(y)
       
        return y

# %%
class Model(Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(2, 32, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)
        self.conv3 = nn.Conv2d(64, 64, 5)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(64*2*9, 64)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(64, 6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练

    def forward(self, x):
        y = self.conv1(x)
        y = self.relu1(y)
        y = self.pool1(y)
        y = self.conv2(y)
        y = self.relu2(y)
        y = self.pool2(y)
        y = self.conv3(y)
        y = self.relu3(y)
        y = self.pool3(y)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu3(y)
        y = self.fc2(y)
        # y = self.relu4(y)
        # y = self.fc3(y)
        # y = self.relu5(y)
        return y

# %%
def get_data(dataset_path, fm, dev_ratio):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    #datalen = int(len(x_data) / 3)
    datalen=5000
    x = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str(i)
        #print(xkey)
        x[i] = data[xkey]
        
        ykey = 'y' + str(i)
        y[i] = data[ykey]#噪声
        #if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])
        

    data_size = len(y)
    train_size = int(data_size * (1 - dev_ratio))
    state = np.random.get_state()
    np.random.shuffle(x)
    np.random.set_state(state)
    np.random.shuffle(y)
    # print("train size:", train_size)
    # print("dev size:", data_size - train_size)
    x_train = x[:train_size]
    y_train = y[:train_size]
    x_dev = x[train_size:]
    y_dev = y[train_size:]
    return x_train, y_train, x_dev, y_dev

# %%
class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x, self.y = x, y
        self.data_size = len(self.y)
        #norm_mean = [0.485, 0.456, 0.406]
        #norm_std = [0.229, 0.224, 0.225]
        self.img_transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.ToTensor(),
            # transforms.Normalize(norm_mean, norm_std),
        ])

    def __len__(self):
        return self.data_size

    def __getitem__(self, item):
        '''
        这个函数是关键，通过item(索引)来取数据集中的数据，
        一般来说在这里才将图像数据加载入内存，之前存的是图像的保存路径
        '''
        ycut=self.y[item]
        #ycut=ycut[101:-6:400,1:-5:500]

        label = torch.from_numpy(ycut)
        #label = torch.reshape(label, (1, -1))
        xcut = self.x[item]
        #xcut = xcut[101:-6:400,1:-5:500]
        x = torch.from_numpy(xcut)
        #x=x.unsqueeze(0)
        #label=label.squeeze(0)
        x=x.float()
        label=label.float()
        x = torch.div(x, 255.)
        label = torch.div(label, 10000.)
        #print(x.size())
        #print(label.size())
        #label=torch.div(label, 255.)
        return x, label

# %%
x=np.array([1,2,3,4])
x=x/4
print(x)
# Out:
# [0.25 0.5  0.75 1.  ]

# %%
def psnr(target_data, ref_data):
    # target:目标图像  ref:参考图像  scale:尺寸大小
    # assume RGB image
    #target_data = np.array(target)
    #target_data = target_data[scale:-scale, scale:-scale]

    #ref_data = np.array(ref)
    #ref_data = ref_data[scale:-scale, scale:-scale]
    im = ref_data.max()
    print('参考图像峰值', ref_data.max(), ref_data.min())
    print('实际图像峰值', target_data.max(), target_data.min())
    target_data = target_data * (ref_data.max() / target_data.max())
    #print('实际图像峰值', target_data.max(), target_data.min())
    diff = ref_data - target_data
    diff = diff.flatten('C')

    #rmse = math.sqrt(np.mean(diff ** 2.))
    #return 20 * math.log10(math.pow(im,2) / rmse)
    mse = np.mean(diff ** 2.)
    return 20 * math.log10(math.pow(im,2) / mse)

def ab_err(target_data, ref_data):
  diff = abs(ref_data - target_data)/ref_data
  diff=diff.cpu().data.numpy()
  tdiff=diff[0:,0:3]
  vdiff=diff[0:,3:6]
  #print(np.shape(tdiff))
  #print(np.shape(vdiff))
  num=0
  for i in range(1,len(diff)):
    for j in range(1,3):
      if (tdiff[i-1,j-1]<0.2) & (vdiff[i-1,j-1]<0.2):
        num=num+1
  terr = np.mean(tdiff)
  verr = np.mean(vdiff)
  acc = num/(3*np.shape(tdiff)[0])
  return terr,verr,acc

# %%
if __name__ == '__main__':

    batch_size = 32
    lr=1e-3
    #lr=1e-4#loss:11.72 10.74
    #lr=1e-3#9.6519
    #lr=0.01#8.3690
    #lr=0.1#8.2 7.72 7.71 ..7156.7147
    log_dir='/content/drive/My Drive/model.pth'
    #数据集加载
    dataset_path = '/content/drive/My Drive/'
    x_train, y_train, x_dev, y_dev = get_data(dataset_path, 'TrainData_MutiSNRnoMPI.mat', 0.2)
    #print(x_train[0])
    train_dataset = MyDataset(x_train, y_train)
    train_loader = DataLoader(train_dataset, batch_size=batch_size)
    dev_dataset = MyDataset(x_dev, y_dev)
    dev_loader = DataLoader(train_dataset, batch_size=batch_size)

    model = DnCNN()
    #model = Model()
    #模型加载
    start_epoch=0
    '''
    if os.path.exists(log_dir):
        checkpoint = torch.load(log_dir)
        model.load_state_dict(checkpoint['net'])
        start_epoch = checkpoint['epoch']
        print('加载 epoch {} 成功！'.format(start_epoch))
    else:
        start_epoch = 0
        print('无保存模型，将从头开始训练！')
    '''
    sgd = SGD(model.parameters(), lr)

    cost = CrossEntropyLoss()
    criterion = MSELoss(reduction='sum')
    epoch = 150
    use_GPU = True
    if use_GPU:
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")
    model.to(device)
    epoch_train_loss_list = []
    epoch_dev_loss_list = []
    epoch_train_acc_list = []
    epoch_dev_acc_list = []
    epoch_train_derror_list = []
    epoch_dev_derror_list = []
    epoch_train_verror_list = []
    epoch_dev_verror_list = []
    for _epoch in range(start_epoch+1,start_epoch+epoch):
        model.train()
        epoch_train_loss = 0
        epoch_dev_loss = 0
        epoch_train_acc = 0
        epoch_dev_acc = 0
        train_num=0
        dev_num = 0
        epoch_dev_derror=0
        epoch_dev_verror=0
        epoch_train_derror=0
        epoch_train_verror=0
        for idx, (train_x, train_label) in enumerate(train_loader):
            s = train_label.shape[0]
            sgd.zero_grad()
            #print(train_x.size())
            predict_y = model(train_x.to(device))

            loss = criterion(predict_y, train_label.to(device))/ (2 * len(train_x))
            terror,verror,acc=ab_err(predict_y,train_label.to(device))
            epoch_train_loss += loss.item()
            epoch_train_derror+=terror
            epoch_train_verror+=verror
            epoch_train_acc+=acc
            label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
            #acc = np.sum(label_pred == train_label.numpy())
            # print("batch Train acc:",acc / s)
            #epoch_train_acc += acc / s
            train_num+=1
            loss.backward()
            sgd.step()

        correct = 0
        _sum = 0
        model.eval()

        with torch.no_grad():
            for idx, (dev_x, dev_label) in enumerate(dev_loader):
                s = dev_label.shape[0]
                predict_y = model(dev_x.to(device))
                # print(predict_y[0], dev_label[0])
                loss = criterion(predict_y, train_label.to(device)) / (2 * len(train_x))
                terror,verror,acc=ab_err(predict_y,train_label.to(device))
                
                epoch_dev_derror+=terror
                epoch_dev_verror+=verror
                epoch_dev_acc+=acc
                epoch_dev_loss += loss.item()
                label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
                # print("------")
                # print(label_pred)
                # print(dev_label.numpy())
                # print("------")
                #acc = np.sum(label_pred == dev_label.numpy())
                #batch_acc=acc / s
                dev_num+=1
                # print("batch_acc::",batch_acc)
                #epoch_dev_acc += acc / s
                # print("devacc", acc);
        epoch_train_loss_list.append(epoch_train_loss / train_num)
        epoch_dev_loss_list.append(epoch_dev_loss / dev_num)
        epoch_train_derror_list.append(epoch_train_derror / train_num)
        epoch_dev_derror_list.append(epoch_dev_derror / dev_num)
        epoch_train_verror_list.append(epoch_train_verror / train_num)
        epoch_dev_verror_list.append(epoch_dev_verror / dev_num)
        epoch_train_acc_list.append(epoch_train_acc / train_num)
        epoch_dev_acc_list.append(epoch_dev_acc / dev_num)

        #epoch_train_acc_list.append(epoch_train_acc / dev_num)
        #epoch_dev_acc_list.append(epoch_dev_acc / dev_num)
        print('-------------------------------------------------------------------------------------------------------------------------------------')
        print("epoch {:.4f} ,train loss: {:.4f}, dev loss: {:.4f}".format(_epoch, epoch_train_loss / train_num, epoch_dev_loss / dev_num))
        print("epoch {:.4f} ,train derror: {:.4f}, dev derror: {:.4f}，train verror: {:.4f}, dev verror: {:.4f}".format(_epoch, epoch_train_derror / train_num, epoch_dev_derror / dev_num, epoch_train_verror / train_num, epoch_dev_verror / dev_num))
        print("epoch {:.4f} ,train acc: {:.4f}, dev acc: {:.4f}".format(_epoch, epoch_train_acc / train_num, epoch_dev_acc / dev_num))
        print('-------------------------------------------------------------------------------------------------------------------------------------')

    t = np.arange(1, len(epoch_train_loss_list) + 1)
    #模型保存
    
    state = {'net':model.state_dict(),  'epoch':epoch}
    torch.save(state, log_dir)

    plt.figure(figsize=(5,15))
    
    loss_plot = plt.subplot(3, 1, 1)
    plt.title('loss ')
    plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
    plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
    der_plot = plt.subplot(3, 1, 2)
    plt.title('distance error')
    plt.plot(t, epoch_train_derror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
    der_plot = plt.subplot(3, 1, 3)
    plt.title('Velocity error')
    plt.plot(t, epoch_train_verror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
    plt.show()
# Out:
# load data from path1: /content/drive/My Drive/
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 1.0000 ,train loss: 1.1858, dev loss: 0.3760
# epoch 1.0000 ,train derror: inf, dev derror: 2.8802，train verror: inf, dev verror: 0.2754
# epoch 1.0000 ,train acc: 0.0047, dev acc: 0.0031
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 2.0000 ,train loss: 0.8646, dev loss: 0.1617
# epoch 2.0000 ,train derror: inf, dev derror: 2.8592，train verror: inf, dev verror: 0.1681
# epoch 2.0000 ,train acc: 0.0054, dev acc: 0.0132
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 3.0000 ,train loss: 0.7524, dev loss: 0.0920
# epoch 3.0000 ,train derror: inf, dev derror: 2.2059，train verror: inf, dev verror: 0.1208
# epoch 3.0000 ,train acc: 0.0043, dev acc: 0.0253
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 4.0000 ,train loss: 0.6804, dev loss: 0.1514
# epoch 4.0000 ,train derror: inf, dev derror: 2.3024，train verror: inf, dev verror: 0.1639
# epoch 4.0000 ,train acc: 0.0031, dev acc: 0.0213
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 5.0000 ,train loss: 0.6288, dev loss: 0.1145
# epoch 5.0000 ,train derror: inf, dev derror: 1.9203，train verror: inf, dev verror: 0.1397
# epoch 5.0000 ,train acc: 0.0053, dev acc: 0.0330
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 6.0000 ,train loss: 0.5671, dev loss: 0.1086
# epoch 6.0000 ,train derror: inf, dev derror: 1.6585，train verror: inf, dev verror: 0.1351
# epoch 6.0000 ,train acc: 0.0043, dev acc: 0.0428
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 7.0000 ,train loss: 0.5410, dev loss: 0.1531
# epoch 7.0000 ,train derror: inf, dev derror: 1.9275，train verror: inf, dev verror: 0.1676
# epoch 7.0000 ,train acc: 0.0062, dev acc: 0.0347
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 8.0000 ,train loss: 0.5199, dev loss: 0.0752
# epoch 8.0000 ,train derror: inf, dev derror: 1.3421，train verror: inf, dev verror: 0.1068
# epoch 8.0000 ,train acc: 0.0067, dev acc: 0.0604
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 9.0000 ,train loss: 0.4663, dev loss: 0.0999
# epoch 9.0000 ,train derror: inf, dev derror: 1.3873，train verror: inf, dev verror: 0.1289
# epoch 9.0000 ,train acc: 0.0092, dev acc: 0.0563
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 10.0000 ,train loss: 0.4232, dev loss: 0.1121
# epoch 10.0000 ,train derror: inf, dev derror: 1.3871，train verror: inf, dev verror: 0.1381
# epoch 10.0000 ,train acc: 0.0106, dev acc: 0.0524
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 11.0000 ,train loss: 0.4095, dev loss: 0.0600
# epoch 11.0000 ,train derror: inf, dev derror: 1.1113，train verror: inf, dev verror: 0.0934
# epoch 11.0000 ,train acc: 0.0122, dev acc: 0.0757
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 12.0000 ,train loss: 0.4014, dev loss: 0.0708
# epoch 12.0000 ,train derror: inf, dev derror: 1.1970，train verror: inf, dev verror: 0.1040
# epoch 12.0000 ,train acc: 0.0158, dev acc: 0.0714
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 13.0000 ,train loss: 0.3797, dev loss: 0.0535
# epoch 13.0000 ,train derror: inf, dev derror: 1.0457，train verror: inf, dev verror: 0.0874
# epoch 13.0000 ,train acc: 0.0115, dev acc: 0.0689
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 14.0000 ,train loss: 0.3641, dev loss: 0.0575
# epoch 14.0000 ,train derror: inf, dev derror: 0.9631，train verror: inf, dev verror: 0.0915
# epoch 14.0000 ,train acc: 0.0160, dev acc: 0.0852
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 15.0000 ,train loss: 0.3358, dev loss: 0.0693
# epoch 15.0000 ,train derror: inf, dev derror: 1.0440，train verror: inf, dev verror: 0.1035
# epoch 15.0000 ,train acc: 0.0165, dev acc: 0.0915
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 16.0000 ,train loss: 0.3328, dev loss: 0.0905
# epoch 16.0000 ,train derror: inf, dev derror: 1.3320，train verror: inf, dev verror: 0.1220
# epoch 16.0000 ,train acc: 0.0181, dev acc: 0.0663
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 17.0000 ,train loss: 0.3239, dev loss: 0.0665
# epoch 17.0000 ,train derror: inf, dev derror: 0.9857，train verror: inf, dev verror: 0.1004
# epoch 17.0000 ,train acc: 0.0182, dev acc: 0.1059
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 18.0000 ,train loss: 0.2923, dev loss: 0.0547
# epoch 18.0000 ,train derror: inf, dev derror: 0.9018，train verror: inf, dev verror: 0.0889
# epoch 18.0000 ,train acc: 0.0184, dev acc: 0.1172
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 19.0000 ,train loss: 0.2918, dev loss: 0.0459
# epoch 19.0000 ,train derror: inf, dev derror: 0.8182，train verror: inf, dev verror: 0.0799
# epoch 19.0000 ,train acc: 0.0260, dev acc: 0.1248
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 20.0000 ,train loss: 0.2574, dev loss: 0.0587
# epoch 20.0000 ,train derror: inf, dev derror: 0.9513，train verror: inf, dev verror: 0.0932
# epoch 20.0000 ,train acc: 0.0248, dev acc: 0.1108
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 21.0000 ,train loss: 0.2656, dev loss: 0.0557
# epoch 21.0000 ,train derror: inf, dev derror: 0.9775，train verror: inf, dev verror: 0.0905
# epoch 21.0000 ,train acc: 0.0238, dev acc: 0.0989
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 22.0000 ,train loss: 0.2442, dev loss: 0.0549
# epoch 22.0000 ,train derror: inf, dev derror: 1.0582，train verror: inf, dev verror: 0.0890
# epoch 22.0000 ,train acc: 0.0333, dev acc: 0.0647
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 23.0000 ,train loss: 0.2349, dev loss: 0.0410
# epoch 23.0000 ,train derror: inf, dev derror: 0.7799，train verror: inf, dev verror: 0.0747
# epoch 23.0000 ,train acc: 0.0349, dev acc: 0.1267
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 24.0000 ,train loss: 0.2226, dev loss: 0.0495
# epoch 24.0000 ,train derror: inf, dev derror: 0.9293，train verror: inf, dev verror: 0.0837
# epoch 24.0000 ,train acc: 0.0310, dev acc: 0.0970
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 25.0000 ,train loss: 0.2138, dev loss: 0.0428
# epoch 25.0000 ,train derror: inf, dev derror: 0.8841，train verror: inf, dev verror: 0.0766
# epoch 25.0000 ,train acc: 0.0389, dev acc: 0.0923
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 26.0000 ,train loss: 0.2128, dev loss: 0.0467
# epoch 26.0000 ,train derror: inf, dev derror: 0.8584，train verror: inf, dev verror: 0.0806
# epoch 26.0000 ,train acc: 0.0332, dev acc: 0.1206
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 27.0000 ,train loss: 0.2062, dev loss: 0.0361
# epoch 27.0000 ,train derror: inf, dev derror: 0.7470，train verror: inf, dev verror: 0.0694
# epoch 27.0000 ,train acc: 0.0414, dev acc: 0.1313
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 28.0000 ,train loss: 0.1940, dev loss: 0.0416
# epoch 28.0000 ,train derror: inf, dev derror: 0.9135，train verror: inf, dev verror: 0.0754
# epoch 28.0000 ,train acc: 0.0512, dev acc: 0.0706
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 29.0000 ,train loss: 0.1769, dev loss: 0.0364
# epoch 29.0000 ,train derror: inf, dev derror: 0.7842，train verror: inf, dev verror: 0.0699
# epoch 29.0000 ,train acc: 0.0525, dev acc: 0.1089
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 30.0000 ,train loss: 0.1638, dev loss: 0.0297
# epoch 30.0000 ,train derror: inf, dev derror: 0.6398，train verror: inf, dev verror: 0.0624
# epoch 30.0000 ,train acc: 0.0485, dev acc: 0.1508
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 31.0000 ,train loss: 0.1665, dev loss: 0.0377
# epoch 31.0000 ,train derror: inf, dev derror: 0.8102，train verror: inf, dev verror: 0.0713
# epoch 31.0000 ,train acc: 0.0585, dev acc: 0.1015
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 32.0000 ,train loss: 0.1601, dev loss: 0.0334
# epoch 32.0000 ,train derror: inf, dev derror: 0.7222，train verror: inf, dev verror: 0.0670
# epoch 32.0000 ,train acc: 0.0616, dev acc: 0.1277
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 33.0000 ,train loss: 0.1570, dev loss: 0.0411
# epoch 33.0000 ,train derror: inf, dev derror: 0.8553，train verror: inf, dev verror: 0.0751
# epoch 33.0000 ,train acc: 0.0620, dev acc: 0.0958
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 34.0000 ,train loss: 0.1490, dev loss: 0.0373
# epoch 34.0000 ,train derror: inf, dev derror: 0.7521，train verror: inf, dev verror: 0.0709
# epoch 34.0000 ,train acc: 0.0683, dev acc: 0.1308
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 35.0000 ,train loss: 0.1337, dev loss: 0.0337
# epoch 35.0000 ,train derror: inf, dev derror: 0.7083，train verror: inf, dev verror: 0.0672
# epoch 35.0000 ,train acc: 0.0665, dev acc: 0.1338
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 36.0000 ,train loss: 0.1285, dev loss: 0.0330
# epoch 36.0000 ,train derror: inf, dev derror: 0.7248，train verror: inf, dev verror: 0.0664
# epoch 36.0000 ,train acc: 0.0791, dev acc: 0.1228
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 37.0000 ,train loss: 0.1310, dev loss: 0.0360
# epoch 37.0000 ,train derror: inf, dev derror: 0.7717，train verror: inf, dev verror: 0.0698
# epoch 37.0000 ,train acc: 0.0802, dev acc: 0.1103
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 38.0000 ,train loss: 0.1208, dev loss: 0.0317
# epoch 38.0000 ,train derror: inf, dev derror: 0.7466，train verror: inf, dev verror: 0.0651
# epoch 38.0000 ,train acc: 0.0798, dev acc: 0.1043
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 39.0000 ,train loss: 0.1198, dev loss: 0.0341
# epoch 39.0000 ,train derror: inf, dev derror: 0.7484，train verror: inf, dev verror: 0.0678
# epoch 39.0000 ,train acc: 0.0882, dev acc: 0.1155
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 40.0000 ,train loss: 0.1107, dev loss: 0.0337
# epoch 40.0000 ,train derror: inf, dev derror: 0.7385，train verror: inf, dev verror: 0.0674
# epoch 40.0000 ,train acc: 0.0848, dev acc: 0.1183
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 41.0000 ,train loss: 0.1064, dev loss: 0.0285
# epoch 41.0000 ,train derror: inf, dev derror: 0.6616，train verror: inf, dev verror: 0.0620
# epoch 41.0000 ,train acc: 0.0824, dev acc: 0.1303
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 42.0000 ,train loss: 0.0980, dev loss: 0.0306
# epoch 42.0000 ,train derror: inf, dev derror: 0.7023，train verror: inf, dev verror: 0.0638
# epoch 42.0000 ,train acc: 0.0907, dev acc: 0.1172
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 43.0000 ,train loss: 0.0989, dev loss: 0.0311
# epoch 43.0000 ,train derror: inf, dev derror: 0.6962，train verror: inf, dev verror: 0.0643
# epoch 43.0000 ,train acc: 0.0928, dev acc: 0.1255
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 44.0000 ,train loss: 0.0968, dev loss: 0.0326
# epoch 44.0000 ,train derror: inf, dev derror: 0.7263，train verror: inf, dev verror: 0.0660
# epoch 44.0000 ,train acc: 0.0897, dev acc: 0.1172
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 45.0000 ,train loss: 0.0949, dev loss: 0.0310
# epoch 45.0000 ,train derror: inf, dev derror: 0.7002，train verror: inf, dev verror: 0.0645
# epoch 45.0000 ,train acc: 0.0856, dev acc: 0.1247
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 46.0000 ,train loss: 0.0870, dev loss: 0.0305
# epoch 46.0000 ,train derror: inf, dev derror: 0.6828，train verror: inf, dev verror: 0.0640
# epoch 46.0000 ,train acc: 0.0949, dev acc: 0.1295
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 47.0000 ,train loss: 0.0812, dev loss: 0.0280
# epoch 47.0000 ,train derror: inf, dev derror: 0.6356，train verror: inf, dev verror: 0.0612
# epoch 47.0000 ,train acc: 0.0951, dev acc: 0.1427
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 48.0000 ,train loss: 0.0819, dev loss: 0.0278
# epoch 48.0000 ,train derror: inf, dev derror: 0.6348，train verror: inf, dev verror: 0.0608
# epoch 48.0000 ,train acc: 0.0943, dev acc: 0.1419
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 49.0000 ,train loss: 0.0760, dev loss: 0.0290
# epoch 49.0000 ,train derror: inf, dev derror: 0.6593，train verror: inf, dev verror: 0.0622
# epoch 49.0000 ,train acc: 0.0930, dev acc: 0.1313
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 50.0000 ,train loss: 0.0696, dev loss: 0.0267
# epoch 50.0000 ,train derror: inf, dev derror: 0.6117，train verror: inf, dev verror: 0.0599
# epoch 50.0000 ,train acc: 0.0932, dev acc: 0.1452
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 51.0000 ,train loss: 0.0706, dev loss: 0.0260
# epoch 51.0000 ,train derror: inf, dev derror: 0.5950，train verror: inf, dev verror: 0.0593
# epoch 51.0000 ,train acc: 0.0988, dev acc: 0.1496
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 52.0000 ,train loss: 0.0687, dev loss: 0.0265
# epoch 52.0000 ,train derror: inf, dev derror: 0.6025，train verror: inf, dev verror: 0.0600
# epoch 52.0000 ,train acc: 0.0931, dev acc: 0.1477
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 53.0000 ,train loss: 0.0661, dev loss: 0.0253
# epoch 53.0000 ,train derror: inf, dev derror: 0.5792，train verror: inf, dev verror: 0.0584
# epoch 53.0000 ,train acc: 0.1020, dev acc: 0.1561
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 54.0000 ,train loss: 0.0613, dev loss: 0.0269
# epoch 54.0000 ,train derror: inf, dev derror: 0.6077，train verror: inf, dev verror: 0.0605
# epoch 54.0000 ,train acc: 0.1002, dev acc: 0.1486
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 55.0000 ,train loss: 0.0593, dev loss: 0.0263
# epoch 55.0000 ,train derror: inf, dev derror: 0.5995，train verror: inf, dev verror: 0.0595
# epoch 55.0000 ,train acc: 0.0973, dev acc: 0.1502
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 56.0000 ,train loss: 0.0571, dev loss: 0.0243
# epoch 56.0000 ,train derror: inf, dev derror: 0.5471，train verror: inf, dev verror: 0.0578
# epoch 56.0000 ,train acc: 0.0979, dev acc: 0.1621
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 57.0000 ,train loss: 0.0534, dev loss: 0.0250
# epoch 57.0000 ,train derror: inf, dev derror: 0.5647，train verror: inf, dev verror: 0.0585
# epoch 57.0000 ,train acc: 0.1042, dev acc: 0.1593
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 58.0000 ,train loss: 0.0535, dev loss: 0.0259
# epoch 58.0000 ,train derror: inf, dev derror: 0.5805，train verror: inf, dev verror: 0.0593
# epoch 58.0000 ,train acc: 0.0986, dev acc: 0.1580
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 59.0000 ,train loss: 0.0508, dev loss: 0.0242
# epoch 59.0000 ,train derror: inf, dev derror: 0.5437，train verror: inf, dev verror: 0.0573
# epoch 59.0000 ,train acc: 0.0963, dev acc: 0.1687
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 60.0000 ,train loss: 0.0478, dev loss: 0.0233
# epoch 60.0000 ,train derror: inf, dev derror: 0.5110，train verror: inf, dev verror: 0.0567
# epoch 60.0000 ,train acc: 0.0953, dev acc: 0.1802
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 61.0000 ,train loss: 0.0469, dev loss: 0.0236
# epoch 61.0000 ,train derror: inf, dev derror: 0.5150，train verror: inf, dev verror: 0.0573
# epoch 61.0000 ,train acc: 0.1000, dev acc: 0.1771
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 62.0000 ,train loss: 0.0467, dev loss: 0.0234
# epoch 62.0000 ,train derror: inf, dev derror: 0.5158，train verror: inf, dev verror: 0.0567
# epoch 62.0000 ,train acc: 0.1022, dev acc: 0.1788
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 63.0000 ,train loss: 0.0428, dev loss: 0.0239
# epoch 63.0000 ,train derror: inf, dev derror: 0.5255，train verror: inf, dev verror: 0.0572
# epoch 63.0000 ,train acc: 0.1063, dev acc: 0.1752
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 64.0000 ,train loss: 0.0414, dev loss: 0.0239
# epoch 64.0000 ,train derror: inf, dev derror: 0.5228，train verror: inf, dev verror: 0.0576
# epoch 64.0000 ,train acc: 0.1026, dev acc: 0.1775
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 65.0000 ,train loss: 0.0387, dev loss: 0.0223
# epoch 65.0000 ,train derror: inf, dev derror: 0.4849，train verror: inf, dev verror: 0.0557
# epoch 65.0000 ,train acc: 0.1047, dev acc: 0.1821
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 66.0000 ,train loss: 0.0388, dev loss: 0.0226
# epoch 66.0000 ,train derror: inf, dev derror: 0.4836，train verror: inf, dev verror: 0.0565
# epoch 66.0000 ,train acc: 0.1031, dev acc: 0.1830
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 67.0000 ,train loss: 0.0377, dev loss: 0.0228
# epoch 67.0000 ,train derror: inf, dev derror: 0.4954，train verror: inf, dev verror: 0.0563
# epoch 67.0000 ,train acc: 0.1016, dev acc: 0.1841
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 68.0000 ,train loss: 0.0359, dev loss: 0.0226
# epoch 68.0000 ,train derror: inf, dev derror: 0.4890，train verror: inf, dev verror: 0.0557
# epoch 68.0000 ,train acc: 0.0965, dev acc: 0.1861
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 69.0000 ,train loss: 0.0343, dev loss: 0.0229
# epoch 69.0000 ,train derror: inf, dev derror: 0.4852，train verror: inf, dev verror: 0.0565
# epoch 69.0000 ,train acc: 0.1010, dev acc: 0.1849
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 70.0000 ,train loss: 0.0324, dev loss: 0.0229
# epoch 70.0000 ,train derror: inf, dev derror: 0.4904，train verror: inf, dev verror: 0.0565
# epoch 70.0000 ,train acc: 0.1022, dev acc: 0.1837
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 71.0000 ,train loss: 0.0316, dev loss: 0.0231
# epoch 71.0000 ,train derror: inf, dev derror: 0.4884，train verror: inf, dev verror: 0.0565
# epoch 71.0000 ,train acc: 0.1072, dev acc: 0.1854
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 72.0000 ,train loss: 0.0304, dev loss: 0.0219
# epoch 72.0000 ,train derror: inf, dev derror: 0.4629，train verror: inf, dev verror: 0.0553
# epoch 72.0000 ,train acc: 0.1023, dev acc: 0.1908
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 73.0000 ,train loss: 0.0294, dev loss: 0.0217
# epoch 73.0000 ,train derror: inf, dev derror: 0.4499，train verror: inf, dev verror: 0.0554
# epoch 73.0000 ,train acc: 0.1061, dev acc: 0.1938
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 74.0000 ,train loss: 0.0273, dev loss: 0.0219
# epoch 74.0000 ,train derror: inf, dev derror: 0.4528，train verror: inf, dev verror: 0.0555
# epoch 74.0000 ,train acc: 0.1158, dev acc: 0.1944
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 75.0000 ,train loss: 0.0265, dev loss: 0.0220
# epoch 75.0000 ,train derror: inf, dev derror: 0.4643，train verror: inf, dev verror: 0.0555
# epoch 75.0000 ,train acc: 0.1141, dev acc: 0.1862
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 76.0000 ,train loss: 0.0256, dev loss: 0.0216
# epoch 76.0000 ,train derror: inf, dev derror: 0.4535，train verror: inf, dev verror: 0.0550
# epoch 76.0000 ,train acc: 0.1096, dev acc: 0.1927
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 77.0000 ,train loss: 0.0254, dev loss: 0.0220
# epoch 77.0000 ,train derror: inf, dev derror: 0.4631，train verror: inf, dev verror: 0.0553
# epoch 77.0000 ,train acc: 0.1104, dev acc: 0.1924
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 78.0000 ,train loss: 0.0235, dev loss: 0.0218
# epoch 78.0000 ,train derror: inf, dev derror: 0.4475，train verror: inf, dev verror: 0.0555
# epoch 78.0000 ,train acc: 0.1117, dev acc: 0.1988
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 79.0000 ,train loss: 0.0233, dev loss: 0.0216
# epoch 79.0000 ,train derror: inf, dev derror: 0.4516，train verror: inf, dev verror: 0.0552
# epoch 79.0000 ,train acc: 0.1079, dev acc: 0.1933
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 80.0000 ,train loss: 0.0217, dev loss: 0.0216
# epoch 80.0000 ,train derror: inf, dev derror: 0.4472，train verror: inf, dev verror: 0.0552
# epoch 80.0000 ,train acc: 0.1112, dev acc: 0.1963
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 81.0000 ,train loss: 0.0219, dev loss: 0.0216
# epoch 81.0000 ,train derror: inf, dev derror: 0.4395，train verror: inf, dev verror: 0.0555
# epoch 81.0000 ,train acc: 0.1060, dev acc: 0.1971
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 82.0000 ,train loss: 0.0210, dev loss: 0.0210
# epoch 82.0000 ,train derror: inf, dev derror: 0.4120，train verror: inf, dev verror: 0.0550
# epoch 82.0000 ,train acc: 0.1123, dev acc: 0.2080
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 83.0000 ,train loss: 0.0203, dev loss: 0.0211
# epoch 83.0000 ,train derror: inf, dev derror: 0.4205，train verror: inf, dev verror: 0.0549
# epoch 83.0000 ,train acc: 0.1157, dev acc: 0.2060
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 84.0000 ,train loss: 0.0195, dev loss: 0.0211
# epoch 84.0000 ,train derror: inf, dev derror: 0.4106，train verror: inf, dev verror: 0.0553
# epoch 84.0000 ,train acc: 0.1174, dev acc: 0.2063
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 85.0000 ,train loss: 0.0192, dev loss: 0.0216
# epoch 85.0000 ,train derror: inf, dev derror: 0.4295，train verror: inf, dev verror: 0.0555
# epoch 85.0000 ,train acc: 0.1176, dev acc: 0.1987
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 86.0000 ,train loss: 0.0183, dev loss: 0.0209
# epoch 86.0000 ,train derror: inf, dev derror: 0.4148，train verror: inf, dev verror: 0.0547
# epoch 86.0000 ,train acc: 0.1156, dev acc: 0.2070
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 87.0000 ,train loss: 0.0173, dev loss: 0.0212
# epoch 87.0000 ,train derror: inf, dev derror: 0.4039，train verror: inf, dev verror: 0.0553
# epoch 87.0000 ,train acc: 0.1148, dev acc: 0.2063
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 88.0000 ,train loss: 0.0178, dev loss: 0.0212
# epoch 88.0000 ,train derror: inf, dev derror: 0.4112，train verror: inf, dev verror: 0.0551
# epoch 88.0000 ,train acc: 0.1154, dev acc: 0.2070
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 89.0000 ,train loss: 0.0162, dev loss: 0.0211
# epoch 89.0000 ,train derror: inf, dev derror: 0.4073，train verror: inf, dev verror: 0.0551
# epoch 89.0000 ,train acc: 0.1173, dev acc: 0.2050
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 90.0000 ,train loss: 0.0161, dev loss: 0.0210
# epoch 90.0000 ,train derror: inf, dev derror: 0.3998，train verror: inf, dev verror: 0.0549
# epoch 90.0000 ,train acc: 0.1250, dev acc: 0.2099
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 91.0000 ,train loss: 0.0155, dev loss: 0.0214
# epoch 91.0000 ,train derror: inf, dev derror: 0.4090，train verror: inf, dev verror: 0.0557
# epoch 91.0000 ,train acc: 0.1229, dev acc: 0.2028
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 92.0000 ,train loss: 0.0141, dev loss: 0.0219
# epoch 92.0000 ,train derror: inf, dev derror: 0.4155，train verror: inf, dev verror: 0.0560
# epoch 92.0000 ,train acc: 0.1252, dev acc: 0.2002
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 93.0000 ,train loss: 0.0133, dev loss: 0.0211
# epoch 93.0000 ,train derror: inf, dev derror: 0.3983，train verror: inf, dev verror: 0.0553
# epoch 93.0000 ,train acc: 0.1223, dev acc: 0.2058
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 94.0000 ,train loss: 0.0141, dev loss: 0.0212
# epoch 94.0000 ,train derror: inf, dev derror: 0.4041，train verror: inf, dev verror: 0.0552
# epoch 94.0000 ,train acc: 0.1276, dev acc: 0.2062
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 95.0000 ,train loss: 0.0135, dev loss: 0.0209
# epoch 95.0000 ,train derror: inf, dev derror: 0.3928，train verror: inf, dev verror: 0.0549
# epoch 95.0000 ,train acc: 0.1268, dev acc: 0.2106
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 96.0000 ,train loss: 0.0122, dev loss: 0.0205
# epoch 96.0000 ,train derror: inf, dev derror: 0.3875，train verror: inf, dev verror: 0.0545
# epoch 96.0000 ,train acc: 0.1257, dev acc: 0.2130
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 97.0000 ,train loss: 0.0124, dev loss: 0.0207
# epoch 97.0000 ,train derror: inf, dev derror: 0.3851，train verror: inf, dev verror: 0.0548
# epoch 97.0000 ,train acc: 0.1284, dev acc: 0.2108
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 98.0000 ,train loss: 0.0120, dev loss: 0.0209
# epoch 98.0000 ,train derror: inf, dev derror: 0.3766，train verror: inf, dev verror: 0.0552
# epoch 98.0000 ,train acc: 0.1357, dev acc: 0.2145
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 99.0000 ,train loss: 0.0117, dev loss: 0.0205
# epoch 99.0000 ,train derror: inf, dev derror: 0.3707，train verror: inf, dev verror: 0.0547
# epoch 99.0000 ,train acc: 0.1342, dev acc: 0.2178
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 100.0000 ,train loss: 0.0111, dev loss: 0.0206
# epoch 100.0000 ,train derror: inf, dev derror: 0.3760，train verror: inf, dev verror: 0.0548
# epoch 100.0000 ,train acc: 0.1388, dev acc: 0.2158
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 101.0000 ,train loss: 0.0115, dev loss: 0.0208
# epoch 101.0000 ,train derror: inf, dev derror: 0.3745，train verror: inf, dev verror: 0.0553
# epoch 101.0000 ,train acc: 0.1415, dev acc: 0.2116
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 102.0000 ,train loss: 0.0104, dev loss: 0.0209
# epoch 102.0000 ,train derror: inf, dev derror: 0.3726，train verror: inf, dev verror: 0.0551
# epoch 102.0000 ,train acc: 0.1385, dev acc: 0.2163
# -------------------------------------------------------------------------------------------------------------------------------------
# ...
# epoch 115.0000 ,train acc: 0.1640, dev acc: 0.2351
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 116.0000 ,train loss: 0.0070, dev loss: 0.0206
# epoch 116.0000 ,train derror: inf, dev derror: 0.3433，train verror: inf, dev verror: 0.0547
# epoch 116.0000 ,train acc: 0.1660, dev acc: 0.2227
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 117.0000 ,train loss: 0.0069, dev loss: 0.0207
# epoch 117.0000 ,train derror: inf, dev derror: 0.3403，train verror: inf, dev verror: 0.0553
# epoch 117.0000 ,train acc: 0.1653, dev acc: 0.2245
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 118.0000 ,train loss: 0.0071, dev loss: 0.0204
# epoch 118.0000 ,train derror: inf, dev derror: 0.3330，train verror: inf, dev verror: 0.0549
# epoch 118.0000 ,train acc: 0.1712, dev acc: 0.2298
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 119.0000 ,train loss: 0.0073, dev loss: 0.0207
# epoch 119.0000 ,train derror: inf, dev derror: 0.3329，train verror: inf, dev verror: 0.0554
# epoch 119.0000 ,train acc: 0.1687, dev acc: 0.2281
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 120.0000 ,train loss: 0.0071, dev loss: 0.0201
# epoch 120.0000 ,train derror: inf, dev derror: 0.3244，train verror: inf, dev verror: 0.0547
# epoch 120.0000 ,train acc: 0.1683, dev acc: 0.2361
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 121.0000 ,train loss: 0.0068, dev loss: 0.0198
# epoch 121.0000 ,train derror: inf, dev derror: 0.3248，train verror: inf, dev verror: 0.0542
# epoch 121.0000 ,train acc: 0.1783, dev acc: 0.2307
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 122.0000 ,train loss: 0.0061, dev loss: 0.0199
# epoch 122.0000 ,train derror: inf, dev derror: 0.3218，train verror: inf, dev verror: 0.0543
# epoch 122.0000 ,train acc: 0.1822, dev acc: 0.2332
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 123.0000 ,train loss: 0.0060, dev loss: 0.0203
# epoch 123.0000 ,train derror: inf, dev derror: 0.3192，train verror: inf, dev verror: 0.0547
# epoch 123.0000 ,train acc: 0.1804, dev acc: 0.2389
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 124.0000 ,train loss: 0.0064, dev loss: 0.0202
# epoch 124.0000 ,train derror: inf, dev derror: 0.3152，train verror: inf, dev verror: 0.0547
# epoch 124.0000 ,train acc: 0.1862, dev acc: 0.2413
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 125.0000 ,train loss: 0.0060, dev loss: 0.0200
# epoch 125.0000 ,train derror: inf, dev derror: 0.3107，train verror: inf, dev verror: 0.0546
# epoch 125.0000 ,train acc: 0.1860, dev acc: 0.2422
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 126.0000 ,train loss: 0.0063, dev loss: 0.0201
# epoch 126.0000 ,train derror: inf, dev derror: 0.3109，train verror: inf, dev verror: 0.0547
# epoch 126.0000 ,train acc: 0.1933, dev acc: 0.2428
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 127.0000 ,train loss: 0.0058, dev loss: 0.0199
# epoch 127.0000 ,train derror: inf, dev derror: 0.3075，train verror: inf, dev verror: 0.0544
# epoch 127.0000 ,train acc: 0.1960, dev acc: 0.2436
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 128.0000 ,train loss: 0.0054, dev loss: 0.0197
# epoch 128.0000 ,train derror: inf, dev derror: 0.3072，train verror: inf, dev verror: 0.0542
# epoch 128.0000 ,train acc: 0.1982, dev acc: 0.2402
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 129.0000 ,train loss: 0.0059, dev loss: 0.0198
# epoch 129.0000 ,train derror: inf, dev derror: 0.3045，train verror: inf, dev verror: 0.0544
# epoch 129.0000 ,train acc: 0.1981, dev acc: 0.2462
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 130.0000 ,train loss: 0.0055, dev loss: 0.0196
# epoch 130.0000 ,train derror: inf, dev derror: 0.2967，train verror: inf, dev verror: 0.0542
# epoch 130.0000 ,train acc: 0.2016, dev acc: 0.2556
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 131.0000 ,train loss: 0.0055, dev loss: 0.0193
# epoch 131.0000 ,train derror: inf, dev derror: 0.2959，train verror: inf, dev verror: 0.0538
# epoch 131.0000 ,train acc: 0.2146, dev acc: 0.2555
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 132.0000 ,train loss: 0.0052, dev loss: 0.0190
# epoch 132.0000 ,train derror: inf, dev derror: 0.2931，train verror: inf, dev verror: 0.0532
# epoch 132.0000 ,train acc: 0.2130, dev acc: 0.2620
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 133.0000 ,train loss: 0.0058, dev loss: 0.0195
# epoch 133.0000 ,train derror: inf, dev derror: 0.2913，train verror: inf, dev verror: 0.0541
# epoch 133.0000 ,train acc: 0.2227, dev acc: 0.2637
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 134.0000 ,train loss: 0.0053, dev loss: 0.0196
# epoch 134.0000 ,train derror: inf, dev derror: 0.2912，train verror: inf, dev verror: 0.0544
# epoch 134.0000 ,train acc: 0.2242, dev acc: 0.2624
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 135.0000 ,train loss: 0.0053, dev loss: 0.0196
# epoch 135.0000 ,train derror: inf, dev derror: 0.2913，train verror: inf, dev verror: 0.0543
# epoch 135.0000 ,train acc: 0.2248, dev acc: 0.2647
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 136.0000 ,train loss: 0.0057, dev loss: 0.0193
# epoch 136.0000 ,train derror: inf, dev derror: 0.2866，train verror: inf, dev verror: 0.0539
# epoch 136.0000 ,train acc: 0.2277, dev acc: 0.2705
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 137.0000 ,train loss: 0.0052, dev loss: 0.0194
# epoch 137.0000 ,train derror: inf, dev derror: 0.2847，train verror: inf, dev verror: 0.0540
# epoch 137.0000 ,train acc: 0.2294, dev acc: 0.2736
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 138.0000 ,train loss: 0.0058, dev loss: 0.0193
# epoch 138.0000 ,train derror: inf, dev derror: 0.2816，train verror: inf, dev verror: 0.0541
# epoch 138.0000 ,train acc: 0.2319, dev acc: 0.2742
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 139.0000 ,train loss: 0.0051, dev loss: 0.0197
# epoch 139.0000 ,train derror: inf, dev derror: 0.2845，train verror: inf, dev verror: 0.0544
# epoch 139.0000 ,train acc: 0.2340, dev acc: 0.2726
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 140.0000 ,train loss: 0.0049, dev loss: 0.0198
# epoch 140.0000 ,train derror: inf, dev derror: 0.2822，train verror: inf, dev verror: 0.0546
# epoch 140.0000 ,train acc: 0.2325, dev acc: 0.2747
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 141.0000 ,train loss: 0.0055, dev loss: 0.0192
# epoch 141.0000 ,train derror: inf, dev derror: 0.2742，train verror: inf, dev verror: 0.0540
# epoch 141.0000 ,train acc: 0.2329, dev acc: 0.2807
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 142.0000 ,train loss: 0.0054, dev loss: 0.0197
# epoch 142.0000 ,train derror: inf, dev derror: 0.2767，train verror: inf, dev verror: 0.0546
# epoch 142.0000 ,train acc: 0.2376, dev acc: 0.2776
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 143.0000 ,train loss: 0.0048, dev loss: 0.0192
# epoch 143.0000 ,train derror: inf, dev derror: 0.2730，train verror: inf, dev verror: 0.0538
# epoch 143.0000 ,train acc: 0.2365, dev acc: 0.2809
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 144.0000 ,train loss: 0.0052, dev loss: 0.0198
# epoch 144.0000 ,train derror: inf, dev derror: 0.2774，train verror: inf, dev verror: 0.0548
# epoch 144.0000 ,train acc: 0.2430, dev acc: 0.2731
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 145.0000 ,train loss: 0.0054, dev loss: 0.0194
# epoch 145.0000 ,train derror: inf, dev derror: 0.2741，train verror: inf, dev verror: 0.0541
# epoch 145.0000 ,train acc: 0.2482, dev acc: 0.2771
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 146.0000 ,train loss: 0.0049, dev loss: 0.0191
# epoch 146.0000 ,train derror: inf, dev derror: 0.2683，train verror: inf, dev verror: 0.0538
# epoch 146.0000 ,train acc: 0.2485, dev acc: 0.2805
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 147.0000 ,train loss: 0.0049, dev loss: 0.0195
# epoch 147.0000 ,train derror: inf, dev derror: 0.2675，train verror: inf, dev verror: 0.0545
# epoch 147.0000 ,train acc: 0.2557, dev acc: 0.2843
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 148.0000 ,train loss: 0.0051, dev loss: 0.0198
# epoch 148.0000 ,train derror: inf, dev derror: 0.2701，train verror: inf, dev verror: 0.0548
# epoch 148.0000 ,train acc: 0.2551, dev acc: 0.2801
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 149.0000 ,train loss: 0.0051, dev loss: 0.0195
# epoch 149.0000 ,train derror: inf, dev derror: 0.2661，train verror: inf, dev verror: 0.0545
# epoch 149.0000 ,train acc: 0.2513, dev acc: 0.2825
# -------------------------------------------------------------------------------------------------------------------------------------

# %%
print(0:3)
# Out:
#   File "<ipython-input-18-b55870bed798>", line 1
#     print(0:3)
#            ^
# SyntaxError: invalid syntax

# %%
    
    

    t = np.arange(1, len(epoch_train_loss_list) + 1)
    #模型保存
    log_dir='/content/drive/My Drive/testCNN04201145.pth'
    state = {'net':model.state_dict(),  'epoch':epoch}
    torch.save(state, log_dir)

    plt.figure(figsize=(5,15))
    
    loss_plot = plt.subplot(3, 1, 1)
    plt.title('loss ')
    plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
    plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
    der_plot = plt.subplot(3, 1, 2)
    plt.title('distance error')
    plt.plot(t, epoch_train_derror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
    der_plot = plt.subplot(3, 1, 3)
    plt.title('Velocity error')
    plt.plot(t, epoch_train_verror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
    plt.show()

# %%
def get_test_data(dataset_path, fm, SNR):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    #datalen = int(len(x_data) / 3)
    datalen=500
    x_test = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y_test = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1,datalen):
        xkey = 'x' + str((SNR+5)*500)
        #print(xkey)
        x_test[i] = data[xkey]
        
        ykey = 'y' + str((SNR+5)*500)
        y_test[i] = data[ykey]#噪声
        #if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])
        

    
    return x_test, y_test

# %%
batch_size=100
model = DnCNN()

def detect_acc(label_y,predict_y):
  sum=0
  for i in range(1,label_y.shape[0]):
    for 
        
  return x_test, y_test

if os.path.exists(log_dir):
  checkpoint = torch.load(log_dir)
  model.load_state_dict(checkpoint['net'])
  start_epoch = checkpoint['epoch']
  print('加载 epoch {} 成功！'.format(start_epoch))
else:
    start_epoch = 0
    print('加载失败')

for SNR in range(-5,5):
  x_test, y_test = get_test_data(dataset_path, 'TrainData_MutiSNRnoMPI.mat', SNR)
  test_dataset = MyDataset(x_test, y_test)
  train_loader = DataLoader(test_dataset, batch_size=batch_size)


  for idx, (test_x, test_label) in enumerate(train_loader):
                  s = test_label.shape[0]
                  predict_y = model(test_x.to(device))
                  # print(predict_y[0], dev_label[0])
                  #loss = criterion(predict_y, train_label.to(device)) / (2 * len(train_x))
                  terror,verror=ab_err(predict_y,train_label.to(device))
                  label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
                  # print("------")
                  # print(label_pred)
                  # print(dev_label.numpy())
                  # print("------")
                  acc = np.sum(label_pred == dev_label.numpy())
                  batch_acc=acc / s
                  dev_num+=1
                  # print("batch_acc::",batch_acc)
                  epoch_dev_acc += acc / s
                  epoch_dev_derror+=terror
                  epoch_dev_verror+=verror
                  epoch_dev_loss += loss.item()
                  label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
                  # print("------")
                  # print(label_pred)
                  # print(dev_label.numpy())
                  # print("------")
                  #acc = np.sum(label_pred == dev_label.numpy())
                  #batch_acc=acc / s
                  dev_num+=1
                  # print("batch_acc::",batch_acc)
                  #epoch_dev_acc += acc / s
                  # print("devacc", acc);
          epoch_train_loss_list.append(epoch_train_loss / train_num)
          epoch_dev_loss_list.append(epoch_dev_loss / dev_num)
          epoch_train_derror_list.append(epoch_train_derror / train_num)
          epoch_dev_derror_list.append(epoch_dev_derror / dev_num)
          epoch_train_verror_list.append(epoch_train_verror / train_num)
          epoch_dev_verror_list.append(epoch_dev_verror / dev_num)

          #epoch_train_acc_list.append(epoch_train_acc / dev_num)
          #epoch_dev_acc_list.append(epoch_dev_acc / dev_num)
          print('-------------------------------------------------------------------------------------------------------------------------------------')
          print("epoch {:.4f} ,train loss: {:.4f}, dev loss: {:.4f}".format(_epoch, epoch_train_loss / train_num, epoch_dev_loss / dev_num))
          print("epoch {:.4f} ,train derror: {:.4f}, dev derror: {:.4f}，train verror: {:.4f}, dev verror: {:.4f}".format(_epoch, epoch_train_derror / train_num, epoch_dev_derror / dev_num, epoch_train_verror / train_num, epoch_dev_verror / dev_num))
          print('-------------------------------------------------------------------------------------------------------------------------------------')
