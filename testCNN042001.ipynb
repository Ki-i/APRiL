# %% [markdown]
# <a href="https://colab.research.google.com/github/Ki-i/APRiL/blob/master/testCNN042001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
workspace_dir = '.'
#!unzip -q "/content/drive/My Drive/crypko_data.zip" -d "{workspace_dir}/"

# %%
from torch.nn import Module
from torch import nn
import numpy as np
import math
import torch
from torch.nn import CrossEntropyLoss
from torch.nn import MSELoss
from torch.optim import SGD
from torch.utils.data import DataLoader, TensorDataset
import os
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import matplotlib.pyplot as plt
import sys
import scipy.io as scio
import pylab

# %%
class DnCNN(nn.Module):
    def __init__(self):
        super(DnCNN, self).__init__()
        channels=3
        num_of_layers=10
        kernel_size = 3
        padding = 1
        features = 64
        layers = []
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))
        for _ in range(num_of_layers-2):
            layers.append(nn.Conv2d(in_channels=features, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
            layers.append(nn.BatchNorm2d(features))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False))
 
        self.dncnn = nn.Sequential(*layers)
        self.fc1=nn.Linear( 3*50*100,6)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(6,6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练
    def forward(self, x):
        y = self.dncnn(x)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu(y)
        y = self.fc2(y)
       
        return y

# %%
class Model(Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(2, 32, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)
        self.conv3 = nn.Conv2d(64, 64, 5)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(64*2*9, 64)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(64, 6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练

    def forward(self, x):
        y = self.conv1(x)
        y = self.relu1(y)
        y = self.pool1(y)
        y = self.conv2(y)
        y = self.relu2(y)
        y = self.pool2(y)
        y = self.conv3(y)
        y = self.relu3(y)
        y = self.pool3(y)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu3(y)
        y = self.fc2(y)
        # y = self.relu4(y)
        # y = self.fc3(y)
        # y = self.relu5(y)
        return y

# %%
def get_data(dataset_path, fm, dev_ratio):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    #datalen = int(len(x_data) / 3)
    datalen=5000
    x = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str(i)
        #print(xkey)
        x[i] = data[xkey]
        
        ykey = 'y' + str(i)
        y[i] = data[ykey]#噪声
        #if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])
        

    data_size = len(y)
    train_size = int(data_size * (1 - dev_ratio))
    state = np.random.get_state()
    np.random.shuffle(x)
    np.random.set_state(state)
    np.random.shuffle(y)
    # print("train size:", train_size)
    # print("dev size:", data_size - train_size)
    x_train = x[:train_size]
    y_train = y[:train_size]
    x_dev = x[train_size:]
    y_dev = y[train_size:]
    return x_train, y_train, x_dev, y_dev

# %%
class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x, self.y = x, y
        self.data_size = len(self.y)
        #norm_mean = [0.485, 0.456, 0.406]
        #norm_std = [0.229, 0.224, 0.225]
        self.img_transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.ToTensor(),
            # transforms.Normalize(norm_mean, norm_std),
        ])

    def __len__(self):
        return self.data_size

    def __getitem__(self, item):
        '''
        这个函数是关键，通过item(索引)来取数据集中的数据，
        一般来说在这里才将图像数据加载入内存，之前存的是图像的保存路径
        '''
        ycut=self.y[item]
        #ycut=ycut[101:-6:400,1:-5:500]

        label = torch.from_numpy(ycut)
        #label = torch.reshape(label, (1, -1))
        xcut = self.x[item]
        #xcut = xcut[101:-6:400,1:-5:500]
        x = torch.from_numpy(xcut)
        #x=x.unsqueeze(0)
        #label=label.squeeze(0)
        x=x.float()
        label=label.float()
        x = torch.div(x, 255.)
        label = torch.div(label, 10000.)
        #print(x.size())
        #print(label.size())
        #label=torch.div(label, 255.)
        return x, label

# %%
x=np.array([1,2,3,4])
x=x/4
print(x)
# Out:
# [0.25 0.5  0.75 1.  ]

# %%
def psnr(target_data, ref_data):
    # target:目标图像  ref:参考图像  scale:尺寸大小
    # assume RGB image
    #target_data = np.array(target)
    #target_data = target_data[scale:-scale, scale:-scale]

    #ref_data = np.array(ref)
    #ref_data = ref_data[scale:-scale, scale:-scale]
    im = ref_data.max()
    print('参考图像峰值', ref_data.max(), ref_data.min())
    print('实际图像峰值', target_data.max(), target_data.min())
    target_data = target_data * (ref_data.max() / target_data.max())
    #print('实际图像峰值', target_data.max(), target_data.min())
    diff = ref_data - target_data
    diff = diff.flatten('C')

    #rmse = math.sqrt(np.mean(diff ** 2.))
    #return 20 * math.log10(math.pow(im,2) / rmse)
    mse = np.mean(diff ** 2.)
    return 20 * math.log10(math.pow(im,2) / mse)

def ab_err(target_data, ref_data):
  diff = abs(ref_data - target_data)/ref_data
  diff=diff.cpu().data.numpy()
  tdiff=diff[0:,0:2]
  vdiff=diff[0:,3:5]
  
  
  terr = np.mean(tdiff)
  verr = np.mean(vdiff)

  return terr,verr

# %%
if __name__ == '__main__':

    batch_size = 32
    lr=1e-3
    #lr=1e-4#loss:11.72 10.74
    #lr=1e-3#9.6519
    #lr=0.01#8.3690
    #lr=0.1#8.2 7.72 7.71 ..7156.7147
    log_dir='/content/drive/My Drive/model.pth'
    #数据集加载
    dataset_path = '/content/drive/My Drive/'
    x_train, y_train, x_dev, y_dev = get_data(dataset_path, 'TrainData_MutiSNRnoMPI.mat', 0.2)
    #print(x_train[0])
    train_dataset = MyDataset(x_train, y_train)
    train_loader = DataLoader(train_dataset, batch_size=batch_size)
    dev_dataset = MyDataset(x_dev, y_dev)
    dev_loader = DataLoader(train_dataset, batch_size=batch_size)

    model = DnCNN()
    #model = Model()
    #模型加载
    start_epoch=0
    '''
    if os.path.exists(log_dir):
        checkpoint = torch.load(log_dir)
        model.load_state_dict(checkpoint['net'])
        start_epoch = checkpoint['epoch']
        print('加载 epoch {} 成功！'.format(start_epoch))
    else:
        start_epoch = 0
        print('无保存模型，将从头开始训练！')
    '''
    sgd = SGD(model.parameters(), lr)

    cost = CrossEntropyLoss()
    criterion = MSELoss(reduction='sum')
    epoch = 150
    use_GPU = True
    if use_GPU:
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")
    model.to(device)
    epoch_train_loss_list = []
    epoch_dev_loss_list = []
    epoch_train_acc_list = []
    epoch_dev_acc_list = []
    epoch_train_derror_list = []
    epoch_dev_derror_list = []
    epoch_train_verror_list = []
    epoch_dev_verror_list = []
    for _epoch in range(start_epoch+1,start_epoch+epoch):
        model.train()
        epoch_train_loss = 0
        epoch_dev_loss = 0
        epoch_train_acc = 0
        epoch_dev_acc = 0
        train_num=0
        dev_num = 0
        epoch_dev_derror=0
        epoch_dev_verror=0
        epoch_train_derror=0
        epoch_train_verror=0
        for idx, (train_x, train_label) in enumerate(train_loader):
            s = train_label.shape[0]
            sgd.zero_grad()
            #print(train_x.size())
            predict_y = model(train_x.to(device))

            loss = criterion(predict_y, train_label.to(device))/ (2 * len(train_x))
            terror,verror=ab_err(predict_y,train_label.to(device))
            epoch_train_loss += loss.item()
            epoch_train_derror+=terror
            epoch_train_verror+=verror
            label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
            #acc = np.sum(label_pred == train_label.numpy())
            # print("batch Train acc:",acc / s)
            #epoch_train_acc += acc / s
            train_num+=1
            loss.backward()
            sgd.step()

        correct = 0
        _sum = 0
        model.eval()

        with torch.no_grad():
            for idx, (dev_x, dev_label) in enumerate(dev_loader):
                s = dev_label.shape[0]
                predict_y = model(dev_x.to(device))
                # print(predict_y[0], dev_label[0])
                loss = criterion(predict_y, train_label.to(device)) / (2 * len(train_x))
                terror,verror=ab_err(predict_y,train_label.to(device))
                
                epoch_dev_derror+=terror
                epoch_dev_verror+=verror
                epoch_dev_loss += loss.item()
                label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
                # print("------")
                # print(label_pred)
                # print(dev_label.numpy())
                # print("------")
                #acc = np.sum(label_pred == dev_label.numpy())
                #batch_acc=acc / s
                dev_num+=1
                # print("batch_acc::",batch_acc)
                #epoch_dev_acc += acc / s
                # print("devacc", acc);
        epoch_train_loss_list.append(epoch_train_loss / train_num)
        epoch_dev_loss_list.append(epoch_dev_loss / dev_num)
        epoch_train_derror_list.append(epoch_train_derror / train_num)
        epoch_dev_derror_list.append(epoch_dev_derror / dev_num)
        epoch_train_verror_list.append(epoch_train_verror / train_num)
        epoch_dev_verror_list.append(epoch_dev_verror / dev_num)

        #epoch_train_acc_list.append(epoch_train_acc / dev_num)
        #epoch_dev_acc_list.append(epoch_dev_acc / dev_num)
        print('-------------------------------------------------------------------------------------------------------------------------------------')
        print("epoch {:.4f} ,train loss: {:.4f}, dev loss: {:.4f}".format(_epoch, epoch_train_loss / train_num, epoch_dev_loss / dev_num))
        print("epoch {:.4f} ,train derror: {:.4f}, dev derror: {:.4f}，train verror: {:.4f}, dev verror: {:.4f}".format(_epoch, epoch_train_derror / train_num, epoch_dev_derror / dev_num, epoch_train_verror / train_num, epoch_dev_verror / dev_num))
        print('-------------------------------------------------------------------------------------------------------------------------------------')
        '''
        #绘图
        y_show = predict_y.reshape([batch_size, 50, 100])
        y_show = y_show.cpu().data.numpy()
        
        #print(train_x.size())
        x_show_x=train_x.squeeze(1)
        label_show=train_label.reshape([batch_size,50, 100])
        label_show=label_show.cpu().data.numpy()
        #print(x_show_x.size())
        x_show= x_show_x.numpy()
        y_show=x_show-y_show
        label_show=x_show-label_show
        #print(len(y_show[batch_size-1]))
        im1=1
        im2=int(batch_size/2)
        im3=batch_size-1
        pylab.figure(figsize=(10,10))
        plot = 'plot' + str(_epoch)
        plot = pylab.subplot(3, 3, 1)
        pylab.title('input_epcho'+str(_epoch)+'_image'+str(im1))
        pylab.imshow(np.asarray(x_show[im1]))
        plot = pylab.subplot(3, 3, 2)
        pylab.title('output_epcho'+str(_epoch)+'_image'+str(im1))
        pylab.imshow(np.asarray(y_show[im1]))
        plot = pylab.subplot(3, 3, 3)
        pylab.title('label__epcho'+str(_epoch)+'_image'+str(im1))
        pylab.imshow(np.asarray(label_show[im1]))
        plot = pylab.subplot(3, 3, 4)
        pylab.title('input__epcho'+str(_epoch)+'_image'+str(im2))
        pylab.imshow(np.asarray(x_show[im2]))
        plot = pylab.subplot(3, 3, 5)
        pylab.title('output__epcho'+str(_epoch)+'_image'+str(im2))
        pylab.imshow(np.asarray(y_show[im2]))
        plot = pylab.subplot(3, 3, 6)
        pylab.title('label__epcho'+str(_epoch)+'_image'+str(im2))
        pylab.imshow(np.asarray(label_show[im2]))
        plot = pylab.subplot(3, 3, 7)
        pylab.title('input__epcho'+str(_epoch)+'_image'+str(im3))
        pylab.imshow(np.asarray(x_show[im3]))
        plot = pylab.subplot(3, 3, 8)
        pylab.title('output__epcho'+str(_epoch)+'_image'+str(im3))
        pylab.imshow(np.asarray(y_show[im3]))
        plot = pylab.subplot(3, 3, 9)
        pylab.title('label__epcho'+str(_epoch)+'_image'+str(im3))
        pylab.imshow(np.asarray(label_show[im3]))
        pylab.show()
        '''
        '''
        y_show=predict_y.reshape([batch_size,50,100])
        print(y_show.size())
        #y_show=y_show.cpu().data.numpy()
        #imgs_sample = [y_show[i] for i in range(16,32)]
        y_show = y_show.unsqueeze(1)
        print(y_show.size())
        grid_img = torchvision.utils.make_grid(y_show.cpu(), nrow=4)
        plt.figure(figsize=(10, 10))  # 画图
        plt.imshow(grid_img)
        plt.show()  # 展示图片
        '''

    t = np.arange(1, len(epoch_train_loss_list) + 1)
    #模型保存
    
    state = {'net':model.state_dict(),  'epoch':epoch}
    torch.save(state, log_dir)

    plt.figure(figsize=(5,15))
    
    loss_plot = plt.subplot(3, 1, 1)
    plt.title('loss ')
    plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
    plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
    der_plot = plt.subplot(3, 1, 2)
    plt.title('distance error')
    plt.plot(t, epoch_train_derror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
    der_plot = plt.subplot(3, 1, 3)
    plt.title('Velocity error')
    plt.plot(t, epoch_train_verror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
    plt.show()
# Out:
# load data from path1: /content/drive/My Drive/
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 1.0000 ,train loss: 1.7953, dev loss: 0.6293
# epoch 1.0000 ,train derror: inf, dev derror: 14.3938，train verror: inf, dev verror: 0.3034
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 2.0000 ,train loss: 0.9911, dev loss: 0.3000
# epoch 2.0000 ,train derror: inf, dev derror: 3.8110，train verror: inf, dev verror: 0.2357
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 3.0000 ,train loss: 0.8116, dev loss: 0.1797
# epoch 3.0000 ,train derror: inf, dev derror: 2.0809，train verror: inf, dev verror: 0.1708
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 4.0000 ,train loss: 0.7190, dev loss: 0.2370
# epoch 4.0000 ,train derror: inf, dev derror: 2.9970，train verror: inf, dev verror: 0.2057
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 5.0000 ,train loss: 0.6729, dev loss: 0.2223
# epoch 5.0000 ,train derror: inf, dev derror: 3.3396，train verror: inf, dev verror: 0.1917
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 6.0000 ,train loss: 0.6118, dev loss: 0.1961
# epoch 6.0000 ,train derror: inf, dev derror: 3.2243，train verror: inf, dev verror: 0.1799
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 7.0000 ,train loss: 0.5659, dev loss: 0.1739
# epoch 7.0000 ,train derror: inf, dev derror: 3.1593，train verror: inf, dev verror: 0.1669
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 8.0000 ,train loss: 0.5298, dev loss: 0.1529
# epoch 8.0000 ,train derror: inf, dev derror: 3.1648，train verror: inf, dev verror: 0.1506
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 9.0000 ,train loss: 0.4767, dev loss: 0.1386
# epoch 9.0000 ,train derror: inf, dev derror: 3.0387，train verror: inf, dev verror: 0.1421
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 10.0000 ,train loss: 0.4443, dev loss: 0.1412
# epoch 10.0000 ,train derror: inf, dev derror: 3.0168，train verror: inf, dev verror: 0.1443
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 11.0000 ,train loss: 0.4185, dev loss: 0.1168
# epoch 11.0000 ,train derror: inf, dev derror: 2.8965，train verror: inf, dev verror: 0.1254
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 12.0000 ,train loss: 0.3804, dev loss: 0.1192
# epoch 12.0000 ,train derror: inf, dev derror: 2.9202，train verror: inf, dev verror: 0.1265
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 13.0000 ,train loss: 0.3559, dev loss: 0.1135
# epoch 13.0000 ,train derror: inf, dev derror: 3.1950，train verror: inf, dev verror: 0.1144
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 14.0000 ,train loss: 0.3283, dev loss: 0.0899
# epoch 14.0000 ,train derror: inf, dev derror: 2.5645，train verror: inf, dev verror: 0.1060
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 15.0000 ,train loss: 0.2938, dev loss: 0.1051
# epoch 15.0000 ,train derror: inf, dev derror: 2.5156，train verror: inf, dev verror: 0.1219
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 16.0000 ,train loss: 0.2777, dev loss: 0.0971
# epoch 16.0000 ,train derror: inf, dev derror: 2.4644，train verror: inf, dev verror: 0.1148
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 17.0000 ,train loss: 0.2590, dev loss: 0.0797
# epoch 17.0000 ,train derror: inf, dev derror: 2.3675，train verror: inf, dev verror: 0.0985
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 18.0000 ,train loss: 0.2279, dev loss: 0.0698
# epoch 18.0000 ,train derror: inf, dev derror: 2.1577，train verror: inf, dev verror: 0.0922
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 19.0000 ,train loss: 0.2160, dev loss: 0.0675
# epoch 19.0000 ,train derror: inf, dev derror: 2.1285，train verror: inf, dev verror: 0.0901
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 20.0000 ,train loss: 0.1936, dev loss: 0.0729
# epoch 20.0000 ,train derror: inf, dev derror: 1.9188，train verror: inf, dev verror: 0.1014
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 21.0000 ,train loss: 0.1912, dev loss: 0.0627
# epoch 21.0000 ,train derror: inf, dev derror: 1.9897，train verror: inf, dev verror: 0.0871
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 22.0000 ,train loss: 0.1727, dev loss: 0.0542
# epoch 22.0000 ,train derror: inf, dev derror: 1.7740，train verror: inf, dev verror: 0.0817
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 23.0000 ,train loss: 0.1574, dev loss: 0.0456
# epoch 23.0000 ,train derror: inf, dev derror: 1.8348，train verror: inf, dev verror: 0.0708
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 24.0000 ,train loss: 0.1550, dev loss: 0.0532
# epoch 24.0000 ,train derror: inf, dev derror: 1.6752，train verror: inf, dev verror: 0.0823
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 25.0000 ,train loss: 0.1369, dev loss: 0.0459
# epoch 25.0000 ,train derror: inf, dev derror: 1.4866，train verror: inf, dev verror: 0.0779
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 26.0000 ,train loss: 0.1321, dev loss: 0.0412
# epoch 26.0000 ,train derror: inf, dev derror: 1.4756，train verror: inf, dev verror: 0.0711
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 27.0000 ,train loss: 0.1220, dev loss: 0.0362
# epoch 27.0000 ,train derror: inf, dev derror: 1.4954，train verror: inf, dev verror: 0.0651
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 28.0000 ,train loss: 0.1113, dev loss: 0.0513
# epoch 28.0000 ,train derror: inf, dev derror: 1.5194，train verror: inf, dev verror: 0.0856
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 29.0000 ,train loss: 0.1060, dev loss: 0.0422
# epoch 29.0000 ,train derror: inf, dev derror: 1.3785，train verror: inf, dev verror: 0.0748
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 30.0000 ,train loss: 0.1035, dev loss: 0.0388
# epoch 30.0000 ,train derror: inf, dev derror: 1.2959，train verror: inf, dev verror: 0.0720
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 31.0000 ,train loss: 0.0938, dev loss: 0.0308
# epoch 31.0000 ,train derror: inf, dev derror: 1.1741，train verror: inf, dev verror: 0.0636
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 32.0000 ,train loss: 0.0866, dev loss: 0.0342
# epoch 32.0000 ,train derror: inf, dev derror: 1.1911，train verror: inf, dev verror: 0.0679
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 33.0000 ,train loss: 0.0837, dev loss: 0.0268
# epoch 33.0000 ,train derror: inf, dev derror: 1.0373，train verror: inf, dev verror: 0.0597
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 34.0000 ,train loss: 0.0787, dev loss: 0.0272
# epoch 34.0000 ,train derror: inf, dev derror: 1.0276，train verror: inf, dev verror: 0.0608
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 35.0000 ,train loss: 0.0719, dev loss: 0.0332
# epoch 35.0000 ,train derror: inf, dev derror: 1.2651，train verror: inf, dev verror: 0.0691
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 36.0000 ,train loss: 0.0709, dev loss: 0.0290
# epoch 36.0000 ,train derror: inf, dev derror: 1.0735，train verror: inf, dev verror: 0.0636
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 37.0000 ,train loss: 0.0683, dev loss: 0.0263
# epoch 37.0000 ,train derror: inf, dev derror: 1.0023，train verror: inf, dev verror: 0.0611
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 38.0000 ,train loss: 0.0636, dev loss: 0.0294
# epoch 38.0000 ,train derror: inf, dev derror: 1.0651，train verror: inf, dev verror: 0.0645
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 39.0000 ,train loss: 0.0588, dev loss: 0.0263
# epoch 39.0000 ,train derror: inf, dev derror: 1.0073，train verror: inf, dev verror: 0.0613
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 40.0000 ,train loss: 0.0553, dev loss: 0.0270
# epoch 40.0000 ,train derror: inf, dev derror: 1.0554，train verror: inf, dev verror: 0.0625
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 41.0000 ,train loss: 0.0562, dev loss: 0.0280
# epoch 41.0000 ,train derror: inf, dev derror: 1.1127，train verror: inf, dev verror: 0.0639
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 42.0000 ,train loss: 0.0519, dev loss: 0.0253
# epoch 42.0000 ,train derror: inf, dev derror: 1.0169，train verror: inf, dev verror: 0.0610
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 43.0000 ,train loss: 0.0494, dev loss: 0.0247
# epoch 43.0000 ,train derror: inf, dev derror: 0.9323，train verror: inf, dev verror: 0.0599
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 44.0000 ,train loss: 0.0462, dev loss: 0.0236
# epoch 44.0000 ,train derror: inf, dev derror: 0.9195，train verror: inf, dev verror: 0.0584
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 45.0000 ,train loss: 0.0436, dev loss: 0.0236
# epoch 45.0000 ,train derror: inf, dev derror: 0.9629，train verror: inf, dev verror: 0.0587
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 46.0000 ,train loss: 0.0408, dev loss: 0.0249
# epoch 46.0000 ,train derror: inf, dev derror: 0.9883，train verror: inf, dev verror: 0.0600
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 47.0000 ,train loss: 0.0424, dev loss: 0.0230
# epoch 47.0000 ,train derror: inf, dev derror: 0.8930，train verror: inf, dev verror: 0.0582
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 48.0000 ,train loss: 0.0382, dev loss: 0.0239
# epoch 48.0000 ,train derror: inf, dev derror: 0.9715，train verror: inf, dev verror: 0.0594
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 49.0000 ,train loss: 0.0369, dev loss: 0.0244
# epoch 49.0000 ,train derror: inf, dev derror: 1.0172，train verror: inf, dev verror: 0.0601
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 50.0000 ,train loss: 0.0357, dev loss: 0.0219
# epoch 50.0000 ,train derror: inf, dev derror: 0.8539，train verror: inf, dev verror: 0.0571
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 51.0000 ,train loss: 0.0328, dev loss: 0.0245
# epoch 51.0000 ,train derror: inf, dev derror: 1.0313，train verror: inf, dev verror: 0.0604
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 52.0000 ,train loss: 0.0325, dev loss: 0.0223
# epoch 52.0000 ,train derror: inf, dev derror: 0.8874，train verror: inf, dev verror: 0.0578
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 53.0000 ,train loss: 0.0305, dev loss: 0.0224
# epoch 53.0000 ,train derror: inf, dev derror: 0.9301，train verror: inf, dev verror: 0.0578
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 54.0000 ,train loss: 0.0282, dev loss: 0.0225
# epoch 54.0000 ,train derror: inf, dev derror: 0.9113，train verror: inf, dev verror: 0.0578
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 55.0000 ,train loss: 0.0287, dev loss: 0.0224
# epoch 55.0000 ,train derror: inf, dev derror: 0.8816，train verror: inf, dev verror: 0.0579
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 56.0000 ,train loss: 0.0267, dev loss: 0.0216
# epoch 56.0000 ,train derror: inf, dev derror: 0.8427，train verror: inf, dev verror: 0.0569
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 57.0000 ,train loss: 0.0264, dev loss: 0.0217
# epoch 57.0000 ,train derror: inf, dev derror: 0.8389，train verror: inf, dev verror: 0.0571
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 58.0000 ,train loss: 0.0237, dev loss: 0.0214
# epoch 58.0000 ,train derror: inf, dev derror: 0.8256，train verror: inf, dev verror: 0.0568
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 59.0000 ,train loss: 0.0240, dev loss: 0.0223
# epoch 59.0000 ,train derror: inf, dev derror: 0.8726，train verror: inf, dev verror: 0.0578
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 60.0000 ,train loss: 0.0240, dev loss: 0.0218
# epoch 60.0000 ,train derror: inf, dev derror: 0.8698，train verror: inf, dev verror: 0.0572
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 61.0000 ,train loss: 0.0219, dev loss: 0.0218
# epoch 61.0000 ,train derror: inf, dev derror: 0.9126，train verror: inf, dev verror: 0.0571
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 62.0000 ,train loss: 0.0206, dev loss: 0.0219
# epoch 62.0000 ,train derror: inf, dev derror: 0.9087，train verror: inf, dev verror: 0.0575
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 63.0000 ,train loss: 0.0197, dev loss: 0.0219
# epoch 63.0000 ,train derror: inf, dev derror: 0.9295，train verror: inf, dev verror: 0.0576
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 64.0000 ,train loss: 0.0187, dev loss: 0.0213
# epoch 64.0000 ,train derror: inf, dev derror: 0.8051，train verror: inf, dev verror: 0.0567
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 65.0000 ,train loss: 0.0185, dev loss: 0.0209
# epoch 65.0000 ,train derror: inf, dev derror: 0.7929，train verror: inf, dev verror: 0.0565
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 66.0000 ,train loss: 0.0175, dev loss: 0.0208
# epoch 66.0000 ,train derror: inf, dev derror: 0.8300，train verror: inf, dev verror: 0.0562
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 67.0000 ,train loss: 0.0176, dev loss: 0.0205
# epoch 67.0000 ,train derror: inf, dev derror: 0.7578，train verror: inf, dev verror: 0.0559
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 68.0000 ,train loss: 0.0160, dev loss: 0.0211
# epoch 68.0000 ,train derror: inf, dev derror: 0.8934，train verror: inf, dev verror: 0.0564
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 69.0000 ,train loss: 0.0152, dev loss: 0.0208
# epoch 69.0000 ,train derror: inf, dev derror: 0.7992，train verror: inf, dev verror: 0.0563
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 70.0000 ,train loss: 0.0154, dev loss: 0.0207
# epoch 70.0000 ,train derror: inf, dev derror: 0.8145，train verror: inf, dev verror: 0.0562
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 71.0000 ,train loss: 0.0148, dev loss: 0.0205
# epoch 71.0000 ,train derror: inf, dev derror: 0.7795，train verror: inf, dev verror: 0.0558
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 72.0000 ,train loss: 0.0142, dev loss: 0.0204
# epoch 72.0000 ,train derror: inf, dev derror: 0.7848，train verror: inf, dev verror: 0.0559
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 73.0000 ,train loss: 0.0130, dev loss: 0.0206
# epoch 73.0000 ,train derror: inf, dev derror: 0.8297，train verror: inf, dev verror: 0.0559
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 74.0000 ,train loss: 0.0133, dev loss: 0.0204
# epoch 74.0000 ,train derror: inf, dev derror: 0.7458，train verror: inf, dev verror: 0.0558
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 75.0000 ,train loss: 0.0126, dev loss: 0.0203
# epoch 75.0000 ,train derror: inf, dev derror: 0.7728，train verror: inf, dev verror: 0.0559
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 76.0000 ,train loss: 0.0119, dev loss: 0.0202
# epoch 76.0000 ,train derror: inf, dev derror: 0.7404，train verror: inf, dev verror: 0.0557
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 77.0000 ,train loss: 0.0120, dev loss: 0.0203
# epoch 77.0000 ,train derror: inf, dev derror: 0.7414，train verror: inf, dev verror: 0.0559
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 78.0000 ,train loss: 0.0116, dev loss: 0.0204
# epoch 78.0000 ,train derror: inf, dev derror: 0.7646，train verror: inf, dev verror: 0.0560
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 79.0000 ,train loss: 0.0114, dev loss: 0.0203
# epoch 79.0000 ,train derror: inf, dev derror: 0.7266，train verror: inf, dev verror: 0.0561
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 80.0000 ,train loss: 0.0111, dev loss: 0.0201
# epoch 80.0000 ,train derror: inf, dev derror: 0.7593，train verror: inf, dev verror: 0.0557
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 81.0000 ,train loss: 0.0103, dev loss: 0.0200
# epoch 81.0000 ,train derror: inf, dev derror: 0.7131，train verror: inf, dev verror: 0.0557
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 82.0000 ,train loss: 0.0097, dev loss: 0.0202
# epoch 82.0000 ,train derror: inf, dev derror: 0.7283，train verror: inf, dev verror: 0.0558
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 83.0000 ,train loss: 0.0089, dev loss: 0.0200
# epoch 83.0000 ,train derror: inf, dev derror: 0.7277，train verror: inf, dev verror: 0.0555
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 84.0000 ,train loss: 0.0089, dev loss: 0.0198
# epoch 84.0000 ,train derror: inf, dev derror: 0.7074，train verror: inf, dev verror: 0.0553
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 85.0000 ,train loss: 0.0084, dev loss: 0.0199
# epoch 85.0000 ,train derror: inf, dev derror: 0.7080，train verror: inf, dev verror: 0.0555
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 86.0000 ,train loss: 0.0089, dev loss: 0.0202
# epoch 86.0000 ,train derror: inf, dev derror: 0.6911，train verror: inf, dev verror: 0.0562
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 87.0000 ,train loss: 0.0081, dev loss: 0.0198
# epoch 87.0000 ,train derror: inf, dev derror: 0.6863，train verror: inf, dev verror: 0.0554
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 88.0000 ,train loss: 0.0085, dev loss: 0.0198
# epoch 88.0000 ,train derror: inf, dev derror: 0.6912，train verror: inf, dev verror: 0.0556
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 89.0000 ,train loss: 0.0083, dev loss: 0.0198
# epoch 89.0000 ,train derror: inf, dev derror: 0.6730，train verror: inf, dev verror: 0.0559
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 90.0000 ,train loss: 0.0079, dev loss: 0.0196
# epoch 90.0000 ,train derror: inf, dev derror: 0.6912，train verror: inf, dev verror: 0.0553
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 91.0000 ,train loss: 0.0076, dev loss: 0.0196
# epoch 91.0000 ,train derror: inf, dev derror: 0.6685，train verror: inf, dev verror: 0.0554
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 92.0000 ,train loss: 0.0070, dev loss: 0.0196
# epoch 92.0000 ,train derror: inf, dev derror: 0.6679，train verror: inf, dev verror: 0.0554
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 93.0000 ,train loss: 0.0072, dev loss: 0.0196
# epoch 93.0000 ,train derror: inf, dev derror: 0.6660，train verror: inf, dev verror: 0.0554
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 94.0000 ,train loss: 0.0074, dev loss: 0.0195
# epoch 94.0000 ,train derror: inf, dev derror: 0.6608，train verror: inf, dev verror: 0.0552
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 95.0000 ,train loss: 0.0066, dev loss: 0.0194
# epoch 95.0000 ,train derror: inf, dev derror: 0.6588，train verror: inf, dev verror: 0.0551
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 96.0000 ,train loss: 0.0065, dev loss: 0.0195
# epoch 96.0000 ,train derror: inf, dev derror: 0.6542，train verror: inf, dev verror: 0.0553
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 97.0000 ,train loss: 0.0065, dev loss: 0.0193
# epoch 97.0000 ,train derror: inf, dev derror: 0.6475，train verror: inf, dev verror: 0.0550
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 98.0000 ,train loss: 0.0063, dev loss: 0.0193
# epoch 98.0000 ,train derror: inf, dev derror: 0.6417，train verror: inf, dev verror: 0.0551
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 99.0000 ,train loss: 0.0067, dev loss: 0.0193
# epoch 99.0000 ,train derror: inf, dev derror: 0.6454，train verror: inf, dev verror: 0.0550
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 100.0000 ,train loss: 0.0061, dev loss: 0.0193
# epoch 100.0000 ,train derror: inf, dev derror: 0.6319，train verror: inf, dev verror: 0.0551
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 101.0000 ,train loss: 0.0064, dev loss: 0.0194
# epoch 101.0000 ,train derror: inf, dev derror: 0.6367，train verror: inf, dev verror: 0.0554
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 102.0000 ,train loss: 0.0057, dev loss: 0.0191
# epoch 102.0000 ,train derror: inf, dev derror: 0.6275，train verror: inf, dev verror: 0.0547
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 103.0000 ,train loss: 0.0061, dev loss: 0.0189
# epoch 103.0000 ,train derror: inf, dev derror: 0.6223，train verror: inf, dev verror: 0.0546
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 104.0000 ,train loss: 0.0058, dev loss: 0.0191
# epoch 104.0000 ,train derror: inf, dev derror: 0.6161，train verror: inf, dev verror: 0.0550
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 105.0000 ,train loss: 0.0055, dev loss: 0.0189
# epoch 105.0000 ,train derror: inf, dev derror: 0.6239，train verror: inf, dev verror: 0.0544
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 106.0000 ,train loss: 0.0054, dev loss: 0.0189
# epoch 106.0000 ,train derror: inf, dev derror: 0.6068，train verror: inf, dev verror: 0.0546
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 107.0000 ,train loss: 0.0058, dev loss: 0.0191
# epoch 107.0000 ,train derror: inf, dev derror: 0.6019，train verror: inf, dev verror: 0.0548
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 108.0000 ,train loss: 0.0052, dev loss: 0.0190
# epoch 108.0000 ,train derror: inf, dev derror: 0.5990，train verror: inf, dev verror: 0.0549
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 109.0000 ,train loss: 0.0060, dev loss: 0.0188
# epoch 109.0000 ,train derror: inf, dev derror: 0.5883，train verror: inf, dev verror: 0.0548
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 110.0000 ,train loss: 0.0054, dev loss: 0.0189
# epoch 110.0000 ,train derror: inf, dev derror: 0.5878，train verror: inf, dev verror: 0.0545
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 111.0000 ,train loss: 0.0057, dev loss: 0.0190
# epoch 111.0000 ,train derror: inf, dev derror: 0.5857，train verror: inf, dev verror: 0.0548
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 112.0000 ,train loss: 0.0059, dev loss: 0.0189
# epoch 112.0000 ,train derror: inf, dev derror: 0.5786，train verror: inf, dev verror: 0.0547
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 113.0000 ,train loss: 0.0056, dev loss: 0.0187
# epoch 113.0000 ,train derror: inf, dev derror: 0.5747，train verror: inf, dev verror: 0.0541
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 114.0000 ,train loss: 0.0054, dev loss: 0.0191
# epoch 114.0000 ,train derror: inf, dev derror: 0.5850，train verror: inf, dev verror: 0.0552
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 115.0000 ,train loss: 0.0048, dev loss: 0.0185
# epoch 115.0000 ,train derror: inf, dev derror: 0.5671，train verror: inf, dev verror: 0.0541
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 116.0000 ,train loss: 0.0055, dev loss: 0.0187
# epoch 116.0000 ,train derror: inf, dev derror: 0.5709，train verror: inf, dev verror: 0.0545
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 117.0000 ,train loss: 0.0054, dev loss: 0.0189
# epoch 117.0000 ,train derror: inf, dev derror: 0.5657，train verror: inf, dev verror: 0.0547
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 118.0000 ,train loss: 0.0053, dev loss: 0.0187
# epoch 118.0000 ,train derror: inf, dev derror: 0.5621，train verror: inf, dev verror: 0.0544
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 119.0000 ,train loss: 0.0051, dev loss: 0.0189
# epoch 119.0000 ,train derror: inf, dev derror: 0.5578，train verror: inf, dev verror: 0.0547
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 120.0000 ,train loss: 0.0057, dev loss: 0.0188
# epoch 120.0000 ,train derror: inf, dev derror: 0.5611，train verror: inf, dev verror: 0.0548
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 121.0000 ,train loss: 0.0053, dev loss: 0.0188
# epoch 121.0000 ,train derror: inf, dev derror: 0.5571，train verror: inf, dev verror: 0.0545
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 122.0000 ,train loss: 0.0050, dev loss: 0.0186
# epoch 122.0000 ,train derror: inf, dev derror: 0.5516，train verror: inf, dev verror: 0.0543
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 123.0000 ,train loss: 0.0050, dev loss: 0.0190
# epoch 123.0000 ,train derror: inf, dev derror: 0.5557，train verror: inf, dev verror: 0.0550
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 124.0000 ,train loss: 0.0051, dev loss: 0.0187
# epoch 124.0000 ,train derror: inf, dev derror: 0.5496，train verror: inf, dev verror: 0.0545
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 125.0000 ,train loss: 0.0050, dev loss: 0.0187
# epoch 125.0000 ,train derror: inf, dev derror: 0.5426，train verror: inf, dev verror: 0.0544
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 126.0000 ,train loss: 0.0052, dev loss: 0.0188
# epoch 126.0000 ,train derror: inf, dev derror: 0.5391，train verror: inf, dev verror: 0.0545
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 127.0000 ,train loss: 0.0047, dev loss: 0.0185
# epoch 127.0000 ,train derror: inf, dev derror: 0.5313，train verror: inf, dev verror: 0.0540
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 128.0000 ,train loss: 0.0054, dev loss: 0.0186
# epoch 128.0000 ,train derror: inf, dev derror: 0.5377，train verror: inf, dev verror: 0.0544
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 129.0000 ,train loss: 0.0047, dev loss: 0.0188
# epoch 129.0000 ,train derror: inf, dev derror: 0.5376，train verror: inf, dev verror: 0.0546
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 130.0000 ,train loss: 0.0052, dev loss: 0.0192
# epoch 130.0000 ,train derror: inf, dev derror: 0.5292，train verror: inf, dev verror: 0.0550
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 131.0000 ,train loss: 0.0051, dev loss: 0.0188
# epoch 131.0000 ,train derror: inf, dev derror: 0.5278，train verror: inf, dev verror: 0.0545
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 132.0000 ,train loss: 0.0056, dev loss: 0.0185
# epoch 132.0000 ,train derror: inf, dev derror: 0.5276，train verror: inf, dev verror: 0.0543
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 133.0000 ,train loss: 0.0051, dev loss: 0.0187
# epoch 133.0000 ,train derror: inf, dev derror: 0.5275，train verror: inf, dev verror: 0.0547
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 134.0000 ,train loss: 0.0047, dev loss: 0.0189
# epoch 134.0000 ,train derror: inf, dev derror: 0.5338，train verror: inf, dev verror: 0.0550
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 135.0000 ,train loss: 0.0053, dev loss: 0.0187
# epoch 135.0000 ,train derror: inf, dev derror: 0.5236，train verror: inf, dev verror: 0.0544
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 136.0000 ,train loss: 0.0052, dev loss: 0.0187
# epoch 136.0000 ,train derror: inf, dev derror: 0.5165，train verror: inf, dev verror: 0.0544
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 137.0000 ,train loss: 0.0047, dev loss: 0.0188
# epoch 137.0000 ,train derror: inf, dev derror: 0.5208，train verror: inf, dev verror: 0.0546
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 138.0000 ,train loss: 0.0055, dev loss: 0.0185
# epoch 138.0000 ,train derror: inf, dev derror: 0.5167，train verror: inf, dev verror: 0.0543
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 139.0000 ,train loss: 0.0055, dev loss: 0.0187
# epoch 139.0000 ,train derror: inf, dev derror: 0.5156，train verror: inf, dev verror: 0.0545
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 140.0000 ,train loss: 0.0049, dev loss: 0.0186
# epoch 140.0000 ,train derror: inf, dev derror: 0.5184，train verror: inf, dev verror: 0.0546
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 141.0000 ,train loss: 0.0049, dev loss: 0.0185
# epoch 141.0000 ,train derror: inf, dev derror: 0.5201，train verror: inf, dev verror: 0.0544
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 142.0000 ,train loss: 0.0051, dev loss: 0.0182
# epoch 142.0000 ,train derror: inf, dev derror: 0.5089，train verror: inf, dev verror: 0.0539
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 143.0000 ,train loss: 0.0050, dev loss: 0.0184
# epoch 143.0000 ,train derror: inf, dev derror: 0.5090，train verror: inf, dev verror: 0.0542
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 144.0000 ,train loss: 0.0050, dev loss: 0.0185
# epoch 144.0000 ,train derror: inf, dev derror: 0.5048，train verror: inf, dev verror: 0.0543
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 145.0000 ,train loss: 0.0052, dev loss: 0.0183
# epoch 145.0000 ,train derror: inf, dev derror: 0.5005，train verror: inf, dev verror: 0.0541
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 146.0000 ,train loss: 0.0049, dev loss: 0.0187
# epoch 146.0000 ,train derror: inf, dev derror: 0.5103，train verror: inf, dev verror: 0.0548
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 147.0000 ,train loss: 0.0057, dev loss: 0.0182
# epoch 147.0000 ,train derror: inf, dev derror: 0.4972，train verror: inf, dev verror: 0.0538
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 148.0000 ,train loss: 0.0047, dev loss: 0.0186
# epoch 148.0000 ,train derror: inf, dev derror: 0.5073，train verror: inf, dev verror: 0.0546
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 149.0000 ,train loss: 0.0049, dev loss: 0.0188
# epoch 149.0000 ,train derror: inf, dev derror: 0.5040，train verror: inf, dev verror: 0.0548
# -------------------------------------------------------------------------------------------------------------------------------------

# %%
    t = np.arange(1, len(epoch_train_loss_list) + 1)
    #模型保存
    log_dir='/content/drive/My Drive/testCNN04201145.pth'
    state = {'net':model.state_dict(),  'epoch':epoch}
    torch.save(state, log_dir)

    plt.figure(figsize=(5,15))
    
    loss_plot = plt.subplot(3, 1, 1)
    plt.title('loss ')
    plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
    plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
    der_plot = plt.subplot(3, 1, 2)
    plt.title('distance error')
    plt.plot(t, epoch_train_derror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
    der_plot = plt.subplot(3, 1, 3)
    plt.title('Velocity error')
    plt.plot(t, epoch_train_verror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
    plt.show()
