# %% [markdown]
# <a href="https://colab.research.google.com/github/Ki-i/APRiL/blob/master/%E6%B5%8B%E8%AF%95%E9%83%A8%E5%88%86testCNN04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
workspace_dir = '.'
#!unzip -q "/content/drive/My Drive/crypko_data.zip" -d "{workspace_dir}/"

# %%
from torch.nn import Module
from torch import nn
import numpy as np
import math
import torch
from torch.nn import CrossEntropyLoss
from torch.nn import MSELoss
from torch.optim import SGD
from torch.utils.data import DataLoader, TensorDataset
import os
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import matplotlib.pyplot as plt
import sys
import scipy.io as scio
import pylab

# %%
class DnCNN(nn.Module):
    def __init__(self):
        super(DnCNN, self).__init__()
        channels=3
        num_of_layers=15
        kernel_size = 3
        padding = 1
        features = 64
        layers = []
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))
        for _ in range(num_of_layers-2):
            layers.append(nn.Conv2d(in_channels=features, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
            layers.append(nn.BatchNorm2d(features))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False))
 
        self.dncnn = nn.Sequential(*layers)
        self.fc1=nn.Linear( 3*50*100,6)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(6,6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练
    def forward(self, x):
        #print(x.size())
        y = self.dncnn(x)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu(y)
        y = self.fc2(y)
        #print(y.size())
        return y

# %%
class Model(Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(2, 32, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)
        self.conv3 = nn.Conv2d(64, 64, 5)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(64*2*9, 64)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(64, 6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练

    def forward(self, x):
        y = self.conv1(x)
        y = self.relu1(y)
        y = self.pool1(y)
        y = self.conv2(y)
        y = self.relu2(y)
        y = self.pool2(y)
        y = self.conv3(y)
        y = self.relu3(y)
        y = self.pool3(y)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu3(y)
        y = self.fc2(y)
        # y = self.relu4(y)
        # y = self.fc3(y)
        # y = self.relu5(y)
        return y

# %%
def get_data(dataset_path, fm, dev_ratio):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    #datalen = int(len(x_data) / 3)
    datalen=2500
    x = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str(i+2500)
        #print(xkey)
        x[i] = data[xkey]
        
        ykey = 'y' + str(i+2500)
        y[i] = data[ykey]#噪声
        y[i]=y[i]/[100.,100.,100.,10000.,10000.,10000.]
        #if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])
        

    data_size = len(y)
    train_size = int(data_size * (1 - dev_ratio))
    state = np.random.get_state()
    np.random.shuffle(x)
    np.random.set_state(state)
    np.random.shuffle(y)
    # print("train size:", train_size)
    # print("dev size:", data_size - train_size)
    x_train = x[:train_size]
    y_train = y[:train_size]
    x_dev = x[train_size:]
    y_dev = y[train_size:]
    return x_train, y_train, x_dev, y_dev

# %%
class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x, self.y = x, y
        self.data_size = len(self.y)
       

    def __len__(self):
        return self.data_size

    def __getitem__(self, item):
        '''
        这个函数是关键，通过item(索引)来取数据集中的数据，
        一般来说在这里才将图像数据加载入内存，之前存的是图像的保存路径
        '''
        ycut=self.y[item]
        #ycut=ycut[101:-6:400,1:-5:500]

        label = torch.from_numpy(ycut)
        #label = torch.reshape(label, (1, -1))
        xcut = self.x[item]
        #xcut = xcut[101:-6:400,1:-5:500]
        x = torch.from_numpy(xcut)
        #x=x.unsqueeze(0)
        #label=label.squeeze(0)
        x=x.float()
        label=label.float()
        x = torch.div(x, 2.55)
        #label = torch.div(label, 10000.)
        #print(x.size())
        #print(label.size())
        #label=torch.div(label, 255.)
        #print(label.size())
        return x, label

# %%
x=np.array([1,2,3,4])
x=x/4
print(x)
# Out:
# [0.25 0.5  0.75 1.  ]

# %%
def psnr(target_data, ref_data):
    # target:目标图像  ref:参考图像  scale:尺寸大小
    # assume RGB image
    #target_data = np.array(target)
    #target_data = target_data[scale:-scale, scale:-scale]

    #ref_data = np.array(ref)
    #ref_data = ref_data[scale:-scale, scale:-scale]
    im = ref_data.max()
    print('参考图像峰值', ref_data.max(), ref_data.min())
    print('实际图像峰值', target_data.max(), target_data.min())
    target_data = target_data * (ref_data.max() / target_data.max())
    #print('实际图像峰值', target_data.max(), target_data.min())
    diff = ref_data - target_data
    diff = diff.flatten('C')

    #rmse = math.sqrt(np.mean(diff ** 2.))
    #return 20 * math.log10(math.pow(im,2) / rmse)
    mse = np.mean(diff ** 2.)
    return 20 * math.log10(math.pow(im,2) / mse)

def ab_err(target_data, ref_data):
  diff = abs(ref_data - target_data)/ref_data
  diff=diff.cpu().data.numpy()
  tdiff=diff[0:,0:3]
  vdiff=diff[0:,3:6]
  #print(np.shape(tdiff))
  #print(np.shape(vdiff))
  num=0
  for i in range(1,len(diff)):
    for j in range(1,3):
      if (tdiff[i-1,j-1]<0.2) & (vdiff[i-1,j-1]<0.2):
        num=num+1
  terr = np.mean(tdiff)
  verr = np.mean(vdiff)
  acc = num/(3*np.shape(tdiff)[0])
  return terr,verr,acc

def vd_MSE(target_data, ref_data,line):
    diff = ref_data - target_data
    diff=diff.cpu().data.numpy()
    tdiff=diff[0:,0:3]
    vdiff=diff[0:,3:6]

    num=0
    sum=0
    for i in range(1,len(diff)):
      for j in range(1,3):
        sum=sum+1
        if (tdiff[i-1,j-1]<line) & (vdiff[i-1,j-1]<line):
          num=num+1
    acc = num/sum


    tdiff = tdiff.flatten('C')
    vdiff = vdiff.flatten('C')
    diff = diff.flatten('C')
    #rmse = math.sqrt(np.mean(diff ** 2.))
    #return 20 * math.log10(math.pow(im,2) / rmse)
    tmse = np.mean(tdiff ** 2.)
    vmse = np.mean(vdiff ** 2.)
    mse=np.mean(diff ** 2.)
  
    
    terr = np.mean(tdiff)
    verr = np.mean(vdiff)
    

    return tmse,vmse,acc,mse

# %%
if __name__ == '__main__':

    batch_size = 32
    lr=1e-3
    #lr=1e-4#loss:11.72 10.74
    #lr=1e-3#9.6519
    #lr=0.01#8.3690
    #lr=0.1#8.2 7.72 7.71 ..7156.7147
    log_dir='/content/drive/My Drive/model042103highSNR1.pth'
    #数据集加载
    dataset_path = '/content/drive/My Drive/'
    x_train, y_train, x_dev, y_dev = get_data(dataset_path, 'TrainData_MutiSNRnoMPI.mat', 0.2)
    print(np.shape(x_train))
    train_dataset = MyDataset(x_train, y_train)
    #print(train_dataset.size())
    train_loader = DataLoader(train_dataset, batch_size=batch_size)
  
    dev_dataset = MyDataset(x_dev, y_dev)
    dev_loader = DataLoader(dev_dataset, batch_size=batch_size)

    model = DnCNN()
    #model = Model()
    #模型加载
    start_epoch=0
    '''
    if os.path.exists(log_dir):
        checkpoint = torch.load(log_dir)
        model.load_state_dict(checkpoint['net'])
        start_epoch = checkpoint['epoch']
        print('加载 epoch {} 成功！'.format(start_epoch))
    else:
        start_epoch = 0
        print('无保存模型，将从头开始训练！')
    '''
    sgd = SGD(model.parameters(), lr)

    cost = CrossEntropyLoss()
    criterion = MSELoss(reduction='sum')
    epoch = 150
    use_GPU = True
    if use_GPU:
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")
    model.to(device)
    epoch_train_loss_list = []
    epoch_dev_loss_list = []
    epoch_train_acc_list = []
    epoch_dev_acc_list = []
    epoch_train_derror_list = []
    epoch_dev_derror_list = []
    epoch_train_verror_list = []
    epoch_dev_verror_list = []
    for _epoch in range(start_epoch+1,start_epoch+epoch):
        model.train()
        epoch_train_loss = 0
        epoch_dev_loss = 0
        epoch_train_acc = 0
        epoch_dev_acc = 0
        train_num=0
        dev_num = 0
        epoch_dev_derror=0
        epoch_dev_verror=0
        epoch_train_derror=0
        epoch_train_verror=0
        epoch_train_mse=0
        for idx, (train_x, train_label) in enumerate(train_loader):
            s = train_label.shape[0]
            sgd.zero_grad()
            #print(train_x.size())
            predict_y = model(train_x.to(device))

            loss = criterion(predict_y, train_label.to(device))/ (2 * len(train_x))
            #loss = criterion(predict_y, train_label.to(device))
            terror,verror,acc,mse=vd_MSE(predict_y,train_label.to(device),0.2)
            epoch_train_mse+=mse
            epoch_train_loss += loss.item()
            epoch_train_derror+=terror
            epoch_train_verror+=verror
            epoch_train_acc+=acc
            label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
            #acc = np.sum(label_pred == train_label.numpy())
            # print("batch Train acc:",acc / s)
            #epoch_train_acc += acc / s
            train_num+=1
            loss.backward()
            sgd.step()

        correct = 0
        _sum = 0
        model.eval()

        with torch.no_grad():
            for idx, (dev_x, dev_label) in enumerate(dev_loader):
                s = dev_label.shape[0]
                predict_y = model(dev_x.to(device))
                # print(predict_y[0], dev_label[0])
                #print(train_label.size())
                loss = criterion(predict_y, dev_label.to(device)) / (2 * len(train_x))
                #loss = criterion(predict_y, train_label.to(device))
                terror,verror,acc,mse=vd_MSE(predict_y,dev_label.to(device),0.2)
                
                epoch_dev_derror+=terror
                epoch_dev_verror+=verror
                epoch_dev_acc+=acc
                epoch_dev_loss += loss.item()
                label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
                # print("------")
                # print(label_pred)
                # print(dev_label.numpy())
                # print("------")
                #acc = np.sum(label_pred == dev_label.numpy())
                #batch_acc=acc / s
                dev_num+=1
                # print("batch_acc::",batch_acc)
                #epoch_dev_acc += acc / s
                # print("devacc", acc);
        epoch_train_loss_list.append(epoch_train_loss / train_num)
        epoch_dev_loss_list.append(epoch_dev_loss / dev_num)
        epoch_train_derror_list.append(epoch_train_derror / train_num)
        epoch_dev_derror_list.append(epoch_dev_derror / dev_num)
        epoch_train_verror_list.append(epoch_train_verror / train_num)
        epoch_dev_verror_list.append(epoch_dev_verror / dev_num)
        epoch_train_acc_list.append(epoch_train_acc / train_num)
        epoch_dev_acc_list.append(epoch_dev_acc / dev_num)

        #epoch_train_acc_list.append(epoch_train_acc / dev_num)
        #epoch_dev_acc_list.append(epoch_dev_acc / dev_num)
        print('-------------------------------------------------------------------------------------------------------------------------------------')
        print("epoch {:.4f} ,train loss: {:.4f}, dev loss: {:.4f},test mse: {:.4f}".format(_epoch, epoch_train_loss / train_num, epoch_dev_loss / dev_num,epoch_train_mse/train_num))
        print("epoch {:.4f} ,train derror: {:.4f}, dev derror: {:.4f}，train verror: {:.4f}, dev verror: {:.4f}".format(_epoch, epoch_train_derror / train_num, epoch_dev_derror / dev_num, epoch_train_verror / train_num, epoch_dev_verror / dev_num))
        print("epoch {:.4f} ,train acc: {:.4f}, dev acc: {:.4f}".format(_epoch, epoch_train_acc / train_num, epoch_dev_acc / dev_num))
        print('-------------------------------------------------------------------------------------------------------------------------------------')

    t = np.arange(1, len(epoch_train_loss_list) + 1)
    #模型保存
    
    state = {'net':model.state_dict(),  'epoch':epoch}
    torch.save(state, log_dir)

    plt.figure(figsize=(5,15))
    
    loss_plot = plt.subplot(3, 1, 1)
    plt.title('loss ')
    plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
    plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
    der_plot = plt.subplot(3, 1, 2)
    plt.title('distance error')
    plt.plot(t, epoch_train_derror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
    der_plot = plt.subplot(3, 1, 3)
    plt.title('Velocity error')
    plt.plot(t, epoch_train_verror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
    plt.show()
# Out:
# load data from path1: /content/drive/My Drive/
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (2000, 3, 50, 100)
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 1.0000 ,train loss: 6.6337, dev loss: 4.4822,test mse: 2.2112
# epoch 1.0000 ,train derror: 1.9153, dev derror: 0.8032，train verror: 2.5071, dev verror: 0.7234
# epoch 1.0000 ,train acc: 0.0794, dev acc: 0.0000
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 2.0000 ,train loss: 2.8408, dev loss: 0.4849,test mse: 0.9469
# epoch 2.0000 ,train derror: 0.7832, dev derror: 0.0344，train verror: 1.1106, dev verror: 0.1300
# epoch 2.0000 ,train acc: 0.3086, dev acc: 0.0901
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 3.0000 ,train loss: 2.2810, dev loss: 0.6555,test mse: 0.7603
# epoch 3.0000 ,train derror: 0.6679, dev derror: 0.0678，train verror: 0.8528, dev verror: 0.1546
# epoch 3.0000 ,train acc: 0.3350, dev acc: 0.0248
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 4.0000 ,train loss: 1.8370, dev loss: 0.6011,test mse: 0.6123
# epoch 4.0000 ,train derror: 0.5785, dev derror: 0.0858，train verror: 0.6462, dev verror: 0.1183
# epoch 4.0000 ,train acc: 0.4382, dev acc: 0.0291
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 5.0000 ,train loss: 1.7601, dev loss: 0.5692,test mse: 0.5867
# epoch 5.0000 ,train derror: 0.6093, dev derror: 0.0928，train verror: 0.5641, dev verror: 0.1002
# epoch 5.0000 ,train acc: 0.4441, dev acc: 0.0650
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 6.0000 ,train loss: 1.6337, dev loss: 0.3443,test mse: 0.5446
# epoch 6.0000 ,train derror: 0.5791, dev derror: 0.0596，train verror: 0.5101, dev verror: 0.0571
# epoch 6.0000 ,train acc: 0.4700, dev acc: 0.2397
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 7.0000 ,train loss: 1.4383, dev loss: 0.5531,test mse: 0.4794
# epoch 7.0000 ,train derror: 0.5229, dev derror: 0.1083，train verror: 0.4360, dev verror: 0.0793
# epoch 7.0000 ,train acc: 0.4777, dev acc: 0.1579
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 8.0000 ,train loss: 1.4503, dev loss: 1.2962,test mse: 0.4834
# epoch 8.0000 ,train derror: 0.5249, dev derror: 0.2415，train verror: 0.4420, dev verror: 0.1993
# epoch 8.0000 ,train acc: 0.4898, dev acc: 0.0050
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 9.0000 ,train loss: 1.3940, dev loss: 0.3379,test mse: 0.4647
# epoch 9.0000 ,train derror: 0.5111, dev derror: 0.0701，train verror: 0.4182, dev verror: 0.0445
# epoch 9.0000 ,train acc: 0.4736, dev acc: 0.2750
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 10.0000 ,train loss: 1.3890, dev loss: 0.5500,test mse: 0.4630
# epoch 10.0000 ,train derror: 0.5117, dev derror: 0.1102，train verror: 0.4143, dev verror: 0.0764
# epoch 10.0000 ,train acc: 0.4792, dev acc: 0.1186
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 11.0000 ,train loss: 1.3688, dev loss: 0.3171,test mse: 0.4563
# epoch 11.0000 ,train derror: 0.5064, dev derror: 0.0684，train verror: 0.4062, dev verror: 0.0391
# epoch 11.0000 ,train acc: 0.4874, dev acc: 0.2837
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 12.0000 ,train loss: 1.2913, dev loss: 0.3774,test mse: 0.4304
# epoch 12.0000 ,train derror: 0.4797, dev derror: 0.0776，train verror: 0.3811, dev verror: 0.0505
# epoch 12.0000 ,train acc: 0.4877, dev acc: 0.2462
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 13.0000 ,train loss: 1.3070, dev loss: 0.7680,test mse: 0.4357
# epoch 13.0000 ,train derror: 0.4926, dev derror: 0.1490，train verror: 0.3787, dev verror: 0.1121
# epoch 13.0000 ,train acc: 0.4837, dev acc: 0.0295
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 14.0000 ,train loss: 1.2428, dev loss: 0.5346,test mse: 0.4143
# epoch 14.0000 ,train derror: 0.4672, dev derror: 0.1082，train verror: 0.3613, dev verror: 0.0735
# epoch 14.0000 ,train acc: 0.4854, dev acc: 0.1023
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 15.0000 ,train loss: 1.1876, dev loss: 0.2899,test mse: 0.3959
# epoch 15.0000 ,train derror: 0.4442, dev derror: 0.0620，train verror: 0.3476, dev verror: 0.0363
# epoch 15.0000 ,train acc: 0.5025, dev acc: 0.3243
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 16.0000 ,train loss: 1.1712, dev loss: 0.4810,test mse: 0.3904
# epoch 16.0000 ,train derror: 0.4407, dev derror: 0.0971，train verror: 0.3401, dev verror: 0.0662
# epoch 16.0000 ,train acc: 0.4964, dev acc: 0.1200
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 17.0000 ,train loss: 1.1304, dev loss: 0.1889,test mse: 0.3768
# epoch 17.0000 ,train derror: 0.4262, dev derror: 0.0459，train verror: 0.3274, dev verror: 0.0182
# epoch 17.0000 ,train acc: 0.4975, dev acc: 0.5206
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 18.0000 ,train loss: 1.1267, dev loss: 0.4643,test mse: 0.3756
# epoch 18.0000 ,train derror: 0.4212, dev derror: 0.0976，train verror: 0.3299, dev verror: 0.0600
# epoch 18.0000 ,train acc: 0.4920, dev acc: 0.1399
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 19.0000 ,train loss: 1.1533, dev loss: 0.2918,test mse: 0.3844
# epoch 19.0000 ,train derror: 0.4394, dev derror: 0.0649，train verror: 0.3294, dev verror: 0.0342
# epoch 19.0000 ,train acc: 0.4892, dev acc: 0.3298
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 20.0000 ,train loss: 1.0514, dev loss: 0.4142,test mse: 0.3505
# epoch 20.0000 ,train derror: 0.3979, dev derror: 0.0853，train verror: 0.3030, dev verror: 0.0555
# epoch 20.0000 ,train acc: 0.4887, dev acc: 0.1791
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 21.0000 ,train loss: 0.9864, dev loss: 0.6653,test mse: 0.3288
# epoch 21.0000 ,train derror: 0.3703, dev derror: 0.1322，train verror: 0.2873, dev verror: 0.0939
# epoch 21.0000 ,train acc: 0.4886, dev acc: 0.0376
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 22.0000 ,train loss: 0.9994, dev loss: 0.1728,test mse: 0.3331
# epoch 22.0000 ,train derror: 0.3801, dev derror: 0.0386，train verror: 0.2861, dev verror: 0.0200
# epoch 22.0000 ,train acc: 0.4950, dev acc: 0.5526
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 23.0000 ,train loss: 0.9427, dev loss: 0.3423,test mse: 0.3142
# epoch 23.0000 ,train derror: 0.3569, dev derror: 0.0747，train verror: 0.2716, dev verror: 0.0415
# epoch 23.0000 ,train acc: 0.4859, dev acc: 0.2661
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 24.0000 ,train loss: 0.9943, dev loss: 0.4624,test mse: 0.3314
# epoch 24.0000 ,train derror: 0.3768, dev derror: 0.0958，train verror: 0.2861, dev verror: 0.0614
# epoch 24.0000 ,train acc: 0.4731, dev acc: 0.1322
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 25.0000 ,train loss: 0.9005, dev loss: 0.3444,test mse: 0.3002
# epoch 25.0000 ,train derror: 0.3452, dev derror: 0.0718，train verror: 0.2551, dev verror: 0.0451
# epoch 25.0000 ,train acc: 0.4759, dev acc: 0.2539
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 26.0000 ,train loss: 0.8875, dev loss: 0.4135,test mse: 0.2958
# epoch 26.0000 ,train derror: 0.3351, dev derror: 0.0848，train verror: 0.2566, dev verror: 0.0556
# epoch 26.0000 ,train acc: 0.4667, dev acc: 0.1540
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 27.0000 ,train loss: 0.8842, dev loss: 0.4335,test mse: 0.2947
# epoch 27.0000 ,train derror: 0.3368, dev derror: 0.0868，train verror: 0.2527, dev verror: 0.0604
# epoch 27.0000 ,train acc: 0.4680, dev acc: 0.1307
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 28.0000 ,train loss: 0.8795, dev loss: 0.2905,test mse: 0.2932
# epoch 28.0000 ,train derror: 0.3351, dev derror: 0.0638，train verror: 0.2512, dev verror: 0.0347
# epoch 28.0000 ,train acc: 0.4518, dev acc: 0.2999
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 29.0000 ,train loss: 0.8042, dev loss: 0.3525,test mse: 0.2681
# epoch 29.0000 ,train derror: 0.3053, dev derror: 0.0748，train verror: 0.2308, dev verror: 0.0448
# epoch 29.0000 ,train acc: 0.4540, dev acc: 0.2351
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 30.0000 ,train loss: 0.8213, dev loss: 0.2888,test mse: 0.2738
# epoch 30.0000 ,train derror: 0.3102, dev derror: 0.0618，train verror: 0.2374, dev verror: 0.0363
# epoch 30.0000 ,train acc: 0.4585, dev acc: 0.2951
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 31.0000 ,train loss: 0.7408, dev loss: 0.2106,test mse: 0.2469
# epoch 31.0000 ,train derror: 0.2797, dev derror: 0.0477，train verror: 0.2142, dev verror: 0.0238
# epoch 31.0000 ,train acc: 0.4541, dev acc: 0.4465
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 32.0000 ,train loss: 0.7605, dev loss: 0.3545,test mse: 0.2535
# epoch 32.0000 ,train derror: 0.2879, dev derror: 0.0752，train verror: 0.2191, dev verror: 0.0452
# epoch 32.0000 ,train acc: 0.4493, dev acc: 0.2215
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 33.0000 ,train loss: 0.7161, dev loss: 0.3499,test mse: 0.2387
# epoch 33.0000 ,train derror: 0.2696, dev derror: 0.0726，train verror: 0.2078, dev verror: 0.0463
# epoch 33.0000 ,train acc: 0.4475, dev acc: 0.1854
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 34.0000 ,train loss: 0.7273, dev loss: 0.2047,test mse: 0.2424
# epoch 34.0000 ,train derror: 0.2768, dev derror: 0.0455，train verror: 0.2081, dev verror: 0.0240
# epoch 34.0000 ,train acc: 0.4320, dev acc: 0.4445
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 35.0000 ,train loss: 0.7390, dev loss: 0.4594,test mse: 0.2463
# epoch 35.0000 ,train derror: 0.2823, dev derror: 0.0930，train verror: 0.2104, dev verror: 0.0631
# epoch 35.0000 ,train acc: 0.4264, dev acc: 0.1050
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 36.0000 ,train loss: 0.6721, dev loss: 0.4059,test mse: 0.2240
# epoch 36.0000 ,train derror: 0.2542, dev derror: 0.0856，train verror: 0.1939, dev verror: 0.0523
# epoch 36.0000 ,train acc: 0.4189, dev acc: 0.1627
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 37.0000 ,train loss: 0.6376, dev loss: 0.3712,test mse: 0.2125
# epoch 37.0000 ,train derror: 0.2397, dev derror: 0.0774，train verror: 0.1853, dev verror: 0.0487
# epoch 37.0000 ,train acc: 0.4092, dev acc: 0.1744
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 38.0000 ,train loss: 0.6387, dev loss: 0.1716,test mse: 0.2129
# epoch 38.0000 ,train derror: 0.2421, dev derror: 0.0396，train verror: 0.1837, dev verror: 0.0186
# epoch 38.0000 ,train acc: 0.3947, dev acc: 0.5364
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 39.0000 ,train loss: 0.6043, dev loss: 0.1213,test mse: 0.2014
# epoch 39.0000 ,train derror: 0.2275, dev derror: 0.0285，train verror: 0.1754, dev verror: 0.0126
# epoch 39.0000 ,train acc: 0.3997, dev acc: 0.6774
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 40.0000 ,train loss: 0.6195, dev loss: 0.2612,test mse: 0.2065
# epoch 40.0000 ,train derror: 0.2321, dev derror: 0.0568，train verror: 0.1809, dev verror: 0.0319
# epoch 40.0000 ,train acc: 0.3986, dev acc: 0.3330
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 41.0000 ,train loss: 0.5905, dev loss: 0.1665,test mse: 0.1968
# epoch 41.0000 ,train derror: 0.2172, dev derror: 0.0384，train verror: 0.1765, dev verror: 0.0181
# epoch 41.0000 ,train acc: 0.4059, dev acc: 0.5572
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 42.0000 ,train loss: 0.5525, dev loss: 0.2255,test mse: 0.1842
# epoch 42.0000 ,train derror: 0.2068, dev derror: 0.0488，train verror: 0.1615, dev verror: 0.0277
# epoch 42.0000 ,train acc: 0.4159, dev acc: 0.3988
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 43.0000 ,train loss: 0.5337, dev loss: 0.2304,test mse: 0.1779
# epoch 43.0000 ,train derror: 0.1956, dev derror: 0.0504，train verror: 0.1602, dev verror: 0.0277
# epoch 43.0000 ,train acc: 0.4209, dev acc: 0.3974
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 44.0000 ,train loss: 0.5546, dev loss: 0.4120,test mse: 0.1849
# epoch 44.0000 ,train derror: 0.2058, dev derror: 0.0820，train verror: 0.1639, dev verror: 0.0580
# epoch 44.0000 ,train acc: 0.4105, dev acc: 0.1412
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 45.0000 ,train loss: 0.5403, dev loss: 0.1392,test mse: 0.1801
# epoch 45.0000 ,train derror: 0.2000, dev derror: 0.0326，train verror: 0.1602, dev verror: 0.0146
# epoch 45.0000 ,train acc: 0.4162, dev acc: 0.6169
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 46.0000 ,train loss: 0.5131, dev loss: 0.3166,test mse: 0.1710
# epoch 46.0000 ,train derror: 0.1899, dev derror: 0.0665，train verror: 0.1521, dev verror: 0.0409
# epoch 46.0000 ,train acc: 0.4214, dev acc: 0.2269
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 47.0000 ,train loss: 0.5182, dev loss: 0.2103,test mse: 0.1727
# epoch 47.0000 ,train derror: 0.1909, dev derror: 0.0459，train verror: 0.1545, dev verror: 0.0255
# epoch 47.0000 ,train acc: 0.4150, dev acc: 0.4371
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 48.0000 ,train loss: 0.4962, dev loss: 0.2368,test mse: 0.1654
# epoch 48.0000 ,train derror: 0.1813, dev derror: 0.0504，train verror: 0.1495, dev verror: 0.0300
# epoch 48.0000 ,train acc: 0.4235, dev acc: 0.3640
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 49.0000 ,train loss: 0.4983, dev loss: 0.2875,test mse: 0.1661
# epoch 49.0000 ,train derror: 0.1813, dev derror: 0.0586，train verror: 0.1509, dev verror: 0.0390
# epoch 49.0000 ,train acc: 0.4302, dev acc: 0.2485
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 50.0000 ,train loss: 0.4773, dev loss: 0.1886,test mse: 0.1591
# epoch 50.0000 ,train derror: 0.1741, dev derror: 0.0407，train verror: 0.1441, dev verror: 0.0233
# epoch 50.0000 ,train acc: 0.4391, dev acc: 0.4563
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 51.0000 ,train loss: 0.4630, dev loss: 0.1720,test mse: 0.1543
# epoch 51.0000 ,train derror: 0.1677, dev derror: 0.0374，train verror: 0.1409, dev verror: 0.0209
# epoch 51.0000 ,train acc: 0.4331, dev acc: 0.5173
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 52.0000 ,train loss: 0.4718, dev loss: 0.1998,test mse: 0.1573
# epoch 52.0000 ,train derror: 0.1709, dev derror: 0.0426，train verror: 0.1436, dev verror: 0.0253
# epoch 52.0000 ,train acc: 0.4445, dev acc: 0.4335
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 53.0000 ,train loss: 0.4567, dev loss: 0.2225,test mse: 0.1522
# epoch 53.0000 ,train derror: 0.1637, dev derror: 0.0455，train verror: 0.1407, dev verror: 0.0300
# epoch 53.0000 ,train acc: 0.4516, dev acc: 0.3814
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 54.0000 ,train loss: 0.4395, dev loss: 0.2522,test mse: 0.1465
# epoch 54.0000 ,train derror: 0.1600, dev derror: 0.0538，train verror: 0.1330, dev verror: 0.0318
# epoch 54.0000 ,train acc: 0.4537, dev acc: 0.3565
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 55.0000 ,train loss: 0.4353, dev loss: 0.1348,test mse: 0.1451
# epoch 55.0000 ,train derror: 0.1591, dev derror: 0.0303，train verror: 0.1311, dev verror: 0.0154
# epoch 55.0000 ,train acc: 0.4550, dev acc: 0.6300
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 56.0000 ,train loss: 0.4300, dev loss: 0.3342,test mse: 0.1433
# epoch 56.0000 ,train derror: 0.1562, dev derror: 0.0660，train verror: 0.1305, dev verror: 0.0476
# epoch 56.0000 ,train acc: 0.4670, dev acc: 0.2109
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 57.0000 ,train loss: 0.4140, dev loss: 0.1917,test mse: 0.1380
# epoch 57.0000 ,train derror: 0.1494, dev derror: 0.0415，train verror: 0.1265, dev verror: 0.0236
# epoch 57.0000 ,train acc: 0.4617, dev acc: 0.4718
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 58.0000 ,train loss: 0.4014, dev loss: 0.2333,test mse: 0.1338
# epoch 58.0000 ,train derror: 0.1437, dev derror: 0.0483，train verror: 0.1239, dev verror: 0.0311
# epoch 58.0000 ,train acc: 0.4784, dev acc: 0.3519
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 59.0000 ,train loss: 0.4049, dev loss: 0.1241,test mse: 0.1350
# epoch 59.0000 ,train derror: 0.1449, dev derror: 0.0285，train verror: 0.1250, dev verror: 0.0137
# epoch 59.0000 ,train acc: 0.4743, dev acc: 0.6697
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 60.0000 ,train loss: 0.4068, dev loss: 0.2144,test mse: 0.1356
# epoch 60.0000 ,train derror: 0.1461, dev derror: 0.0464，train verror: 0.1251, dev verror: 0.0264
# epoch 60.0000 ,train acc: 0.4775, dev acc: 0.3993
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 61.0000 ,train loss: 0.3886, dev loss: 0.1662,test mse: 0.1295
# epoch 61.0000 ,train derror: 0.1404, dev derror: 0.0374，train verror: 0.1187, dev verror: 0.0190
# epoch 61.0000 ,train acc: 0.4723, dev acc: 0.5623
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 62.0000 ,train loss: 0.3668, dev loss: 0.1155,test mse: 0.1223
# epoch 62.0000 ,train derror: 0.1315, dev derror: 0.0263，train verror: 0.1131, dev verror: 0.0129
# epoch 62.0000 ,train acc: 0.4858, dev acc: 0.6820
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 63.0000 ,train loss: 0.3847, dev loss: 0.1887,test mse: 0.1282
# epoch 63.0000 ,train derror: 0.1371, dev derror: 0.0406，train verror: 0.1193, dev verror: 0.0234
# epoch 63.0000 ,train acc: 0.4859, dev acc: 0.4832
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 64.0000 ,train loss: 0.3734, dev loss: 0.1377,test mse: 0.1245
# epoch 64.0000 ,train derror: 0.1324, dev derror: 0.0304，train verror: 0.1165, dev verror: 0.0163
# epoch 64.0000 ,train acc: 0.4936, dev acc: 0.6218
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 65.0000 ,train loss: 0.3456, dev loss: 0.2848,test mse: 0.1152
# epoch 65.0000 ,train derror: 0.1239, dev derror: 0.0561，train verror: 0.1065, dev verror: 0.0409
# epoch 65.0000 ,train acc: 0.4852, dev acc: 0.2469
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 66.0000 ,train loss: 0.3331, dev loss: 0.1192,test mse: 0.1110
# epoch 66.0000 ,train derror: 0.1195, dev derror: 0.0275，train verror: 0.1026, dev verror: 0.0130
# epoch 66.0000 ,train acc: 0.4969, dev acc: 0.6834
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 67.0000 ,train loss: 0.3522, dev loss: 0.1783,test mse: 0.1174
# epoch 67.0000 ,train derror: 0.1269, dev derror: 0.0374，train verror: 0.1079, dev verror: 0.0231
# epoch 67.0000 ,train acc: 0.4962, dev acc: 0.4906
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 68.0000 ,train loss: 0.3462, dev loss: 0.1280,test mse: 0.1154
# epoch 68.0000 ,train derror: 0.1246, dev derror: 0.0287，train verror: 0.1062, dev verror: 0.0148
# epoch 68.0000 ,train acc: 0.5010, dev acc: 0.6525
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 69.0000 ,train loss: 0.3284, dev loss: 0.0983,test mse: 0.1095
# epoch 69.0000 ,train derror: 0.1179, dev derror: 0.0239，train verror: 0.1010, dev verror: 0.0095
# epoch 69.0000 ,train acc: 0.5119, dev acc: 0.7680
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 70.0000 ,train loss: 0.3269, dev loss: 0.1805,test mse: 0.1090
# epoch 70.0000 ,train derror: 0.1176, dev derror: 0.0389，train verror: 0.1004, dev verror: 0.0225
# epoch 70.0000 ,train acc: 0.5236, dev acc: 0.5077
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 71.0000 ,train loss: 0.3186, dev loss: 0.2392,test mse: 0.1062
# epoch 71.0000 ,train derror: 0.1147, dev derror: 0.0486，train verror: 0.0978, dev verror: 0.0328
# epoch 71.0000 ,train acc: 0.5131, dev acc: 0.3178
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 72.0000 ,train loss: 0.3108, dev loss: 0.2216,test mse: 0.1036
# epoch 72.0000 ,train derror: 0.1106, dev derror: 0.0459，train verror: 0.0966, dev verror: 0.0294
# epoch 72.0000 ,train acc: 0.5218, dev acc: 0.3644
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 73.0000 ,train loss: 0.3253, dev loss: 0.2106,test mse: 0.1084
# epoch 73.0000 ,train derror: 0.1174, dev derror: 0.0436，train verror: 0.0995, dev verror: 0.0279
# epoch 73.0000 ,train acc: 0.5126, dev acc: 0.3896
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 74.0000 ,train loss: 0.3132, dev loss: 0.1512,test mse: 0.1044
# epoch 74.0000 ,train derror: 0.1128, dev derror: 0.0324，train verror: 0.0960, dev verror: 0.0190
# epoch 74.0000 ,train acc: 0.5315, dev acc: 0.5561
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 75.0000 ,train loss: 0.2989, dev loss: 0.1472,test mse: 0.0996
# epoch 75.0000 ,train derror: 0.1072, dev derror: 0.0312，train verror: 0.0921, dev verror: 0.0188
# epoch 75.0000 ,train acc: 0.5323, dev acc: 0.5959
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 76.0000 ,train loss: 0.3018, dev loss: 0.1153,test mse: 0.1006
# epoch 76.0000 ,train derror: 0.1068, dev derror: 0.0262，train verror: 0.0944, dev verror: 0.0129
# epoch 76.0000 ,train acc: 0.5350, dev acc: 0.6988
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 77.0000 ,train loss: 0.2855, dev loss: 0.1539,test mse: 0.0952
# epoch 77.0000 ,train derror: 0.1007, dev derror: 0.0335，train verror: 0.0897, dev verror: 0.0187
# epoch 77.0000 ,train acc: 0.5464, dev acc: 0.5663
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 78.0000 ,train loss: 0.3107, dev loss: 0.1499,test mse: 0.1036
# epoch 78.0000 ,train derror: 0.1101, dev derror: 0.0323，train verror: 0.0970, dev verror: 0.0185
# epoch 78.0000 ,train acc: 0.5343, dev acc: 0.5744
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 79.0000 ,train loss: 0.2967, dev loss: 0.1947,test mse: 0.0989
# epoch 79.0000 ,train derror: 0.1069, dev derror: 0.0400，train verror: 0.0908, dev verror: 0.0260
# epoch 79.0000 ,train acc: 0.5419, dev acc: 0.4338
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 80.0000 ,train loss: 0.2935, dev loss: 0.0984,test mse: 0.0978
# epoch 80.0000 ,train derror: 0.1063, dev derror: 0.0223，train verror: 0.0893, dev verror: 0.0111
# epoch 80.0000 ,train acc: 0.5476, dev acc: 0.7656
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 81.0000 ,train loss: 0.2807, dev loss: 0.1683,test mse: 0.0936
# epoch 81.0000 ,train derror: 0.0994, dev derror: 0.0354，train verror: 0.0877, dev verror: 0.0216
# epoch 81.0000 ,train acc: 0.5491, dev acc: 0.5039
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 82.0000 ,train loss: 0.2609, dev loss: 0.1687,test mse: 0.0870
# epoch 82.0000 ,train derror: 0.0936, dev derror: 0.0358，train verror: 0.0803, dev verror: 0.0214
# epoch 82.0000 ,train acc: 0.5479, dev acc: 0.5110
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 83.0000 ,train loss: 0.2620, dev loss: 0.1366,test mse: 0.0873
# epoch 83.0000 ,train derror: 0.0929, dev derror: 0.0298，train verror: 0.0817, dev verror: 0.0165
# epoch 83.0000 ,train acc: 0.5504, dev acc: 0.5999
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 84.0000 ,train loss: 0.2686, dev loss: 0.1616,test mse: 0.0895
# epoch 84.0000 ,train derror: 0.0961, dev derror: 0.0346，train verror: 0.0829, dev verror: 0.0202
# epoch 84.0000 ,train acc: 0.5545, dev acc: 0.5328
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 85.0000 ,train loss: 0.2605, dev loss: 0.1314,test mse: 0.0868
# epoch 85.0000 ,train derror: 0.0933, dev derror: 0.0291，train verror: 0.0803, dev verror: 0.0154
# epoch 85.0000 ,train acc: 0.5602, dev acc: 0.6436
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 86.0000 ,train loss: 0.2659, dev loss: 0.1534,test mse: 0.0886
# epoch 86.0000 ,train derror: 0.0964, dev derror: 0.0333，train verror: 0.0809, dev verror: 0.0187
# epoch 86.0000 ,train acc: 0.5653, dev acc: 0.5681
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 87.0000 ,train loss: 0.2478, dev loss: 0.1538,test mse: 0.0826
# epoch 87.0000 ,train derror: 0.0895, dev derror: 0.0327，train verror: 0.0757, dev verror: 0.0195
# epoch 87.0000 ,train acc: 0.5643, dev acc: 0.5549
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 88.0000 ,train loss: 0.2440, dev loss: 0.1590,test mse: 0.0813
# epoch 88.0000 ,train derror: 0.0886, dev derror: 0.0338，train verror: 0.0741, dev verror: 0.0201
# epoch 88.0000 ,train acc: 0.5855, dev acc: 0.5463
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 89.0000 ,train loss: 0.2498, dev loss: 0.1217,test mse: 0.0833
# epoch 89.0000 ,train derror: 0.0901, dev derror: 0.0258，train verror: 0.0764, dev verror: 0.0155
# epoch 89.0000 ,train acc: 0.5735, dev acc: 0.6570
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 90.0000 ,train loss: 0.2392, dev loss: 0.1245,test mse: 0.0797
# epoch 90.0000 ,train derror: 0.0866, dev derror: 0.0268，train verror: 0.0729, dev verror: 0.0154
# epoch 90.0000 ,train acc: 0.5802, dev acc: 0.6637
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 91.0000 ,train loss: 0.2506, dev loss: 0.0912,test mse: 0.0835
# epoch 91.0000 ,train derror: 0.0888, dev derror: 0.0215，train verror: 0.0782, dev verror: 0.0094
# epoch 91.0000 ,train acc: 0.5636, dev acc: 0.7771
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 92.0000 ,train loss: 0.2305, dev loss: 0.1214,test mse: 0.0768
# epoch 92.0000 ,train derror: 0.0826, dev derror: 0.0273，train verror: 0.0711, dev verror: 0.0139
# epoch 92.0000 ,train acc: 0.5874, dev acc: 0.6690
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 93.0000 ,train loss: 0.2382, dev loss: 0.1409,test mse: 0.0794
# epoch 93.0000 ,train derror: 0.0856, dev derror: 0.0302，train verror: 0.0732, dev verror: 0.0176
# epoch 93.0000 ,train acc: 0.5755, dev acc: 0.6063
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 94.0000 ,train loss: 0.2325, dev loss: 0.1101,test mse: 0.0775
# epoch 94.0000 ,train derror: 0.0823, dev derror: 0.0257，train verror: 0.0727, dev verror: 0.0117
# epoch 94.0000 ,train acc: 0.5845, dev acc: 0.7221
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 95.0000 ,train loss: 0.2208, dev loss: 0.1373,test mse: 0.0736
# epoch 95.0000 ,train derror: 0.0796, dev derror: 0.0298，train verror: 0.0676, dev verror: 0.0168
# epoch 95.0000 ,train acc: 0.5853, dev acc: 0.6077
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 96.0000 ,train loss: 0.2168, dev loss: 0.1351,test mse: 0.0723
# epoch 96.0000 ,train derror: 0.0791, dev derror: 0.0288，train verror: 0.0654, dev verror: 0.0170
# epoch 96.0000 ,train acc: 0.5889, dev acc: 0.6009
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 97.0000 ,train loss: 0.2160, dev loss: 0.1143,test mse: 0.0720
# epoch 97.0000 ,train derror: 0.0795, dev derror: 0.0258，train verror: 0.0644, dev verror: 0.0130
# epoch 97.0000 ,train acc: 0.5899, dev acc: 0.6969
# -------------------------------------------------------------------------------------------------------------------------------------
# ...
# epoch 117.0000 ,train loss: 0.1624, dev loss: 0.0971,test mse: 0.0541
# epoch 117.0000 ,train derror: 0.0595, dev derror: 0.0222，train verror: 0.0488, dev verror: 0.0108
# epoch 117.0000 ,train acc: 0.6418, dev acc: 0.7650
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 118.0000 ,train loss: 0.1649, dev loss: 0.1038,test mse: 0.0550
# epoch 118.0000 ,train derror: 0.0597, dev derror: 0.0238，train verror: 0.0503, dev verror: 0.0113
# epoch 118.0000 ,train acc: 0.6388, dev acc: 0.7388
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 119.0000 ,train loss: 0.1669, dev loss: 0.1347,test mse: 0.0556
# epoch 119.0000 ,train derror: 0.0610, dev derror: 0.0289，train verror: 0.0503, dev verror: 0.0168
# epoch 119.0000 ,train acc: 0.6395, dev acc: 0.6099
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 120.0000 ,train loss: 0.1572, dev loss: 0.1032,test mse: 0.0524
# epoch 120.0000 ,train derror: 0.0564, dev derror: 0.0233，train verror: 0.0484, dev verror: 0.0117
# epoch 120.0000 ,train acc: 0.6470, dev acc: 0.7421
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 121.0000 ,train loss: 0.1577, dev loss: 0.1027,test mse: 0.0526
# epoch 121.0000 ,train derror: 0.0583, dev derror: 0.0233，train verror: 0.0468, dev verror: 0.0115
# epoch 121.0000 ,train acc: 0.6588, dev acc: 0.7418
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 122.0000 ,train loss: 0.1535, dev loss: 0.1097,test mse: 0.0512
# epoch 122.0000 ,train derror: 0.0556, dev derror: 0.0244，train verror: 0.0467, dev verror: 0.0128
# epoch 122.0000 ,train acc: 0.6462, dev acc: 0.7137
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 123.0000 ,train loss: 0.1611, dev loss: 0.1233,test mse: 0.0537
# epoch 123.0000 ,train derror: 0.0583, dev derror: 0.0266，train verror: 0.0491, dev verror: 0.0152
# epoch 123.0000 ,train acc: 0.6535, dev acc: 0.6499
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 124.0000 ,train loss: 0.1509, dev loss: 0.1108,test mse: 0.0503
# epoch 124.0000 ,train derror: 0.0528, dev derror: 0.0249，train verror: 0.0478, dev verror: 0.0127
# epoch 124.0000 ,train acc: 0.6624, dev acc: 0.7026
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 125.0000 ,train loss: 0.1444, dev loss: 0.1122,test mse: 0.0481
# epoch 125.0000 ,train derror: 0.0530, dev derror: 0.0246，train verror: 0.0433, dev verror: 0.0134
# epoch 125.0000 ,train acc: 0.6644, dev acc: 0.6952
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 126.0000 ,train loss: 0.1518, dev loss: 0.1185,test mse: 0.0506
# epoch 126.0000 ,train derror: 0.0550, dev derror: 0.0265，train verror: 0.0462, dev verror: 0.0137
# epoch 126.0000 ,train acc: 0.6534, dev acc: 0.6848
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 127.0000 ,train loss: 0.1471, dev loss: 0.1202,test mse: 0.0490
# epoch 127.0000 ,train derror: 0.0534, dev derror: 0.0267，train verror: 0.0447, dev verror: 0.0141
# epoch 127.0000 ,train acc: 0.6661, dev acc: 0.6677
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 128.0000 ,train loss: 0.1441, dev loss: 0.0966,test mse: 0.0480
# epoch 128.0000 ,train derror: 0.0524, dev derror: 0.0226，train verror: 0.0436, dev verror: 0.0102
# epoch 128.0000 ,train acc: 0.6652, dev acc: 0.7720
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 129.0000 ,train loss: 0.1432, dev loss: 0.1094,test mse: 0.0477
# epoch 129.0000 ,train derror: 0.0510, dev derror: 0.0245，train verror: 0.0445, dev verror: 0.0126
# epoch 129.0000 ,train acc: 0.6726, dev acc: 0.7221
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 130.0000 ,train loss: 0.1361, dev loss: 0.0983,test mse: 0.0454
# epoch 130.0000 ,train derror: 0.0491, dev derror: 0.0226，train verror: 0.0416, dev verror: 0.0107
# epoch 130.0000 ,train acc: 0.6712, dev acc: 0.7569
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 131.0000 ,train loss: 0.1434, dev loss: 0.1152,test mse: 0.0478
# epoch 131.0000 ,train derror: 0.0519, dev derror: 0.0255，train verror: 0.0437, dev verror: 0.0135
# epoch 131.0000 ,train acc: 0.6691, dev acc: 0.6908
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 132.0000 ,train loss: 0.1343, dev loss: 0.1314,test mse: 0.0448
# epoch 132.0000 ,train derror: 0.0472, dev derror: 0.0287，train verror: 0.0423, dev verror: 0.0159
# epoch 132.0000 ,train acc: 0.6772, dev acc: 0.6281
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 133.0000 ,train loss: 0.1455, dev loss: 0.1021,test mse: 0.0485
# epoch 133.0000 ,train derror: 0.0543, dev derror: 0.0232，train verror: 0.0427, dev verror: 0.0114
# epoch 133.0000 ,train acc: 0.6630, dev acc: 0.7367
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 134.0000 ,train loss: 0.1380, dev loss: 0.1193,test mse: 0.0460
# epoch 134.0000 ,train derror: 0.0499, dev derror: 0.0266，train verror: 0.0421, dev verror: 0.0139
# epoch 134.0000 ,train acc: 0.6724, dev acc: 0.6666
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 135.0000 ,train loss: 0.1375, dev loss: 0.0984,test mse: 0.0458
# epoch 135.0000 ,train derror: 0.0507, dev derror: 0.0226，train verror: 0.0409, dev verror: 0.0109
# epoch 135.0000 ,train acc: 0.6718, dev acc: 0.7609
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 136.0000 ,train loss: 0.1237, dev loss: 0.1020,test mse: 0.0412
# epoch 136.0000 ,train derror: 0.0441, dev derror: 0.0232，train verror: 0.0383, dev verror: 0.0114
# epoch 136.0000 ,train acc: 0.6859, dev acc: 0.7435
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 137.0000 ,train loss: 0.1277, dev loss: 0.1262,test mse: 0.0426
# epoch 137.0000 ,train derror: 0.0458, dev derror: 0.0275，train verror: 0.0394, dev verror: 0.0153
# epoch 137.0000 ,train acc: 0.6836, dev acc: 0.6529
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 138.0000 ,train loss: 0.1226, dev loss: 0.1087,test mse: 0.0409
# epoch 138.0000 ,train derror: 0.0438, dev derror: 0.0240，train verror: 0.0379, dev verror: 0.0129
# epoch 138.0000 ,train acc: 0.6836, dev acc: 0.7029
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 139.0000 ,train loss: 0.1307, dev loss: 0.0861,test mse: 0.0436
# epoch 139.0000 ,train derror: 0.0477, dev derror: 0.0204，train verror: 0.0395, dev verror: 0.0088
# epoch 139.0000 ,train acc: 0.6895, dev acc: 0.8103
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 140.0000 ,train loss: 0.1235, dev loss: 0.0975,test mse: 0.0412
# epoch 140.0000 ,train derror: 0.0439, dev derror: 0.0222，train verror: 0.0384, dev verror: 0.0109
# epoch 140.0000 ,train acc: 0.6881, dev acc: 0.7710
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 141.0000 ,train loss: 0.1181, dev loss: 0.1078,test mse: 0.0394
# epoch 141.0000 ,train derror: 0.0422, dev derror: 0.0241，train verror: 0.0366, dev verror: 0.0125
# epoch 141.0000 ,train acc: 0.6956, dev acc: 0.7163
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 142.0000 ,train loss: 0.1258, dev loss: 0.0937,test mse: 0.0419
# epoch 142.0000 ,train derror: 0.0450, dev derror: 0.0221，train verror: 0.0389, dev verror: 0.0097
# epoch 142.0000 ,train acc: 0.6844, dev acc: 0.7851
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 143.0000 ,train loss: 0.1218, dev loss: 0.1087,test mse: 0.0406
# epoch 143.0000 ,train derror: 0.0439, dev derror: 0.0245，train verror: 0.0373, dev verror: 0.0123
# epoch 143.0000 ,train acc: 0.6844, dev acc: 0.7066
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 144.0000 ,train loss: 0.1118, dev loss: 0.0966,test mse: 0.0373
# epoch 144.0000 ,train derror: 0.0410, dev derror: 0.0226，train verror: 0.0335, dev verror: 0.0102
# epoch 144.0000 ,train acc: 0.7031, dev acc: 0.7744
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 145.0000 ,train loss: 0.1173, dev loss: 0.0882,test mse: 0.0391
# epoch 145.0000 ,train derror: 0.0427, dev derror: 0.0206，train verror: 0.0355, dev verror: 0.0094
# epoch 145.0000 ,train acc: 0.6869, dev acc: 0.8049
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 146.0000 ,train loss: 0.1165, dev loss: 0.0845,test mse: 0.0388
# epoch 146.0000 ,train derror: 0.0424, dev derror: 0.0203，train verror: 0.0353, dev verror: 0.0083
# epoch 146.0000 ,train acc: 0.7016, dev acc: 0.8241
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 147.0000 ,train loss: 0.1105, dev loss: 0.0908,test mse: 0.0368
# epoch 147.0000 ,train derror: 0.0404, dev derror: 0.0209，train verror: 0.0332, dev verror: 0.0099
# epoch 147.0000 ,train acc: 0.7046, dev acc: 0.7932
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 148.0000 ,train loss: 0.1073, dev loss: 0.0958,test mse: 0.0358
# epoch 148.0000 ,train derror: 0.0393, dev derror: 0.0219，train verror: 0.0323, dev verror: 0.0106
# epoch 148.0000 ,train acc: 0.7175, dev acc: 0.7730
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 149.0000 ,train loss: 0.1133, dev loss: 0.1024,test mse: 0.0378
# epoch 149.0000 ,train derror: 0.0412, dev derror: 0.0229，train verror: 0.0343, dev verror: 0.0119
# epoch 149.0000 ,train acc: 0.7087, dev acc: 0.7516
# -------------------------------------------------------------------------------------------------------------------------------------

# %%
print(0:3)
# Out:
#   File "<ipython-input-18-b55870bed798>", line 1
#     print(0:3)
#            ^
# SyntaxError: invalid syntax

# %%
    
    

t = np.arange(1, len(epoch_train_loss_list) + 1)
#模型保存
log_dir='/content/drive/My Drive/model042103highSNR1.pth'
state = {'net':model.state_dict(),  'epoch':epoch}
torch.save(state, log_dir)

plt.figure(figsize=(5,15))

loss_plot = plt.subplot(3, 1, 1)
plt.title('loss ')
plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
der_plot = plt.subplot(3, 1, 2)
plt.title('distance error')
plt.plot(t, epoch_train_derror_list, color='red', label='train error')
plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
der_plot = plt.subplot(3, 1, 3)
plt.title('Velocity error')
plt.plot(t, epoch_train_verror_list, color='red', label='train error')
plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
plt.show()

# %%
def get_test_data(dataset_path, fm, SNR):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    # datalen = int(len(x_data) / 3)
    datalen = 500
    x_test = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y_test = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str((SNR + 5) * 500+i)
        print(xkey)
        x_test[i] = data[xkey]

        ykey = 'y' + str((SNR + 5) * 500+i)
        y_test[i] = data[ykey]  # 噪声
        y_test[i]=y_test[i]/[100.,100.,100.,10000.,10000.,10000.]
        # if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])

    return x_test, y_test

# %%
def get_test_data(dataset_path, fm, SNR):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    # datalen = int(len(x_data) / 3)
    datalen = 500
    x_test = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y_test = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str((SNR + 5) * 500+i)
        #print(xkey)
        x_test[i] = data[xkey]

        ykey = 'y' + str((SNR + 5) * 500+i)
        y_test[i] = data[ykey]  # 噪声
        y_test[i]=y_test[i]/[100.,100.,100.,10000.,10000.,10000.]
        # if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])

    return x_test, y_test


batch_size = 100
use_GPU = True
if use_GPU:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
model = DnCNN()
model.to(device)
print(torch.cuda.is_available())
log_dir = '/content/drive/My Drive/model042103highSNR.pth'
if os.path.exists(log_dir):
    checkpoint = torch.load(log_dir)
    model.load_state_dict(checkpoint['net'])
    start_epoch = checkpoint['epoch']
    print('加载 epoch {} 成功！'.format(start_epoch))
else:
    start_epoch = 0
    print('加载失败')
dataset_path = '/content/drive/My Drive/'
SNR_acc_list = []
for SNR in range(-5, 5):
    x_test, y_test = get_test_data(dataset_path, 'TrainData_MutiSNRnoMPI.mat', SNR)
    test_dataset = MyDataset(x_test, y_test)
    train_loader = DataLoader(test_dataset, batch_size=batch_size)


    test_num = 0
    test_derror=0
    test_verror=0
    test_acc = 0
    for idx, (test_x, test_label) in enumerate(train_loader):

        epoch_dev_acc = 0
        train_num = 0
        dev_num = 0
        epoch_dev_derror = 0
        epoch_dev_verror = 0
        epoch_train_derror = 0
        epoch_train_verror = 0
        s = test_label.shape[0]
        predict_y = model(test_x.to(device))
        # print(predict_y[0], dev_label[0])
        # loss = criterion(predict_y, train_label.to(device)) / (2 * len(train_x))
        terror, verror, acc ,mse= vd_MSE(predict_y, test_label.to(device),0.4)
        #print(acc)
        # print("------")
        # print(label_pred)
        # print(dev_label.numpy())
        # print("------")


        # print("batch_acc::",batch_acc)
        test_acc += acc
        test_derror += terror
        test_verror += verror
        test_num += 1
    #print(test_acc)
    #print(test_num )
        # print("------")
        # print(label_pred)
        # print(dev_label.numpy())
        # print("------")
        # acc = np.sum(label_pred == dev_label.numpy())
        # batch_acc=acc / s

    print(test_acc / test_num)
    SNR_acc_list.append(test_acc / test_num)
        # print("batch_acc::",batch_acc)
        # epoch_dev_acc += acc / s
        # print("devacc", acc);



plt.figure(figsize=(5, 5))
SNR = np.linspace(-5, 5, 10, endpoint=False)
SNR=np.arange(1, len(SNR_acc_list) + 1)
SNR=SNR-5
print(np.shape(SNR))
print(np.shape(SNR_acc_list))
plt.title('acc_SNR')
plt.plot(SNR, SNR_acc_list, color='blue', label='train loss')
plt.ylim(0,1)
plt.xlabel("SNR/dB")         
plt.ylabel("detect_acc") 
plt.show()
# Out:
# True
# 加载 epoch 150 成功！
# load data from path1: /content/drive/My Drive/
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 0.8979797979797979
# load data from path1: /content/drive/My Drive/
# 0.9212121212121211
# load data from path1: /content/drive/My Drive/
# 0.9141414141414141
# load data from path1: /content/drive/My Drive/
# 0.9121212121212121
# load data from path1: /content/drive/My Drive/
# 0.888888888888889
# load data from path1: /content/drive/My Drive/
# 0.9282828282828284
# load data from path1: /content/drive/My Drive/
# 0.8828282828282827
# load data from path1: /content/drive/My Drive/
# 0.9
# load data from path1: /content/drive/My Drive/
# 0.9141414141414141
# load data from path1: /content/drive/My Drive/
# 0.9202020202020202
# (10,)
# (10,)

# %%
# Out:
# [-5. -4. -3. -2. -1.  0.  1.  2.  3.  4.]
