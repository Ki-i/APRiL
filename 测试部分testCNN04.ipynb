# %% [markdown]
# <a href="https://colab.research.google.com/github/Ki-i/APRiL/blob/master/%E6%B5%8B%E8%AF%95%E9%83%A8%E5%88%86testCNN04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
workspace_dir = '.'
#!unzip -q "/content/drive/My Drive/crypko_data.zip" -d "{workspace_dir}/"

# %%
from torch.nn import Module
from torch import nn
import numpy as np
import math
import torch
from torch.nn import CrossEntropyLoss
from torch.nn import MSELoss
from torch.optim import SGD
from torch.utils.data import DataLoader, TensorDataset
import os
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import matplotlib.pyplot as plt
import sys
import scipy.io as scio
import pylab

# %%
class DnCNN(nn.Module):
    def __init__(self):
        super(DnCNN, self).__init__()
        channels=3
        num_of_layers=10
        kernel_size = 3
        padding = 1
        features = 64
        layers = []
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))
        for _ in range(num_of_layers-2):
            layers.append(nn.Conv2d(in_channels=features, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
            layers.append(nn.BatchNorm2d(features))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False))
 
        self.dncnn = nn.Sequential(*layers)
        self.fc1=nn.Linear( 3*50*100,6)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(6,6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练
    def forward(self, x):
        #print(x.size())
        y = self.dncnn(x)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu(y)
        y = self.fc2(y)
        #print(y.size())
        return y

# %%
class Model(Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(2, 32, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)
        self.conv3 = nn.Conv2d(64, 64, 5)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(64*2*9, 64)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(64, 6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练

    def forward(self, x):
        y = self.conv1(x)
        y = self.relu1(y)
        y = self.pool1(y)
        y = self.conv2(y)
        y = self.relu2(y)
        y = self.pool2(y)
        y = self.conv3(y)
        y = self.relu3(y)
        y = self.pool3(y)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu3(y)
        y = self.fc2(y)
        # y = self.relu4(y)
        # y = self.fc3(y)
        # y = self.relu5(y)
        return y

# %%
def get_data(dataset_path, fm, dev_ratio):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    #datalen = int(len(x_data) / 3)
    datalen=2500
    x = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str(i+2500)
        #print(xkey)
        x[i] = data[xkey]
        
        ykey = 'y' + str(i+2500)
        y[i] = data[ykey]#噪声
        y[i]=y[i]/[100.,100.,100.,10000.,10000.,10000.]
        #if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])
        

    data_size = len(y)
    train_size = int(data_size * (1 - dev_ratio))
    state = np.random.get_state()
    np.random.shuffle(x)
    np.random.set_state(state)
    np.random.shuffle(y)
    # print("train size:", train_size)
    # print("dev size:", data_size - train_size)
    x_train = x[:train_size]
    y_train = y[:train_size]
    x_dev = x[train_size:]
    y_dev = y[train_size:]
    return x_train, y_train, x_dev, y_dev

# %%
class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x, self.y = x, y
        self.data_size = len(self.y)
       

    def __len__(self):
        return self.data_size

    def __getitem__(self, item):
        '''
        这个函数是关键，通过item(索引)来取数据集中的数据，
        一般来说在这里才将图像数据加载入内存，之前存的是图像的保存路径
        '''
        ycut=self.y[item]
        #ycut=ycut[101:-6:400,1:-5:500]

        label = torch.from_numpy(ycut)
        #label = torch.reshape(label, (1, -1))
        xcut = self.x[item]
        #xcut = xcut[101:-6:400,1:-5:500]
        x = torch.from_numpy(xcut)
        #x=x.unsqueeze(0)
        #label=label.squeeze(0)
        x=x.float()
        label=label.float()
        x = torch.div(x, 2.55)
        #label = torch.div(label, 10000.)
        #print(x.size())
        #print(label.size())
        #label=torch.div(label, 255.)
        #print(label.size())
        return x, label

# %%
x=np.array([1,2,3,4])
x=x/4
print(x)
# Out:
# [0.25 0.5  0.75 1.  ]

# %%
def psnr(target_data, ref_data):
    # target:目标图像  ref:参考图像  scale:尺寸大小
    # assume RGB image
    #target_data = np.array(target)
    #target_data = target_data[scale:-scale, scale:-scale]

    #ref_data = np.array(ref)
    #ref_data = ref_data[scale:-scale, scale:-scale]
    im = ref_data.max()
    print('参考图像峰值', ref_data.max(), ref_data.min())
    print('实际图像峰值', target_data.max(), target_data.min())
    target_data = target_data * (ref_data.max() / target_data.max())
    #print('实际图像峰值', target_data.max(), target_data.min())
    diff = ref_data - target_data
    diff = diff.flatten('C')

    #rmse = math.sqrt(np.mean(diff ** 2.))
    #return 20 * math.log10(math.pow(im,2) / rmse)
    mse = np.mean(diff ** 2.)
    return 20 * math.log10(math.pow(im,2) / mse)

def ab_err(target_data, ref_data):
  diff = abs(ref_data - target_data)/ref_data
  diff=diff.cpu().data.numpy()
  tdiff=diff[0:,0:3]
  vdiff=diff[0:,3:6]
  #print(np.shape(tdiff))
  #print(np.shape(vdiff))
  num=0
  for i in range(1,len(diff)):
    for j in range(1,3):
      if (tdiff[i-1,j-1]<0.2) & (vdiff[i-1,j-1]<0.2):
        num=num+1
  terr = np.mean(tdiff)
  verr = np.mean(vdiff)
  acc = num/(3*np.shape(tdiff)[0])
  return terr,verr,acc

def vd_MSE(target_data, ref_data,line):
    diff = ref_data - target_data
    diff=diff.cpu().data.numpy()
    tdiff=diff[0:,0:3]
    vdiff=diff[0:,3:6]

    num=0
    sum=0
    for i in range(1,len(diff)):
      for j in range(1,3):
        sum=sum+1
        if (tdiff[i-1,j-1]<line) & (vdiff[i-1,j-1]<line):
          num=num+1
    acc = num/sum


    tdiff = tdiff.flatten('C')
    vdiff = vdiff.flatten('C')
    diff = diff.flatten('C')
    #rmse = math.sqrt(np.mean(diff ** 2.))
    #return 20 * math.log10(math.pow(im,2) / rmse)
    tmse = np.mean(tdiff ** 2.)
    vmse = np.mean(vdiff ** 2.)
    mse=np.mean(diff ** 2.)
  
    
    terr = np.mean(tdiff)
    verr = np.mean(vdiff)
    

    return tmse,vmse,acc,mse

# %%
if __name__ == '__main__':

    batch_size = 32
    lr=1e-3
    #lr=1e-4#loss:11.72 10.74
    #lr=1e-3#9.6519
    #lr=0.01#8.3690
    #lr=0.1#8.2 7.72 7.71 ..7156.7147
    log_dir='/content/drive/My Drive/model042103highSNR1.pth'
    #数据集加载
    dataset_path = '/content/drive/My Drive/'
    x_train, y_train, x_dev, y_dev = get_data(dataset_path, 'TrainData_MutiSNRnoMPI.mat', 0.2)
    print(np.shape(x_train))
    train_dataset = MyDataset(x_train, y_train)
    #print(train_dataset.size())
    train_loader = DataLoader(train_dataset, batch_size=batch_size)
  
    dev_dataset = MyDataset(x_dev, y_dev)
    dev_loader = DataLoader(dev_dataset, batch_size=batch_size)

    model = DnCNN()
    #model = Model()
    #模型加载
    start_epoch=0
    '''
    if os.path.exists(log_dir):
        checkpoint = torch.load(log_dir)
        model.load_state_dict(checkpoint['net'])
        start_epoch = checkpoint['epoch']
        print('加载 epoch {} 成功！'.format(start_epoch))
    else:
        start_epoch = 0
        print('无保存模型，将从头开始训练！')
    '''
    sgd = SGD(model.parameters(), lr)

    cost = CrossEntropyLoss()
    criterion = MSELoss(reduction='sum')
    epoch = 150
    use_GPU = True
    if use_GPU:
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")
    model.to(device)
    epoch_train_loss_list = []
    epoch_dev_loss_list = []
    epoch_train_acc_list = []
    epoch_dev_acc_list = []
    epoch_train_derror_list = []
    epoch_dev_derror_list = []
    epoch_train_verror_list = []
    epoch_dev_verror_list = []
    for _epoch in range(start_epoch+1,start_epoch+epoch):
        model.train()
        epoch_train_loss = 0
        epoch_dev_loss = 0
        epoch_train_acc = 0
        epoch_dev_acc = 0
        train_num=0
        dev_num = 0
        epoch_dev_derror=0
        epoch_dev_verror=0
        epoch_train_derror=0
        epoch_train_verror=0
        epoch_train_mse=0
        for idx, (train_x, train_label) in enumerate(train_loader):
            s = train_label.shape[0]
            sgd.zero_grad()
            #print(train_x.size())
            predict_y = model(train_x.to(device))

            loss = criterion(predict_y, train_label.to(device))/ (2 * len(train_x))
            #loss = criterion(predict_y, train_label.to(device))
            terror,verror,acc,mse=vd_MSE(predict_y,train_label.to(device),0.5)
            epoch_train_mse+=mse
            epoch_train_loss += loss.item()
            epoch_train_derror+=terror
            epoch_train_verror+=verror
            epoch_train_acc+=acc
            label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
            #acc = np.sum(label_pred == train_label.numpy())
            # print("batch Train acc:",acc / s)
            #epoch_train_acc += acc / s
            train_num+=1
            loss.backward()
            sgd.step()

        correct = 0
        _sum = 0
        model.eval()

        with torch.no_grad():
            for idx, (dev_x, dev_label) in enumerate(dev_loader):
                s = dev_label.shape[0]
                predict_y = model(dev_x.to(device))
                # print(predict_y[0], dev_label[0])
                #print(train_label.size())
                loss = criterion(predict_y, dev_label.to(device)) / (2 * len(train_x))
                #loss = criterion(predict_y, train_label.to(device))
                terror,verror,acc,mse=vd_MSE(predict_y,dev_label.to(device),0.5)
                
                epoch_dev_derror+=terror
                epoch_dev_verror+=verror
                epoch_dev_acc+=acc
                epoch_dev_loss += loss.item()
                label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
                # print("------")
                # print(label_pred)
                # print(dev_label.numpy())
                # print("------")
                #acc = np.sum(label_pred == dev_label.numpy())
                #batch_acc=acc / s
                dev_num+=1
                # print("batch_acc::",batch_acc)
                #epoch_dev_acc += acc / s
                # print("devacc", acc);
        epoch_train_loss_list.append(epoch_train_loss / train_num)
        epoch_dev_loss_list.append(epoch_dev_loss / dev_num)
        epoch_train_derror_list.append(epoch_train_derror / train_num)
        epoch_dev_derror_list.append(epoch_dev_derror / dev_num)
        epoch_train_verror_list.append(epoch_train_verror / train_num)
        epoch_dev_verror_list.append(epoch_dev_verror / dev_num)
        epoch_train_acc_list.append(epoch_train_acc / train_num)
        epoch_dev_acc_list.append(epoch_dev_acc / dev_num)

        #epoch_train_acc_list.append(epoch_train_acc / dev_num)
        #epoch_dev_acc_list.append(epoch_dev_acc / dev_num)
        print('-------------------------------------------------------------------------------------------------------------------------------------')
        print("epoch {:.4f} ,train loss: {:.4f}, dev loss: {:.4f},test mse: {:.4f}".format(_epoch, epoch_train_loss / train_num, epoch_dev_loss / dev_num,epoch_train_mse/train_num))
        print("epoch {:.4f} ,train derror: {:.4f}, dev derror: {:.4f}，train verror: {:.4f}, dev verror: {:.4f}".format(_epoch, epoch_train_derror / train_num, epoch_dev_derror / dev_num, epoch_train_verror / train_num, epoch_dev_verror / dev_num))
        print("epoch {:.4f} ,train acc: {:.4f}, dev acc: {:.4f}".format(_epoch, epoch_train_acc / train_num, epoch_dev_acc / dev_num))
        print('-------------------------------------------------------------------------------------------------------------------------------------')

    t = np.arange(1, len(epoch_train_loss_list) + 1)
    #模型保存
    
    state = {'net':model.state_dict(),  'epoch':epoch}
    torch.save(state, log_dir)

    plt.figure(figsize=(5,15))
    
    loss_plot = plt.subplot(3, 1, 1)
    plt.title('loss ')
    plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
    plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
    der_plot = plt.subplot(3, 1, 2)
    plt.title('distance error')
    plt.plot(t, epoch_train_derror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
    der_plot = plt.subplot(3, 1, 3)
    plt.title('Velocity error')
    plt.plot(t, epoch_train_verror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
    plt.show()
# Out:
# load data from path1: /content/drive/My Drive/
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (2000, 3, 50, 100)
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 1.0000 ,train loss: 4.5252, dev loss: 6.4200,test mse: 1.5084
# epoch 1.0000 ,train derror: 1.5170, dev derror: 1.2181，train verror: 1.4999, dev verror: 0.9760
# epoch 1.0000 ,train acc: 0.1436, dev acc: 0.0020
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 2.0000 ,train loss: 2.2999, dev loss: 0.3299,test mse: 0.7666
# epoch 2.0000 ,train derror: 0.8127, dev derror: 0.0730，train verror: 0.7206, dev verror: 0.0392
# epoch 2.0000 ,train acc: 0.3306, dev acc: 0.4373
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 3.0000 ,train loss: 1.9543, dev loss: 0.4359,test mse: 0.6514
# epoch 3.0000 ,train derror: 0.7022, dev derror: 0.0848，train verror: 0.6006, dev verror: 0.0636
# epoch 3.0000 ,train acc: 0.3635, dev acc: 0.2338
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 4.0000 ,train loss: 1.6412, dev loss: 0.7049,test mse: 0.5471
# epoch 4.0000 ,train derror: 0.5882, dev derror: 0.1320，train verror: 0.5060, dev verror: 0.1081
# epoch 4.0000 ,train acc: 0.4058, dev acc: 0.0416
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 5.0000 ,train loss: 1.4154, dev loss: 0.7192,test mse: 0.4718
# epoch 5.0000 ,train derror: 0.5143, dev derror: 0.1402，train verror: 0.4293, dev verror: 0.1051
# epoch 5.0000 ,train acc: 0.4318, dev acc: 0.0520
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 6.0000 ,train loss: 1.2932, dev loss: 1.5290,test mse: 0.4311
# epoch 6.0000 ,train derror: 0.4708, dev derror: 0.2958，train verror: 0.3913, dev verror: 0.2258
# epoch 6.0000 ,train acc: 0.4216, dev acc: 0.0020
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 7.0000 ,train loss: 1.2326, dev loss: 0.2404,test mse: 0.4109
# epoch 7.0000 ,train derror: 0.4531, dev derror: 0.0505，train verror: 0.3686, dev verror: 0.0312
# epoch 7.0000 ,train acc: 0.4218, dev acc: 0.4737
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 8.0000 ,train loss: 1.2597, dev loss: 1.5208,test mse: 0.4199
# epoch 8.0000 ,train derror: 0.4633, dev derror: 0.2939，train verror: 0.3766, dev verror: 0.2254
# epoch 8.0000 ,train acc: 0.4150, dev acc: 0.0020
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 9.0000 ,train loss: 1.1514, dev loss: 1.0543,test mse: 0.3838
# epoch 9.0000 ,train derror: 0.4280, dev derror: 0.2018，train verror: 0.3396, dev verror: 0.1575
# epoch 9.0000 ,train acc: 0.4127, dev acc: 0.0081
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 10.0000 ,train loss: 1.1462, dev loss: 1.1093,test mse: 0.3821
# epoch 10.0000 ,train derror: 0.4231, dev derror: 0.2204，train verror: 0.3410, dev verror: 0.1580
# epoch 10.0000 ,train acc: 0.4207, dev acc: 0.0020
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 11.0000 ,train loss: 1.0880, dev loss: 0.7799,test mse: 0.3627
# epoch 11.0000 ,train derror: 0.4026, dev derror: 0.1524，train verror: 0.3227, dev verror: 0.1134
# epoch 11.0000 ,train acc: 0.4166, dev acc: 0.0255
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 12.0000 ,train loss: 1.0411, dev loss: 0.1357,test mse: 0.3470
# epoch 12.0000 ,train derror: 0.3853, dev derror: 0.0314，train verror: 0.3087, dev verror: 0.0147
# epoch 12.0000 ,train acc: 0.4075, dev acc: 0.7496
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 13.0000 ,train loss: 1.0982, dev loss: 0.2414,test mse: 0.3661
# epoch 13.0000 ,train derror: 0.4073, dev derror: 0.0517，train verror: 0.3248, dev verror: 0.0306
# epoch 13.0000 ,train acc: 0.4141, dev acc: 0.4129
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 14.0000 ,train loss: 0.9596, dev loss: 0.1065,test mse: 0.3199
# epoch 14.0000 ,train derror: 0.3593, dev derror: 0.0250，train verror: 0.2804, dev verror: 0.0112
# epoch 14.0000 ,train acc: 0.4120, dev acc: 0.8799
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 15.0000 ,train loss: 1.0119, dev loss: 0.6781,test mse: 0.3373
# epoch 15.0000 ,train derror: 0.3755, dev derror: 0.1345，train verror: 0.2991, dev verror: 0.0970
# epoch 15.0000 ,train acc: 0.4254, dev acc: 0.0483
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 16.0000 ,train loss: 0.9820, dev loss: 0.2295,test mse: 0.3273
# epoch 16.0000 ,train derror: 0.3663, dev derror: 0.0496，train verror: 0.2884, dev verror: 0.0286
# epoch 16.0000 ,train acc: 0.4097, dev acc: 0.4297
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 17.0000 ,train loss: 0.9569, dev loss: 0.4363,test mse: 0.3190
# epoch 17.0000 ,train derror: 0.3528, dev derror: 0.0883，train verror: 0.2851, dev verror: 0.0604
# epoch 17.0000 ,train acc: 0.4111, dev acc: 0.1432
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 18.0000 ,train loss: 0.9556, dev loss: 0.5731,test mse: 0.3185
# epoch 18.0000 ,train derror: 0.3567, dev derror: 0.1138，train verror: 0.2804, dev verror: 0.0817
# epoch 18.0000 ,train acc: 0.4106, dev acc: 0.0711
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 19.0000 ,train loss: 0.9382, dev loss: 0.6119,test mse: 0.3127
# epoch 19.0000 ,train derror: 0.3493, dev derror: 0.1232，train verror: 0.2761, dev verror: 0.0858
# epoch 19.0000 ,train acc: 0.4022, dev acc: 0.0557
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 20.0000 ,train loss: 0.9064, dev loss: 0.3842,test mse: 0.3021
# epoch 20.0000 ,train derror: 0.3348, dev derror: 0.0792，train verror: 0.2694, dev verror: 0.0518
# epoch 20.0000 ,train acc: 0.4114, dev acc: 0.1888
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 21.0000 ,train loss: 0.9073, dev loss: 0.5809,test mse: 0.3024
# epoch 21.0000 ,train derror: 0.3407, dev derror: 0.1160，train verror: 0.2641, dev verror: 0.0824
# epoch 21.0000 ,train acc: 0.4077, dev acc: 0.0705
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 22.0000 ,train loss: 0.8749, dev loss: 0.3602,test mse: 0.2916
# epoch 22.0000 ,train derror: 0.3251, dev derror: 0.0747，train verror: 0.2582, dev verror: 0.0481
# epoch 22.0000 ,train acc: 0.4104, dev acc: 0.2157
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 23.0000 ,train loss: 0.8269, dev loss: 0.3463,test mse: 0.2756
# epoch 23.0000 ,train derror: 0.3086, dev derror: 0.0717，train verror: 0.2427, dev verror: 0.0464
# epoch 23.0000 ,train acc: 0.4052, dev acc: 0.2415
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 24.0000 ,train loss: 0.8843, dev loss: 0.3537,test mse: 0.2948
# epoch 24.0000 ,train derror: 0.3282, dev derror: 0.0730，train verror: 0.2614, dev verror: 0.0476
# epoch 24.0000 ,train acc: 0.4116, dev acc: 0.2346
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 25.0000 ,train loss: 0.8023, dev loss: 0.2232,test mse: 0.2674
# epoch 25.0000 ,train derror: 0.2985, dev derror: 0.0479，train verror: 0.2364, dev verror: 0.0280
# epoch 25.0000 ,train acc: 0.4229, dev acc: 0.4709
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 26.0000 ,train loss: 0.8387, dev loss: 0.3613,test mse: 0.2796
# epoch 26.0000 ,train derror: 0.3127, dev derror: 0.0739，train verror: 0.2465, dev verror: 0.0492
# epoch 26.0000 ,train acc: 0.4155, dev acc: 0.2217
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 27.0000 ,train loss: 0.7737, dev loss: 0.3312,test mse: 0.2579
# epoch 27.0000 ,train derror: 0.2883, dev derror: 0.0679，train verror: 0.2275, dev verror: 0.0451
# epoch 27.0000 ,train acc: 0.4129, dev acc: 0.3041
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 28.0000 ,train loss: 0.8803, dev loss: 0.3494,test mse: 0.2934
# epoch 28.0000 ,train derror: 0.3243, dev derror: 0.0719，train verror: 0.2625, dev verror: 0.0475
# epoch 28.0000 ,train acc: 0.4047, dev acc: 0.2372
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 29.0000 ,train loss: 0.7772, dev loss: 0.5569,test mse: 0.2591
# epoch 29.0000 ,train derror: 0.2880, dev derror: 0.1115，train verror: 0.2302, dev verror: 0.0788
# epoch 29.0000 ,train acc: 0.4135, dev acc: 0.0725
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 30.0000 ,train loss: 0.8140, dev loss: 0.2029,test mse: 0.2713
# epoch 30.0000 ,train derror: 0.3016, dev derror: 0.0444，train verror: 0.2410, dev verror: 0.0248
# epoch 30.0000 ,train acc: 0.4062, dev acc: 0.4955
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 31.0000 ,train loss: 0.7471, dev loss: 0.1854,test mse: 0.2490
# epoch 31.0000 ,train derror: 0.2747, dev derror: 0.0410，train verror: 0.2234, dev verror: 0.0223
# epoch 31.0000 ,train acc: 0.4223, dev acc: 0.5341
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 32.0000 ,train loss: 0.7355, dev loss: 0.3450,test mse: 0.2452
# epoch 32.0000 ,train derror: 0.2712, dev derror: 0.0717，train verror: 0.2191, dev verror: 0.0460
# epoch 32.0000 ,train acc: 0.4231, dev acc: 0.2332
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 33.0000 ,train loss: 0.7117, dev loss: 0.3290,test mse: 0.2372
# epoch 33.0000 ,train derror: 0.2657, dev derror: 0.0676，train verror: 0.2087, dev verror: 0.0446
# epoch 33.0000 ,train acc: 0.4207, dev acc: 0.2477
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 34.0000 ,train loss: 0.7415, dev loss: 0.2100,test mse: 0.2472
# epoch 34.0000 ,train derror: 0.2745, dev derror: 0.0447，train verror: 0.2198, dev verror: 0.0268
# epoch 34.0000 ,train acc: 0.4216, dev acc: 0.4689
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 35.0000 ,train loss: 0.7020, dev loss: 0.2800,test mse: 0.2340
# epoch 35.0000 ,train derror: 0.2580, dev derror: 0.0582，train verror: 0.2100, dev verror: 0.0372
# epoch 35.0000 ,train acc: 0.4227, dev acc: 0.3397
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 36.0000 ,train loss: 0.6998, dev loss: 0.2940,test mse: 0.2333
# epoch 36.0000 ,train derror: 0.2580, dev derror: 0.0609，train verror: 0.2086, dev verror: 0.0393
# epoch 36.0000 ,train acc: 0.4269, dev acc: 0.2949
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 37.0000 ,train loss: 0.7011, dev loss: 0.2644,test mse: 0.2337
# epoch 37.0000 ,train derror: 0.2605, dev derror: 0.0560，train verror: 0.2069, dev verror: 0.0343
# epoch 37.0000 ,train acc: 0.4321, dev acc: 0.3577
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 38.0000 ,train loss: 0.6887, dev loss: 0.2226,test mse: 0.2296
# epoch 38.0000 ,train derror: 0.2533, dev derror: 0.0470，train verror: 0.2058, dev verror: 0.0289
# epoch 38.0000 ,train acc: 0.4238, dev acc: 0.4378
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 39.0000 ,train loss: 0.6375, dev loss: 0.2827,test mse: 0.2125
# epoch 39.0000 ,train derror: 0.2339, dev derror: 0.0586，train verror: 0.1911, dev verror: 0.0380
# epoch 39.0000 ,train acc: 0.4311, dev acc: 0.3288
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 40.0000 ,train loss: 0.6225, dev loss: 0.2193,test mse: 0.2075
# epoch 40.0000 ,train derror: 0.2276, dev derror: 0.0460，train verror: 0.1874, dev verror: 0.0288
# epoch 40.0000 ,train acc: 0.4313, dev acc: 0.4461
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 41.0000 ,train loss: 0.6744, dev loss: 0.2901,test mse: 0.2248
# epoch 41.0000 ,train derror: 0.2478, dev derror: 0.0592，train verror: 0.2018, dev verror: 0.0398
# epoch 41.0000 ,train acc: 0.4334, dev acc: 0.3033
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 42.0000 ,train loss: 0.6435, dev loss: 0.3005,test mse: 0.2145
# epoch 42.0000 ,train derror: 0.2378, dev derror: 0.0613，train verror: 0.1912, dev verror: 0.0413
# epoch 42.0000 ,train acc: 0.4396, dev acc: 0.2818
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 43.0000 ,train loss: 0.6353, dev loss: 0.1826,test mse: 0.2118
# epoch 43.0000 ,train derror: 0.2326, dev derror: 0.0384，train verror: 0.1909, dev verror: 0.0238
# epoch 43.0000 ,train acc: 0.4365, dev acc: 0.5555
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 44.0000 ,train loss: 0.6211, dev loss: 0.2453,test mse: 0.2070
# epoch 44.0000 ,train derror: 0.2274, dev derror: 0.0503，train verror: 0.1867, dev verror: 0.0334
# epoch 44.0000 ,train acc: 0.4383, dev acc: 0.3824
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 45.0000 ,train loss: 0.6450, dev loss: 0.2637,test mse: 0.2150
# epoch 45.0000 ,train derror: 0.2385, dev derror: 0.0538，train verror: 0.1915, dev verror: 0.0362
# epoch 45.0000 ,train acc: 0.4429, dev acc: 0.3408
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 46.0000 ,train loss: 0.5875, dev loss: 0.2464,test mse: 0.1958
# epoch 46.0000 ,train derror: 0.2138, dev derror: 0.0496，train verror: 0.1778, dev verror: 0.0344
# epoch 46.0000 ,train acc: 0.4449, dev acc: 0.3800
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 47.0000 ,train loss: 0.5826, dev loss: 0.1338,test mse: 0.1942
# epoch 47.0000 ,train derror: 0.2122, dev derror: 0.0303，train verror: 0.1763, dev verror: 0.0152
# epoch 47.0000 ,train acc: 0.4444, dev acc: 0.7171
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 48.0000 ,train loss: 0.5912, dev loss: 0.3476,test mse: 0.1971
# epoch 48.0000 ,train derror: 0.2151, dev derror: 0.0712，train verror: 0.1791, dev verror: 0.0473
# epoch 48.0000 ,train acc: 0.4619, dev acc: 0.2121
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 49.0000 ,train loss: 0.5416, dev loss: 0.2224,test mse: 0.1805
# epoch 49.0000 ,train derror: 0.1971, dev derror: 0.0456，train verror: 0.1639, dev verror: 0.0301
# epoch 49.0000 ,train acc: 0.4544, dev acc: 0.4411
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 50.0000 ,train loss: 0.5697, dev loss: 0.3298,test mse: 0.1899
# epoch 50.0000 ,train derror: 0.2082, dev derror: 0.0662，train verror: 0.1716, dev verror: 0.0462
# epoch 50.0000 ,train acc: 0.4511, dev acc: 0.2268
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 51.0000 ,train loss: 0.5368, dev loss: 0.2454,test mse: 0.1789
# epoch 51.0000 ,train derror: 0.1965, dev derror: 0.0503，train verror: 0.1614, dev verror: 0.0334
# epoch 51.0000 ,train acc: 0.4549, dev acc: 0.3744
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 52.0000 ,train loss: 0.5438, dev loss: 0.2303,test mse: 0.1813
# epoch 52.0000 ,train derror: 0.1973, dev derror: 0.0470，train verror: 0.1652, dev verror: 0.0315
# epoch 52.0000 ,train acc: 0.4632, dev acc: 0.4174
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 53.0000 ,train loss: 0.5328, dev loss: 0.2021,test mse: 0.1776
# epoch 53.0000 ,train derror: 0.1931, dev derror: 0.0420，train verror: 0.1622, dev verror: 0.0269
# epoch 53.0000 ,train acc: 0.4657, dev acc: 0.4820
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 54.0000 ,train loss: 0.5202, dev loss: 0.2181,test mse: 0.1734
# epoch 54.0000 ,train derror: 0.1899, dev derror: 0.0459，train verror: 0.1569, dev verror: 0.0284
# epoch 54.0000 ,train acc: 0.4722, dev acc: 0.4565
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 55.0000 ,train loss: 0.5188, dev loss: 0.1547,test mse: 0.1729
# epoch 55.0000 ,train derror: 0.1869, dev derror: 0.0339，train verror: 0.1590, dev verror: 0.0187
# epoch 55.0000 ,train acc: 0.4701, dev acc: 0.6475
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 56.0000 ,train loss: 0.5178, dev loss: 0.1378,test mse: 0.1726
# epoch 56.0000 ,train derror: 0.1875, dev derror: 0.0300，train verror: 0.1577, dev verror: 0.0168
# epoch 56.0000 ,train acc: 0.4669, dev acc: 0.6989
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 57.0000 ,train loss: 0.4975, dev loss: 0.2412,test mse: 0.1658
# epoch 57.0000 ,train derror: 0.1812, dev derror: 0.0481，train verror: 0.1504, dev verror: 0.0342
# epoch 57.0000 ,train acc: 0.4831, dev acc: 0.3765
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 58.0000 ,train loss: 0.4823, dev loss: 0.1354,test mse: 0.1608
# epoch 58.0000 ,train derror: 0.1717, dev derror: 0.0288，train verror: 0.1499, dev verror: 0.0172
# epoch 58.0000 ,train acc: 0.4720, dev acc: 0.6975
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 59.0000 ,train loss: 0.4606, dev loss: 0.2190,test mse: 0.1535
# epoch 59.0000 ,train derror: 0.1640, dev derror: 0.0449，train verror: 0.1431, dev verror: 0.0297
# epoch 59.0000 ,train acc: 0.4905, dev acc: 0.4400
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 60.0000 ,train loss: 0.4887, dev loss: 0.2244,test mse: 0.1629
# epoch 60.0000 ,train derror: 0.1721, dev derror: 0.0451，train verror: 0.1537, dev verror: 0.0313
# epoch 60.0000 ,train acc: 0.4777, dev acc: 0.4153
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 61.0000 ,train loss: 0.4545, dev loss: 0.2640,test mse: 0.1515
# epoch 61.0000 ,train derror: 0.1635, dev derror: 0.0545，train verror: 0.1395, dev verror: 0.0354
# epoch 61.0000 ,train acc: 0.4876, dev acc: 0.3465
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 62.0000 ,train loss: 0.4330, dev loss: 0.2590,test mse: 0.1443
# epoch 62.0000 ,train derror: 0.1564, dev derror: 0.0526，train verror: 0.1322, dev verror: 0.0356
# epoch 62.0000 ,train acc: 0.4985, dev acc: 0.3449
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 63.0000 ,train loss: 0.4612, dev loss: 0.1860,test mse: 0.1537
# epoch 63.0000 ,train derror: 0.1654, dev derror: 0.0391，train verror: 0.1420, dev verror: 0.0242
# epoch 63.0000 ,train acc: 0.4913, dev acc: 0.5482
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 64.0000 ,train loss: 0.4461, dev loss: 0.1705,test mse: 0.1487
# epoch 64.0000 ,train derror: 0.1608, dev derror: 0.0352，train verror: 0.1366, dev verror: 0.0228
# epoch 64.0000 ,train acc: 0.4931, dev acc: 0.5680
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 65.0000 ,train loss: 0.4346, dev loss: 0.2047,test mse: 0.1449
# epoch 65.0000 ,train derror: 0.1578, dev derror: 0.0423，train verror: 0.1320, dev verror: 0.0274
# epoch 65.0000 ,train acc: 0.5057, dev acc: 0.4961
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 66.0000 ,train loss: 0.4170, dev loss: 0.1790,test mse: 0.1390
# epoch 66.0000 ,train derror: 0.1462, dev derror: 0.0376，train verror: 0.1318, dev verror: 0.0233
# epoch 66.0000 ,train acc: 0.5103, dev acc: 0.5653
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 67.0000 ,train loss: 0.3986, dev loss: 0.1332,test mse: 0.1329
# epoch 67.0000 ,train derror: 0.1435, dev derror: 0.0282，train verror: 0.1222, dev verror: 0.0171
# epoch 67.0000 ,train acc: 0.5189, dev acc: 0.7181
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 68.0000 ,train loss: 0.4002, dev loss: 0.2688,test mse: 0.1334
# epoch 68.0000 ,train derror: 0.1446, dev derror: 0.0545，train verror: 0.1222, dev verror: 0.0371
# epoch 68.0000 ,train acc: 0.5116, dev acc: 0.3170
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 69.0000 ,train loss: 0.4101, dev loss: 0.1733,test mse: 0.1367
# epoch 69.0000 ,train derror: 0.1468, dev derror: 0.0368，train verror: 0.1266, dev verror: 0.0222
# epoch 69.0000 ,train acc: 0.5090, dev acc: 0.5817
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 70.0000 ,train loss: 0.3978, dev loss: 0.1505,test mse: 0.1326
# epoch 70.0000 ,train derror: 0.1427, dev derror: 0.0323，train verror: 0.1225, dev verror: 0.0189
# epoch 70.0000 ,train acc: 0.5133, dev acc: 0.6624
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 71.0000 ,train loss: 0.3764, dev loss: 0.1533,test mse: 0.1255
# epoch 71.0000 ,train derror: 0.1363, dev derror: 0.0322，train verror: 0.1147, dev verror: 0.0199
# epoch 71.0000 ,train acc: 0.5189, dev acc: 0.6402
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 72.0000 ,train loss: 0.3843, dev loss: 0.1557,test mse: 0.1281
# epoch 72.0000 ,train derror: 0.1386, dev derror: 0.0335，train verror: 0.1176, dev verror: 0.0195
# epoch 72.0000 ,train acc: 0.5197, dev acc: 0.6398
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 73.0000 ,train loss: 0.3730, dev loss: 0.1654,test mse: 0.1243
# epoch 73.0000 ,train derror: 0.1348, dev derror: 0.0347，train verror: 0.1138, dev verror: 0.0215
# epoch 73.0000 ,train acc: 0.5218, dev acc: 0.6009
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 74.0000 ,train loss: 0.3590, dev loss: 0.1453,test mse: 0.1197
# epoch 74.0000 ,train derror: 0.1313, dev derror: 0.0314，train verror: 0.1081, dev verror: 0.0179
# epoch 74.0000 ,train acc: 0.5425, dev acc: 0.6895
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 75.0000 ,train loss: 0.3584, dev loss: 0.2020,test mse: 0.1195
# epoch 75.0000 ,train derror: 0.1321, dev derror: 0.0426，train verror: 0.1068, dev verror: 0.0262
# epoch 75.0000 ,train acc: 0.5387, dev acc: 0.5112
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 76.0000 ,train loss: 0.3530, dev loss: 0.1852,test mse: 0.1177
# epoch 76.0000 ,train derror: 0.1293, dev derror: 0.0392，train verror: 0.1060, dev verror: 0.0239
# epoch 76.0000 ,train acc: 0.5421, dev acc: 0.5545
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 77.0000 ,train loss: 0.3439, dev loss: 0.1751,test mse: 0.1146
# epoch 77.0000 ,train derror: 0.1242, dev derror: 0.0372，train verror: 0.1051, dev verror: 0.0224
# epoch 77.0000 ,train acc: 0.5402, dev acc: 0.5922
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 78.0000 ,train loss: 0.3339, dev loss: 0.1530,test mse: 0.1113
# epoch 78.0000 ,train derror: 0.1226, dev derror: 0.0331，train verror: 0.1000, dev verror: 0.0189
# epoch 78.0000 ,train acc: 0.5490, dev acc: 0.6569
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 79.0000 ,train loss: 0.3271, dev loss: 0.1671,test mse: 0.1090
# epoch 79.0000 ,train derror: 0.1213, dev derror: 0.0357，train verror: 0.0968, dev verror: 0.0211
# epoch 79.0000 ,train acc: 0.5584, dev acc: 0.6059
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 80.0000 ,train loss: 0.3161, dev loss: 0.1956,test mse: 0.1054
# epoch 80.0000 ,train derror: 0.1190, dev derror: 0.0412，train verror: 0.0917, dev verror: 0.0254
# epoch 80.0000 ,train acc: 0.5569, dev acc: 0.5236
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 81.0000 ,train loss: 0.3190, dev loss: 0.1491,test mse: 0.1063
# epoch 81.0000 ,train derror: 0.1157, dev derror: 0.0324，train verror: 0.0970, dev verror: 0.0183
# epoch 81.0000 ,train acc: 0.5561, dev acc: 0.6828
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 82.0000 ,train loss: 0.3158, dev loss: 0.1599,test mse: 0.1053
# epoch 82.0000 ,train derror: 0.1153, dev derror: 0.0338，train verror: 0.0953, dev verror: 0.0206
# epoch 82.0000 ,train acc: 0.5546, dev acc: 0.6382
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 83.0000 ,train loss: 0.3003, dev loss: 0.1279,test mse: 0.1001
# epoch 83.0000 ,train derror: 0.1095, dev derror: 0.0287，train verror: 0.0907, dev verror: 0.0147
# epoch 83.0000 ,train acc: 0.5641, dev acc: 0.7651
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 84.0000 ,train loss: 0.3165, dev loss: 0.1485,test mse: 0.1055
# epoch 84.0000 ,train derror: 0.1183, dev derror: 0.0327，train verror: 0.0928, dev verror: 0.0178
# epoch 84.0000 ,train acc: 0.5646, dev acc: 0.6919
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 85.0000 ,train loss: 0.2931, dev loss: 0.1487,test mse: 0.0977
# epoch 85.0000 ,train derror: 0.1094, dev derror: 0.0328，train verror: 0.0860, dev verror: 0.0177
# epoch 85.0000 ,train acc: 0.5743, dev acc: 0.6895
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 86.0000 ,train loss: 0.2828, dev loss: 0.1347,test mse: 0.0943
# epoch 86.0000 ,train derror: 0.1064, dev derror: 0.0293，train verror: 0.0822, dev verror: 0.0164
# epoch 86.0000 ,train acc: 0.5712, dev acc: 0.7318
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 87.0000 ,train loss: 0.2737, dev loss: 0.1869,test mse: 0.0912
# epoch 87.0000 ,train derror: 0.1002, dev derror: 0.0401，train verror: 0.0823, dev verror: 0.0235
# epoch 87.0000 ,train acc: 0.5936, dev acc: 0.5440
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 88.0000 ,train loss: 0.2859, dev loss: 0.1749,test mse: 0.0953
# epoch 88.0000 ,train derror: 0.1087, dev derror: 0.0374，train verror: 0.0819, dev verror: 0.0220
# epoch 88.0000 ,train acc: 0.5849, dev acc: 0.5924
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 89.0000 ,train loss: 0.2698, dev loss: 0.1445,test mse: 0.0899
# epoch 89.0000 ,train derror: 0.1026, dev derror: 0.0315，train verror: 0.0773, dev verror: 0.0176
# epoch 89.0000 ,train acc: 0.5941, dev acc: 0.6955
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 90.0000 ,train loss: 0.2797, dev loss: 0.1391,test mse: 0.0932
# epoch 90.0000 ,train derror: 0.1037, dev derror: 0.0304，train verror: 0.0828, dev verror: 0.0169
# epoch 90.0000 ,train acc: 0.5843, dev acc: 0.7167
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 91.0000 ,train loss: 0.2768, dev loss: 0.1559,test mse: 0.0923
# epoch 91.0000 ,train derror: 0.1046, dev derror: 0.0337，train verror: 0.0800, dev verror: 0.0193
# epoch 91.0000 ,train acc: 0.5841, dev acc: 0.6556
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 92.0000 ,train loss: 0.2723, dev loss: 0.1406,test mse: 0.0908
# epoch 92.0000 ,train derror: 0.1019, dev derror: 0.0316，train verror: 0.0796, dev verror: 0.0162
# epoch 92.0000 ,train acc: 0.5926, dev acc: 0.7187
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 93.0000 ,train loss: 0.2682, dev loss: 0.1159,test mse: 0.0894
# epoch 93.0000 ,train derror: 0.1024, dev derror: 0.0254，train verror: 0.0764, dev verror: 0.0139
# epoch 93.0000 ,train acc: 0.5912, dev acc: 0.8010
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 94.0000 ,train loss: 0.2548, dev loss: 0.1617,test mse: 0.0849
# epoch 94.0000 ,train derror: 0.0960, dev derror: 0.0348，train verror: 0.0739, dev verror: 0.0201
# epoch 94.0000 ,train acc: 0.5976, dev acc: 0.6404
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 95.0000 ,train loss: 0.2651, dev loss: 0.1378,test mse: 0.0884
# epoch 95.0000 ,train derror: 0.1007, dev derror: 0.0306，train verror: 0.0760, dev verror: 0.0162
# epoch 95.0000 ,train acc: 0.5935, dev acc: 0.7207
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 96.0000 ,train loss: 0.2539, dev loss: 0.1438,test mse: 0.0846
# epoch 96.0000 ,train derror: 0.0970, dev derror: 0.0317，train verror: 0.0723, dev verror: 0.0171
# epoch 96.0000 ,train acc: 0.6024, dev acc: 0.7147
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 97.0000 ,train loss: 0.2436, dev loss: 0.1376,test mse: 0.0812
# epoch 97.0000 ,train derror: 0.0932, dev derror: 0.0300，train verror: 0.0692, dev verror: 0.0167
# epoch 97.0000 ,train acc: 0.6027, dev acc: 0.7227
# -------------------------------------------------------------------------------------------------------------------------------------
# ...
# epoch 117.0000 ,train loss: 0.2044, dev loss: 0.1291,test mse: 0.0681
# epoch 117.0000 ,train derror: 0.0772, dev derror: 0.0286，train verror: 0.0591, dev verror: 0.0153
# epoch 117.0000 ,train acc: 0.6328, dev acc: 0.7651
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 118.0000 ,train loss: 0.2026, dev loss: 0.1079,test mse: 0.0675
# epoch 118.0000 ,train derror: 0.0766, dev derror: 0.0245，train verror: 0.0584, dev verror: 0.0121
# epoch 118.0000 ,train acc: 0.6270, dev acc: 0.8517
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 119.0000 ,train loss: 0.1861, dev loss: 0.1315,test mse: 0.0620
# epoch 119.0000 ,train derror: 0.0715, dev derror: 0.0295，train verror: 0.0526, dev verror: 0.0151
# epoch 119.0000 ,train acc: 0.6380, dev acc: 0.7711
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 120.0000 ,train loss: 0.1887, dev loss: 0.1327,test mse: 0.0629
# epoch 120.0000 ,train derror: 0.0743, dev derror: 0.0295，train verror: 0.0515, dev verror: 0.0156
# epoch 120.0000 ,train acc: 0.6493, dev acc: 0.7580
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 121.0000 ,train loss: 0.1876, dev loss: 0.1252,test mse: 0.0625
# epoch 121.0000 ,train derror: 0.0738, dev derror: 0.0279，train verror: 0.0513, dev verror: 0.0147
# epoch 121.0000 ,train acc: 0.6327, dev acc: 0.7872
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 122.0000 ,train loss: 0.1842, dev loss: 0.1154,test mse: 0.0614
# epoch 122.0000 ,train derror: 0.0701, dev derror: 0.0259，train verror: 0.0527, dev verror: 0.0132
# epoch 122.0000 ,train acc: 0.6394, dev acc: 0.8181
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 123.0000 ,train loss: 0.1701, dev loss: 0.1239,test mse: 0.0567
# epoch 123.0000 ,train derror: 0.0649, dev derror: 0.0279，train verror: 0.0485, dev verror: 0.0141
# epoch 123.0000 ,train acc: 0.6591, dev acc: 0.7842
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 124.0000 ,train loss: 0.1767, dev loss: 0.1071,test mse: 0.0589
# epoch 124.0000 ,train derror: 0.0675, dev derror: 0.0243，train verror: 0.0503, dev verror: 0.0121
# epoch 124.0000 ,train acc: 0.6392, dev acc: 0.8496
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 125.0000 ,train loss: 0.1701, dev loss: 0.1186,test mse: 0.0567
# epoch 125.0000 ,train derror: 0.0663, dev derror: 0.0265，train verror: 0.0472, dev verror: 0.0137
# epoch 125.0000 ,train acc: 0.6367, dev acc: 0.8054
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 126.0000 ,train loss: 0.1791, dev loss: 0.1049,test mse: 0.0597
# epoch 126.0000 ,train derror: 0.0694, dev derror: 0.0241，train verror: 0.0499, dev verror: 0.0114
# epoch 126.0000 ,train acc: 0.6427, dev acc: 0.8460
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 127.0000 ,train loss: 0.1700, dev loss: 0.1218,test mse: 0.0567
# epoch 127.0000 ,train derror: 0.0651, dev derror: 0.0270，train verror: 0.0483, dev verror: 0.0143
# epoch 127.0000 ,train acc: 0.6517, dev acc: 0.7943
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 128.0000 ,train loss: 0.1774, dev loss: 0.1250,test mse: 0.0591
# epoch 128.0000 ,train derror: 0.0685, dev derror: 0.0281，train verror: 0.0498, dev verror: 0.0143
# epoch 128.0000 ,train acc: 0.6427, dev acc: 0.7792
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 129.0000 ,train loss: 0.1778, dev loss: 0.1014,test mse: 0.0593
# epoch 129.0000 ,train derror: 0.0682, dev derror: 0.0230，train verror: 0.0503, dev verror: 0.0113
# epoch 129.0000 ,train acc: 0.6355, dev acc: 0.8638
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 130.0000 ,train loss: 0.1706, dev loss: 0.1283,test mse: 0.0569
# epoch 130.0000 ,train derror: 0.0670, dev derror: 0.0285，train verror: 0.0468, dev verror: 0.0151
# epoch 130.0000 ,train acc: 0.6432, dev acc: 0.7701
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 131.0000 ,train loss: 0.1611, dev loss: 0.1156,test mse: 0.0537
# epoch 131.0000 ,train derror: 0.0619, dev derror: 0.0260，train verror: 0.0455, dev verror: 0.0132
# epoch 131.0000 ,train acc: 0.6567, dev acc: 0.8074
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 132.0000 ,train loss: 0.1584, dev loss: 0.1164,test mse: 0.0528
# epoch 132.0000 ,train derror: 0.0615, dev derror: 0.0258，train verror: 0.0440, dev verror: 0.0137
# epoch 132.0000 ,train acc: 0.6550, dev acc: 0.8034
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 133.0000 ,train loss: 0.1604, dev loss: 0.1154,test mse: 0.0535
# epoch 133.0000 ,train derror: 0.0618, dev derror: 0.0261，train verror: 0.0451, dev verror: 0.0131
# epoch 133.0000 ,train acc: 0.6534, dev acc: 0.8044
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 134.0000 ,train loss: 0.1513, dev loss: 0.1171,test mse: 0.0504
# epoch 134.0000 ,train derror: 0.0585, dev derror: 0.0263，train verror: 0.0424, dev verror: 0.0135
# epoch 134.0000 ,train acc: 0.6614, dev acc: 0.7963
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 135.0000 ,train loss: 0.1623, dev loss: 0.1189,test mse: 0.0541
# epoch 135.0000 ,train derror: 0.0622, dev derror: 0.0268，train verror: 0.0460, dev verror: 0.0136
# epoch 135.0000 ,train acc: 0.6527, dev acc: 0.7893
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 136.0000 ,train loss: 0.1525, dev loss: 0.1103,test mse: 0.0508
# epoch 136.0000 ,train derror: 0.0586, dev derror: 0.0248，train verror: 0.0431, dev verror: 0.0126
# epoch 136.0000 ,train acc: 0.6555, dev acc: 0.8258
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 137.0000 ,train loss: 0.1583, dev loss: 0.1091,test mse: 0.0528
# epoch 137.0000 ,train derror: 0.0612, dev derror: 0.0244，train verror: 0.0444, dev verror: 0.0125
# epoch 137.0000 ,train acc: 0.6557, dev acc: 0.8319
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 138.0000 ,train loss: 0.1541, dev loss: 0.1172,test mse: 0.0514
# epoch 138.0000 ,train derror: 0.0592, dev derror: 0.0259，train verror: 0.0435, dev verror: 0.0138
# epoch 138.0000 ,train acc: 0.6523, dev acc: 0.8024
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 139.0000 ,train loss: 0.1486, dev loss: 0.1134,test mse: 0.0495
# epoch 139.0000 ,train derror: 0.0571, dev derror: 0.0255，train verror: 0.0419, dev verror: 0.0130
# epoch 139.0000 ,train acc: 0.6539, dev acc: 0.8157
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 140.0000 ,train loss: 0.1486, dev loss: 0.1111,test mse: 0.0495
# epoch 140.0000 ,train derror: 0.0576, dev derror: 0.0248，train verror: 0.0414, dev verror: 0.0129
# epoch 140.0000 ,train acc: 0.6648, dev acc: 0.8238
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 141.0000 ,train loss: 0.1463, dev loss: 0.1084,test mse: 0.0488
# epoch 141.0000 ,train derror: 0.0553, dev derror: 0.0244，train verror: 0.0422, dev verror: 0.0124
# epoch 141.0000 ,train acc: 0.6691, dev acc: 0.8359
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 142.0000 ,train loss: 0.1455, dev loss: 0.1325,test mse: 0.0485
# epoch 142.0000 ,train derror: 0.0572, dev derror: 0.0291，train verror: 0.0398, dev verror: 0.0158
# epoch 142.0000 ,train acc: 0.6648, dev acc: 0.7479
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 143.0000 ,train loss: 0.1431, dev loss: 0.1087,test mse: 0.0477
# epoch 143.0000 ,train derror: 0.0555, dev derror: 0.0245，train verror: 0.0399, dev verror: 0.0123
# epoch 143.0000 ,train acc: 0.6719, dev acc: 0.8349
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 144.0000 ,train loss: 0.1338, dev loss: 0.1057,test mse: 0.0446
# epoch 144.0000 ,train derror: 0.0504, dev derror: 0.0239，train verror: 0.0388, dev verror: 0.0120
# epoch 144.0000 ,train acc: 0.6664, dev acc: 0.8440
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 145.0000 ,train loss: 0.1386, dev loss: 0.1152,test mse: 0.0462
# epoch 145.0000 ,train derror: 0.0538, dev derror: 0.0259，train verror: 0.0386, dev verror: 0.0132
# epoch 145.0000 ,train acc: 0.6654, dev acc: 0.8107
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 146.0000 ,train loss: 0.1392, dev loss: 0.1202,test mse: 0.0464
# epoch 146.0000 ,train derror: 0.0531, dev derror: 0.0270，train verror: 0.0397, dev verror: 0.0138
# epoch 146.0000 ,train acc: 0.6747, dev acc: 0.7913
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 147.0000 ,train loss: 0.1366, dev loss: 0.1251,test mse: 0.0455
# epoch 147.0000 ,train derror: 0.0515, dev derror: 0.0274，train verror: 0.0396, dev verror: 0.0150
# epoch 147.0000 ,train acc: 0.6555, dev acc: 0.7731
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 148.0000 ,train loss: 0.1431, dev loss: 0.1152,test mse: 0.0477
# epoch 148.0000 ,train derror: 0.0560, dev derror: 0.0254，train verror: 0.0394, dev verror: 0.0137
# epoch 148.0000 ,train acc: 0.6545, dev acc: 0.8185
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 149.0000 ,train loss: 0.1291, dev loss: 0.1123,test mse: 0.0430
# epoch 149.0000 ,train derror: 0.0498, dev derror: 0.0251，train verror: 0.0363, dev verror: 0.0129
# epoch 149.0000 ,train acc: 0.6819, dev acc: 0.8248
# -------------------------------------------------------------------------------------------------------------------------------------

# %%
print(0:3)
# Out:
#   File "<ipython-input-18-b55870bed798>", line 1
#     print(0:3)
#            ^
# SyntaxError: invalid syntax

# %%
    
    

t = np.arange(1, len(epoch_train_loss_list) + 1)
#模型保存
log_dir='/content/drive/My Drive/model042103highSNR1.pth'
state = {'net':model.state_dict(),  'epoch':epoch}
torch.save(state, log_dir)

plt.figure(figsize=(5,15))

loss_plot = plt.subplot(3, 1, 1)
plt.title('loss ')
plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
der_plot = plt.subplot(3, 1, 2)
plt.title('distance error')
plt.plot(t, epoch_train_derror_list, color='red', label='train error')
plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
der_plot = plt.subplot(3, 1, 3)
plt.title('Velocity error')
plt.plot(t, epoch_train_verror_list, color='red', label='train error')
plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
plt.show()

# %%
def get_test_data(dataset_path, fm, SNR):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    # datalen = int(len(x_data) / 3)
    datalen = 500
    x_test = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y_test = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str((SNR + 5) * 500+i)
        print(xkey)
        x_test[i] = data[xkey]

        ykey = 'y' + str((SNR + 5) * 500+i)
        y_test[i] = data[ykey]  # 噪声
        y_test[i]=y_test[i]/[100.,100.,100.,10000.,10000.,10000.]
        # if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])

    return x_test, y_test

# %%
def get_test_data(dataset_path, fm, SNR):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    # datalen = int(len(x_data) / 3)
    datalen = 500
    x_test = np.zeros((datalen, 3, 50, 100), dtype=np.float)
    y_test = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str((SNR + 5) * 500+i)
        #print(xkey)
        x_test[i] = data[xkey]

        ykey = 'y' + str((SNR + 5) * 500+i)
        y_test[i] = data[ykey]  # 噪声
        y_test[i]=y_test[i]/[100.,100.,100.,10000.,10000.,10000.]
        # if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])

    return x_test, y_test


batch_size = 100
use_GPU = True
if use_GPU:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
model = DnCNN()
model.to(device)
print(torch.cuda.is_available())
log_dir = '/content/drive/My Drive/model042103highSNR.pth'
if os.path.exists(log_dir):
    checkpoint = torch.load(log_dir)
    model.load_state_dict(checkpoint['net'])
    start_epoch = checkpoint['epoch']
    print('加载 epoch {} 成功！'.format(start_epoch))
else:
    start_epoch = 0
    print('加载失败')
dataset_path = '/content/drive/My Drive/'
SNR_acc_list = []
for SNR in range(-5, 5):
    x_test, y_test = get_test_data(dataset_path, 'TrainData_MutiSNRnoMPI.mat', SNR)
    test_dataset = MyDataset(x_test, y_test)
    train_loader = DataLoader(test_dataset, batch_size=batch_size)


    test_num = 0
    test_derror=0
    test_verror=0
    test_acc = 0
    for idx, (test_x, test_label) in enumerate(train_loader):

        epoch_dev_acc = 0
        train_num = 0
        dev_num = 0
        epoch_dev_derror = 0
        epoch_dev_verror = 0
        epoch_train_derror = 0
        epoch_train_verror = 0
        s = test_label.shape[0]
        predict_y = model(test_x.to(device))
        # print(predict_y[0], dev_label[0])
        # loss = criterion(predict_y, train_label.to(device)) / (2 * len(train_x))
        terror, verror, acc ,mse= vd_MSE(predict_y, test_label.to(device),0.4)
        #print(acc)
        # print("------")
        # print(label_pred)
        # print(dev_label.numpy())
        # print("------")


        # print("batch_acc::",batch_acc)
        test_acc += acc
        test_derror += terror
        test_verror += verror
        test_num += 1
    #print(test_acc)
    #print(test_num )
        # print("------")
        # print(label_pred)
        # print(dev_label.numpy())
        # print("------")
        # acc = np.sum(label_pred == dev_label.numpy())
        # batch_acc=acc / s

    print(test_acc / test_num)
    SNR_acc_list.append(test_acc / test_num)
        # print("batch_acc::",batch_acc)
        # epoch_dev_acc += acc / s
        # print("devacc", acc);



plt.figure(figsize=(5, 5))
SNR = np.linspace(-5, 5, 10, endpoint=False)
SNR=np.arange(1, len(SNR_acc_list) + 1)
SNR=SNR-5
print(np.shape(SNR))
print(np.shape(SNR_acc_list))
plt.title('acc_SNR')
plt.plot(SNR, SNR_acc_list, color='blue', label='train loss')
plt.ylim(0,1)
plt.xlabel("SNR/dB")         
plt.ylabel("detect_acc") 
plt.show()
# Out:
# True
# 加载 epoch 150 成功！
# load data from path1: /content/drive/My Drive/
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 0.8979797979797979
# load data from path1: /content/drive/My Drive/
# 0.9212121212121211
# load data from path1: /content/drive/My Drive/
# 0.9141414141414141
# load data from path1: /content/drive/My Drive/
# 0.9121212121212121
# load data from path1: /content/drive/My Drive/
# 0.888888888888889
# load data from path1: /content/drive/My Drive/
# 0.9282828282828284
# load data from path1: /content/drive/My Drive/
# 0.8828282828282827
# load data from path1: /content/drive/My Drive/
# 0.9
# load data from path1: /content/drive/My Drive/
# 0.9141414141414141
# load data from path1: /content/drive/My Drive/
# 0.9202020202020202
# (10,)
# (10,)

# %%
# Out:
# [-5. -4. -3. -2. -1.  0.  1.  2.  3.  4.]
