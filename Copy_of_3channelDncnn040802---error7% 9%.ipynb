# %% [markdown]
# <a href="https://colab.research.google.com/github/Ki-i/APRiL/blob/master/Copy_of_3channelDncnn040802---error7%25%209%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
workspace_dir = '.'
#!unzip -q "/content/drive/My Drive/crypko_data.zip" -d "{workspace_dir}/"

# %%
from torch.nn import Module
from torch import nn
import numpy as np
import math
import torch
from torch.nn import CrossEntropyLoss
from torch.nn import MSELoss
from torch.optim import SGD
from torch.utils.data import DataLoader, TensorDataset
import os
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import matplotlib.pyplot as plt
import sys
import scipy.io as scio
import pylab

# %%
class DnCNN(nn.Module):
    def __init__(self):
        super(DnCNN, self).__init__()
        channels=2
        num_of_layers=10
        kernel_size = 3
        padding = 1
        features = 64
        layers = []
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))
        for _ in range(num_of_layers-2):
            layers.append(nn.Conv2d(in_channels=features, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
            layers.append(nn.BatchNorm2d(features))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False))
 
        self.dncnn = nn.Sequential(*layers)
        self.fc1=nn.Linear( 2*50*100,6)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(6,6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练
    def forward(self, x):
        y = self.dncnn(x)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu(y)
        y = self.fc2(y)
       
        return y

# %%
class Model(Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(2, 32, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)
        self.conv3 = nn.Conv2d(64, 64, 5)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(64*2*9, 64)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(64, 6)
        self.dropout = nn.Dropout(p=0.3)  # dropout训练

    def forward(self, x):
        y = self.conv1(x)
        y = self.relu1(y)
        y = self.pool1(y)
        y = self.conv2(y)
        y = self.relu2(y)
        y = self.pool2(y)
        y = self.conv3(y)
        y = self.relu3(y)
        y = self.pool3(y)
        #print(y.size())
        y = y.view(y.shape[0], -1)
        y = self.fc1(y)
        y = self.dropout(y)
        y = self.relu3(y)
        y = self.fc2(y)
        # y = self.relu4(y)
        # y = self.fc3(y)
        # y = self.relu5(y)
        return y

# %%
def get_data(dataset_path, fm, dev_ratio):
    print("load data from path1:", dataset_path)
    data = scio.loadmat(os.path.join(dataset_path, fm))

    del data['__header__']
    del data['__globals__']
    del data['__version__']
    # print(x_data.keys())
    # print(y_data.keys())
    # print(int(len(x_data)/3))
    #datalen = int(len(x_data) / 3)
    datalen=1000
    x = np.zeros((datalen, 2, 50, 100), dtype=np.float)
    y = np.zeros((datalen, 6), dtype=np.float)
    for i in range(1, datalen):
        xkey = 'x' + str(i)
        #print(xkey)
        x[i] = data[xkey]
        
        ykey = 'y' + str(i)
        y[i] = data[ykey]#噪声
        #if i==1:
        #  print(x[1])
        #  print(y_data[ykey])
        #  print(y[1])
        

    data_size = len(y)
    train_size = int(data_size * (1 - dev_ratio))
    state = np.random.get_state()
    np.random.shuffle(x)
    np.random.set_state(state)
    np.random.shuffle(y)
    # print("train size:", train_size)
    # print("dev size:", data_size - train_size)
    x_train = x[:train_size]
    y_train = y[:train_size]
    x_dev = x[train_size:]
    y_dev = y[train_size:]
    return x_train, y_train, x_dev, y_dev

# %%
class MyDataset(Dataset):
    def __init__(self, x, y):
        self.x, self.y = x, y
        self.data_size = len(self.y)
        #norm_mean = [0.485, 0.456, 0.406]
        #norm_std = [0.229, 0.224, 0.225]
        self.img_transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.ToTensor(),
            # transforms.Normalize(norm_mean, norm_std),
        ])

    def __len__(self):
        return self.data_size

    def __getitem__(self, item):
        '''
        这个函数是关键，通过item(索引)来取数据集中的数据，
        一般来说在这里才将图像数据加载入内存，之前存的是图像的保存路径
        '''
        ycut=self.y[item]
        #ycut=ycut[101:-6:400,1:-5:500]

        label = torch.from_numpy(ycut)
        #label = torch.reshape(label, (1, -1))
        xcut = self.x[item]
        #xcut = xcut[101:-6:400,1:-5:500]
        x = torch.from_numpy(xcut)
        #x=x.unsqueeze(0)
        #label=label.squeeze(0)
        x=x.float()
        label=label.float()
        x = torch.div(x, 255.)
        label = torch.div(label, 10000.)
        #print(x.size())
        #print(label.size())
        #label=torch.div(label, 255.)
        return x, label

# %%
x=np.array([1,2,3,4])
x=x/4
print(x)
# Out:
# [0.25 0.5  0.75 1.  ]

# %%
def psnr(target_data, ref_data):
    # target:目标图像  ref:参考图像  scale:尺寸大小
    # assume RGB image
    #target_data = np.array(target)
    #target_data = target_data[scale:-scale, scale:-scale]

    #ref_data = np.array(ref)
    #ref_data = ref_data[scale:-scale, scale:-scale]
    im = ref_data.max()
    print('参考图像峰值', ref_data.max(), ref_data.min())
    print('实际图像峰值', target_data.max(), target_data.min())
    target_data = target_data * (ref_data.max() / target_data.max())
    #print('实际图像峰值', target_data.max(), target_data.min())
    diff = ref_data - target_data
    diff = diff.flatten('C')

    #rmse = math.sqrt(np.mean(diff ** 2.))
    #return 20 * math.log10(math.pow(im,2) / rmse)
    mse = np.mean(diff ** 2.)
    return 20 * math.log10(math.pow(im,2) / mse)

def ab_err(target_data, ref_data):
  diff = abs(ref_data - target_data)/ref_data
  diff=diff.cpu().data.numpy()
  tdiff=diff[0:,0:2]
  vdiff=diff[0:,3:5]
  
  
  terr = np.mean(tdiff)
  verr = np.mean(vdiff)

  return terr,verr

# %%
if __name__ == '__main__':

    batch_size = 32
    lr=1e-2
    #lr=1e-4#loss:11.72 10.74
    #lr=1e-3#9.6519
    #lr=0.01#8.3690
    #lr=0.1#8.2 7.72 7.71 ..7156.7147
    log_dir='/content/drive/My Drive/model.pth'
    #数据集加载
    dataset_path = '/content/drive/My Drive/'
    x_train, y_train, x_dev, y_dev = get_data(dataset_path, 'TrainData.mat', 0.2)
    #print(x_train[0])
    train_dataset = MyDataset(x_train, y_train)
    train_loader = DataLoader(train_dataset, batch_size=batch_size)
    dev_dataset = MyDataset(x_dev, y_dev)
    dev_loader = DataLoader(train_dataset, batch_size=batch_size)

    model = DnCNN()
    #model = Model()
    #模型加载
    start_epoch=0
    '''
    if os.path.exists(log_dir):
        checkpoint = torch.load(log_dir)
        model.load_state_dict(checkpoint['net'])
        start_epoch = checkpoint['epoch']
        print('加载 epoch {} 成功！'.format(start_epoch))
    else:
        start_epoch = 0
        print('无保存模型，将从头开始训练！')
    '''
    sgd = SGD(model.parameters(), lr)

    cost = CrossEntropyLoss()
    criterion = MSELoss(reduction='sum')
    epoch = 150
    use_GPU = True
    if use_GPU:
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")
    model.to(device)
    epoch_train_loss_list = []
    epoch_dev_loss_list = []
    epoch_train_acc_list = []
    epoch_dev_acc_list = []
    epoch_train_derror_list = []
    epoch_dev_derror_list = []
    epoch_train_verror_list = []
    epoch_dev_verror_list = []
    for _epoch in range(start_epoch+1,start_epoch+epoch):
        model.train()
        epoch_train_loss = 0
        epoch_dev_loss = 0
        epoch_train_acc = 0
        epoch_dev_acc = 0
        train_num=0
        dev_num = 0
        epoch_dev_derror=0
        epoch_dev_verror=0
        epoch_train_derror=0
        epoch_train_verror=0
        for idx, (train_x, train_label) in enumerate(train_loader):
            s = train_label.shape[0]
            sgd.zero_grad()
            #print(train_x.size())
            predict_y = model(train_x.to(device))

            loss = criterion(predict_y, train_label.to(device))/ (2 * len(train_x))
            terror,verror=ab_err(predict_y,train_label.to(device))
            epoch_train_loss += loss.item()
            epoch_train_derror+=terror
            epoch_train_verror+=verror
            label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
            #acc = np.sum(label_pred == train_label.numpy())
            # print("batch Train acc:",acc / s)
            #epoch_train_acc += acc / s
            train_num+=1
            loss.backward()
            sgd.step()

        correct = 0
        _sum = 0
        model.eval()

        with torch.no_grad():
            for idx, (dev_x, dev_label) in enumerate(dev_loader):
                s = dev_label.shape[0]
                predict_y = model(dev_x.to(device))
                # print(predict_y[0], dev_label[0])
                loss = criterion(predict_y, train_label.to(device)) / (2 * len(train_x))
                terror,verror=ab_err(predict_y,train_label.to(device))
                
                epoch_dev_derror+=terror
                epoch_dev_verror+=verror
                epoch_dev_loss += loss.item()
                label_pred = np.argmax(predict_y.cpu().data.numpy(), axis=1)
                # print("------")
                # print(label_pred)
                # print(dev_label.numpy())
                # print("------")
                #acc = np.sum(label_pred == dev_label.numpy())
                #batch_acc=acc / s
                dev_num+=1
                # print("batch_acc::",batch_acc)
                #epoch_dev_acc += acc / s
                # print("devacc", acc);
        epoch_train_loss_list.append(epoch_train_loss / train_num)
        epoch_dev_loss_list.append(epoch_dev_loss / dev_num)
        epoch_train_derror_list.append(epoch_train_derror / train_num)
        epoch_dev_derror_list.append(epoch_dev_derror / dev_num)
        epoch_train_verror_list.append(epoch_train_verror / train_num)
        epoch_dev_verror_list.append(epoch_dev_verror / dev_num)

        #epoch_train_acc_list.append(epoch_train_acc / dev_num)
        #epoch_dev_acc_list.append(epoch_dev_acc / dev_num)
        print('-------------------------------------------------------------------------------------------------------------------------------------')
        print("epoch {:.4f} ,train loss: {:.4f}, dev loss: {:.4f}".format(_epoch, epoch_train_loss / train_num, epoch_dev_loss / dev_num))
        print("epoch {:.4f} ,train derror: {:.4f}, dev derror: {:.4f}，train verror: {:.4f}, dev verror: {:.4f}".format(_epoch, epoch_train_derror / train_num, epoch_dev_derror / dev_num, epoch_train_verror / train_num, epoch_dev_verror / dev_num))
        print('-------------------------------------------------------------------------------------------------------------------------------------')
        '''
        #绘图
        y_show = predict_y.reshape([batch_size, 50, 100])
        y_show = y_show.cpu().data.numpy()
        
        #print(train_x.size())
        x_show_x=train_x.squeeze(1)
        label_show=train_label.reshape([batch_size,50, 100])
        label_show=label_show.cpu().data.numpy()
        #print(x_show_x.size())
        x_show= x_show_x.numpy()
        y_show=x_show-y_show
        label_show=x_show-label_show
        #print(len(y_show[batch_size-1]))
        im1=1
        im2=int(batch_size/2)
        im3=batch_size-1
        pylab.figure(figsize=(10,10))
        plot = 'plot' + str(_epoch)
        plot = pylab.subplot(3, 3, 1)
        pylab.title('input_epcho'+str(_epoch)+'_image'+str(im1))
        pylab.imshow(np.asarray(x_show[im1]))
        plot = pylab.subplot(3, 3, 2)
        pylab.title('output_epcho'+str(_epoch)+'_image'+str(im1))
        pylab.imshow(np.asarray(y_show[im1]))
        plot = pylab.subplot(3, 3, 3)
        pylab.title('label__epcho'+str(_epoch)+'_image'+str(im1))
        pylab.imshow(np.asarray(label_show[im1]))
        plot = pylab.subplot(3, 3, 4)
        pylab.title('input__epcho'+str(_epoch)+'_image'+str(im2))
        pylab.imshow(np.asarray(x_show[im2]))
        plot = pylab.subplot(3, 3, 5)
        pylab.title('output__epcho'+str(_epoch)+'_image'+str(im2))
        pylab.imshow(np.asarray(y_show[im2]))
        plot = pylab.subplot(3, 3, 6)
        pylab.title('label__epcho'+str(_epoch)+'_image'+str(im2))
        pylab.imshow(np.asarray(label_show[im2]))
        plot = pylab.subplot(3, 3, 7)
        pylab.title('input__epcho'+str(_epoch)+'_image'+str(im3))
        pylab.imshow(np.asarray(x_show[im3]))
        plot = pylab.subplot(3, 3, 8)
        pylab.title('output__epcho'+str(_epoch)+'_image'+str(im3))
        pylab.imshow(np.asarray(y_show[im3]))
        plot = pylab.subplot(3, 3, 9)
        pylab.title('label__epcho'+str(_epoch)+'_image'+str(im3))
        pylab.imshow(np.asarray(label_show[im3]))
        pylab.show()
        '''
        '''
        y_show=predict_y.reshape([batch_size,50,100])
        print(y_show.size())
        #y_show=y_show.cpu().data.numpy()
        #imgs_sample = [y_show[i] for i in range(16,32)]
        y_show = y_show.unsqueeze(1)
        print(y_show.size())
        grid_img = torchvision.utils.make_grid(y_show.cpu(), nrow=4)
        plt.figure(figsize=(10, 10))  # 画图
        plt.imshow(grid_img)
        plt.show()  # 展示图片
        '''

    t = np.arange(1, len(epoch_train_loss_list) + 1)
    #模型保存
    
    state = {'net':model.state_dict(),  'epoch':epoch}
    torch.save(state, log_dir)

    plt.figure(figsize=(5,15))
    
    loss_plot = plt.subplot(3, 1, 1)
    plt.title('loss ')
    plt.plot(t, epoch_train_loss_list, color='red', label='train loss')
    plt.plot(t, epoch_dev_loss_list, color='skyblue', label='dev loss')
    der_plot = plt.subplot(3, 1, 2)
    plt.title('distance error')
    plt.plot(t, epoch_train_derror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_derror_list, color='blue', label='dev error')
    der_plot = plt.subplot(3, 1, 3)
    plt.title('Velocity error')
    plt.plot(t, epoch_train_verror_list, color='red', label='train error')
    plt.plot(t, epoch_dev_verror_list, color='blue', label='dev error')
    plt.show()
# Out:
# load data from path1: /content/drive/My Drive/
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 1.0000 ,train loss: 3.2936, dev loss: 2.4780
# epoch 1.0000 ,train derror: inf, dev derror: 2.8705，train verror: inf, dev verror: 0.7436
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 2.0000 ,train loss: 1.9878, dev loss: 1.5004
# epoch 2.0000 ,train derror: inf, dev derror: 2.2327，train verror: inf, dev verror: 0.5774
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 3.0000 ,train loss: 1.2093, dev loss: 0.9094
# epoch 3.0000 ,train derror: inf, dev derror: 1.7366，train verror: inf, dev verror: 0.4481
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 4.0000 ,train loss: 0.7383, dev loss: 0.5523
# epoch 4.0000 ,train derror: inf, dev derror: 1.3508，train verror: inf, dev verror: 0.3475
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 5.0000 ,train loss: 0.4533, dev loss: 0.3365
# epoch 5.0000 ,train derror: inf, dev derror: 1.0507，train verror: inf, dev verror: 0.2693
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 6.0000 ,train loss: 0.2808, dev loss: 0.2062
# epoch 6.0000 ,train derror: inf, dev derror: 0.8172，train verror: inf, dev verror: 0.2084
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 7.0000 ,train loss: 0.1765, dev loss: 0.1275
# epoch 7.0000 ,train derror: inf, dev derror: 0.6357，train verror: inf, dev verror: 0.1611
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 8.0000 ,train loss: 0.1134, dev loss: 0.0801
# epoch 8.0000 ,train derror: inf, dev derror: 0.4944，train verror: inf, dev verror: 0.1243
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 9.0000 ,train loss: 0.0752, dev loss: 0.0515
# epoch 9.0000 ,train derror: inf, dev derror: 0.3846，train verror: inf, dev verror: 0.0957
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 10.0000 ,train loss: 0.0521, dev loss: 0.0343
# epoch 10.0000 ,train derror: inf, dev derror: 0.2991，train verror: inf, dev verror: 0.0739
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 11.0000 ,train loss: 0.0381, dev loss: 0.0239
# epoch 11.0000 ,train derror: inf, dev derror: 0.2327，train verror: inf, dev verror: 0.0604
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 12.0000 ,train loss: 0.0297, dev loss: 0.0177
# epoch 12.0000 ,train derror: inf, dev derror: 0.1810，train verror: inf, dev verror: 0.0512
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 13.0000 ,train loss: 0.0245, dev loss: 0.0140
# epoch 13.0000 ,train derror: inf, dev derror: 0.1422，train verror: inf, dev verror: 0.0454
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 14.0000 ,train loss: 0.0214, dev loss: 0.0118
# epoch 14.0000 ,train derror: inf, dev derror: 0.1167，train verror: inf, dev verror: 0.0418
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 15.0000 ,train loss: 0.0196, dev loss: 0.0104
# epoch 15.0000 ,train derror: inf, dev derror: 0.1019，train verror: inf, dev verror: 0.0396
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 16.0000 ,train loss: 0.0184, dev loss: 0.0097
# epoch 16.0000 ,train derror: inf, dev derror: 0.0931，train verror: inf, dev verror: 0.0384
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 17.0000 ,train loss: 0.0177, dev loss: 0.0092
# epoch 17.0000 ,train derror: inf, dev derror: 0.0879，train verror: inf, dev verror: 0.0379
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 18.0000 ,train loss: 0.0173, dev loss: 0.0089
# epoch 18.0000 ,train derror: inf, dev derror: 0.0841，train verror: inf, dev verror: 0.0377
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 19.0000 ,train loss: 0.0171, dev loss: 0.0088
# epoch 19.0000 ,train derror: inf, dev derror: 0.0817，train verror: inf, dev verror: 0.0375
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 20.0000 ,train loss: 0.0169, dev loss: 0.0087
# epoch 20.0000 ,train derror: inf, dev derror: 0.0803，train verror: inf, dev verror: 0.0373
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 21.0000 ,train loss: 0.0168, dev loss: 0.0087
# epoch 21.0000 ,train derror: inf, dev derror: 0.0794，train verror: inf, dev verror: 0.0372
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 22.0000 ,train loss: 0.0168, dev loss: 0.0086
# epoch 22.0000 ,train derror: inf, dev derror: 0.0789，train verror: inf, dev verror: 0.0371
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 23.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 23.0000 ,train derror: inf, dev derror: 0.0787，train verror: inf, dev verror: 0.0370
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 24.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 24.0000 ,train derror: inf, dev derror: 0.0787，train verror: inf, dev verror: 0.0370
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 25.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 25.0000 ,train derror: inf, dev derror: 0.0786，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 26.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 26.0000 ,train derror: inf, dev derror: 0.0786，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 27.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 27.0000 ,train derror: inf, dev derror: 0.0786，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 28.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 28.0000 ,train derror: inf, dev derror: 0.0786，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 29.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 29.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 30.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 30.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 31.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 31.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 32.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 32.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 33.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 33.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 34.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 34.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 35.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 35.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 36.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 36.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 37.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 37.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 38.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 38.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 39.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 39.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 40.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 40.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 41.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 41.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 42.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 42.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 43.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 43.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 44.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 44.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 45.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 45.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 46.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 46.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 47.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 47.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 48.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 48.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 49.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 49.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 50.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 50.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 51.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 51.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 52.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 52.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 53.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 53.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 54.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 54.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 55.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 55.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 56.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 56.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 57.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 57.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 58.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 58.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 59.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 59.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 60.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 60.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 61.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 61.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 62.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 62.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 63.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 63.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 64.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 64.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 65.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 65.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 66.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 66.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 67.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 67.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 68.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 68.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 69.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 69.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 70.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 70.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 71.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 71.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 72.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 72.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 73.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 73.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 74.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 74.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 75.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 75.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 76.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 76.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 77.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 77.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 78.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 78.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 79.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 79.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 80.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 80.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 81.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 81.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 82.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 82.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 83.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 83.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 84.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 84.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 85.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 85.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------
# epoch 86.0000 ,train loss: 0.0167, dev loss: 0.0086
# epoch 86.0000 ,train derror: inf, dev derror: 0.0785，train verror: inf, dev verror: 0.0369
# -------------------------------------------------------------------------------------------------------------------------------------
